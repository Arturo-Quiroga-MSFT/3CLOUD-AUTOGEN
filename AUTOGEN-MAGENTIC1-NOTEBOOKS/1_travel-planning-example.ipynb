# %%
#%pip install -U "autogen-agentchat"
#%pip install -U "autogen-agentchat[azure]"
#%pip install -U autogenstudio
# %pip install python-dotenv

# %% [markdown]
# ## Example team of AI Assistant agents in a ROUND ROBIN CHATGROUP team

# %%
from autogen_agentchat.agents import AssistantAgent
from autogen_agentchat.conditions import TextMentionTermination
from autogen_agentchat.teams import RoundRobinGroupChat
from autogen_agentchat.ui import Console
from autogen_ext.models.openai import AzureOpenAIChatCompletionClient
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
model_client = AzureOpenAIChatCompletionClient(
    azure_deployment="gpt-4o",
    azure_endpoint="https://aq-aoai-swedencentral.openai.azure.com/",
    model="gpt-4o",
    api_version="2025-03-01-preview",
    api_key="3ShjYyRHd6t0VthIuoOUe1GEnwlj1tkNSHkOs6IrO1CxKQ3gHmsIJQQJ99BAACfhMk5XJ3w3AAABACOG3ddZ",
    temperature=0.7,
)

# %%
planner_agent = AssistantAgent(
    "planner_agent",
    model_client=model_client,
    description="A helpful assistant that can plan trips.",
    system_message="You are a helpful assistant that can suggest a travel plan for a user based on their request.",
)

local_agent = AssistantAgent(
    "local_agent",
    model_client=model_client,
    description="A local assistant that can suggest local activities or places to visit.",
    system_message="You are a helpful assistant that can suggest authentic and interesting local activities or places to visit for a user and can utilize any context information provided.",
)

language_agent = AssistantAgent(
    "language_agent",
    model_client=model_client,
    description="A helpful assistant that can provide language tips for a given destination.",
    system_message="You are a helpful assistant that can review travel plans, providing feedback on important/critical tips about how best to address language or communication challenges for the given destination. If the plan already includes language tips, you can mention that the plan is satisfactory, with rationale.",
)

travel_summary_agent = AssistantAgent(
    "travel_summary_agent",
    model_client=model_client,
    description="A helpful assistant that can summarize the travel plan.",
    system_message="You are a helpful assistant that can take in all of the suggestions and advice from the other agents and provide a detailed final travel plan. You must ensure that the final plan is integrated and complete. YOUR FINAL RESPONSE MUST BE THE COMPLETE PLAN. When the plan is complete and all perspectives are integrated, you can respond with TERMINATE.",
)

# %%
termination = TextMentionTermination("TERMINATE")
group_chat = RoundRobinGroupChat(
    [planner_agent, local_agent, language_agent, travel_summary_agent], termination_condition=termination
)
await Console(group_chat.run_stream(task="Plan a 3 day trip to Nepal."))

await model_client.close()
# Out:
# ---------- user ----------
# Plan a 3 day trip to Nepal.
# ---------- planner_agent ----------
# Certainly! Nepal offers stunning landscapes, rich culture, and unique experiences that can be explored even in a short 3-day trip. Here’s a well-rounded itinerary for your visit:
#
# ---
#
# ### **Day 1: Arrival in Kathmandu & Cultural Exploration**
# **Morning: Arrival in Kathmandu**
# - Land at Tribhuvan International Airport and check into your hotel.
# - Choose a stay in Thamel, a vibrant area with shops, restaurants, and easy access to attractions.
#
# **Afternoon: Explore UNESCO World Heritage Sites**
# 1. **Pashupatinath Temple** – A sacred Hindu temple located on the banks of the Bagmati River.
# 2. **Boudhanath Stupa** – One of the largest Buddhist stupas in the world, a serene and spiritual spot.
#
# **Evening:**
# - Stroll around Thamel and enjoy local Nepali cuisine like momos (dumplings) and dal bhat (lentil curry with rice).
#
# ---
#
# ### **Day 2: Day Trip to Bhaktapur & Nagarkot**
# **Morning: Visit Bhaktapur**
# - Head to Bhaktapur (30 minutes from Kathmandu), a medieval city filled with narrow alleyways, ancient temples, and charming squares.
# - Must-see spots:
#   - **Durbar Square** – A collection of stunning temples and palaces.
#   - **Nyatapola Temple** – The tallest temple in Nepal.
#   - **Pottery Square** – Watch artisans crafting pottery the traditional way.
#
# **Afternoon: Drive to Nagarkot**
# - Nagarkot is a hill station famed for its panoramic views of the Himalayas (including Mount Everest on clear days).
# - Check into a hotel or resort with mountain views.
#
# **Evening:**
# - Capture the sunset over the Himalayas.
# - Relax at your hotel and enjoy the peaceful vibe of Nagarkot.
#
# ---
#
# ### **Day 3: Sunrise in Nagarkot & Return to Kathmandu**
# **Early Morning:**
# - Wake up early to witness the stunning sunrise over the Himalayan range.
#
# **Breakfast & Leisure:**
# - Enjoy breakfast at your resort while soaking in the views.
#
# **Mid-Morning: Return to Kathmandu**
# - Drive back to Kathmandu (1.5 hours).
#
# **Afternoon: Explore Patan**
# - Visit **Patan Durbar Square**, a historic site filled with intricate architecture, temples, and the Patan Museum.
# - Stroll through the streets to see local artisans working on wood carvings and metal crafts.
#
# **Evening:**
# - Head to the Garden of Dreams in Kathmandu for a peaceful end to your trip.
# - Shop for souvenirs like pashmina scarves, handicrafts, or Nepali tea in Thamel.
# - Conclude with a farewell dinner at a traditional Nepali restaurant.
#
# ---
#
# ### Tips for Your Trip:
# - **Transport:** Hire a private vehicle for convenience when traveling to Bhaktapur and Nagarkot.
# - **Best Time to Visit:** October to April offers clear skies and great mountain views.
# - **Packing:** Bring comfortable walking shoes, layers for varying temperatures, and a camera for the stunning landscapes.
#
# Enjoy your adventure in Nepal! Let me know if you'd like further details or adjustments.
# /Users/arturoquiroga/3CLOUD-AUTOGEN/.venv/lib/python3.13/site-packages/autogen_agentchat/agents/_assistant_agent.py:870: UserWarning: Resolved model mismatch: gpt-4o-2024-08-06 != gpt-4o-2024-11-20. Model mapping in autogen_ext.models.openai may be incorrect. Set the model to gpt-4o-2024-11-20 to enhance token/cost estimation and suppress this warning.
#   model_result = await model_client.create(
# ---------- local_agent ----------
# Would you like suggestions for specific hotels or restaurants in Kathmandu, Nagarkot, or Bhaktapur? Or recommendations for guided tours or trekking options to enhance your trip?
# Would you like suggestions for specific hotels or restaurants in Kathmandu, Nagarkot, or Bhaktapur? Or recommendations for guided tours or trekking options to enhance your trip?
# ---------- language_agent ----------
# Before diving into accommodation or guided recommendations, it's crucial to address **language and communication tips** for your Nepal trip:
#
# ### **Language & Communication Tips for Nepal:**
# 1. **National Language:** Nepali is the official language of Nepal. While English is widely spoken in tourist areas like Kathmandu, Bhaktapur, and Nagarkot, knowing a few basic Nepali phrases can be helpful and appreciated by locals:
#    - **Namaste:** Hello or greetings (used universally in Nepal).
#    - **Dhanyabad:** Thank you.
#    - **Kripaya:** Please.
#    - **Kaha cha?:** Where is...?
#    - **Pani:** Water.
#    - **Tapaiko naam k ho?:** What is your name?
#
# 2. **English Proficiency:** Many people working in the tourism industry (hoteliers, guides, shopkeepers, etc.) speak decent English, so you'll be able to communicate effectively in most places, especially in Thamel and tourist hubs.
#
# 3. **Offline Translation Apps:** Download translation apps like Google Translate for Nepali. Consider downloading offline language packs since connectivity can be spotty, particularly in hill stations like Nagarkot.
#
# 4. **Body Language & Gesture:** Nepalese people are warm and welcoming. A smile and polite gestures go a long way, especially when language barriers exist.
#
# 5. **Signage:** Tourist destinations often have bilingual signs (Nepali and English), making navigation relatively easy. However, in rural areas or less-touristed spots, signs might be only in Nepali.
#
# ---
#
# ### **Feedback on Your Plan:**
# Your itinerary is well-planned and incorporates key destinations and cultural highlights. It’s also satisfactory in terms of language considerations, as most of the locations you'll visit are English-friendly. However, adding basic Nepali phrases for greetings and expressions would enhance your experience and build rapport with locals.
#
# Would you like assistance incorporating these language tips into a printable quick-reference guide for your trip?
# ---------- travel_summary_agent ----------
# Here's the final integrated travel plan for your 3-day trip to Nepal, complete with all suggestions and advice:
#
# ---
#
# ### **Day 1: Arrival in Kathmandu & Cultural Exploration**
# **Morning: Arrival in Kathmandu**
# - Land at Tribhuvan International Airport and transfer to your hotel in Thamel, a vibrant area ideal for tourists. Recommended hotels:
#   - **Luxury:** Hotel Yak & Yeti
#   - **Mid-Range:** Kathmandu Guest House
#   - **Budget:** Oasis Kathmandu Hotel
#
# **Afternoon: Explore UNESCO World Heritage Sites**
# 1. **Pashupatinath Temple:** A sacred Hindu temple on the Bagmati River.
# 2. **Boudhanath Stupa:** One of the largest Buddhist stupas in the world; serene and spiritual.
#    - Consider hiring a guide to explain the cultural and historical significance of these sites.
#
# **Evening:**
# - Stroll around Thamel for shopping and dinner. Recommended restaurants:
#   - **OR2K:** Vegetarian cuisine with a cozy ambiance.
#   - **Thamel House Restaurant:** Traditional Nepali food and cultural performances.
#
# **Language Tip:** Greet locals with "Namaste" and say "Dhanyabad" (thank you) when interacting.
#
# ---
#
# ### **Day 2: Day Trip to Bhaktapur & Nagarkot**
# **Morning: Visit Bhaktapur**
# - Drive to Bhaktapur (30 minutes from Kathmandu). Explore:
#   - **Durbar Square:** Stunning temples and palaces.
#   - **Nyatapola Temple:** The tallest pagoda-style temple in Nepal.
#   - **Pottery Square:** Watch artisans craft pottery the traditional way.
# - Recommended lunch spot: **Cafe Nyatapola** for local specialties.
#
# **Afternoon: Drive to Nagarkot**
# - Nagarkot is known for panoramic views of the Himalayas.
# - Check into a mountain-view resort. Recommended stays:
#   - **Luxury:** Club Himalaya, Nagarkot Resort
#   - **Mid-Range:** Hotel Himalayan Villa
#   - **Budget:** Peaceful Cottage
#
# **Evening:**
# - Watch the sunset over the Himalayas.
# - Relax at your hotel and enjoy local dishes.
#
# **Language Tip:** If lost or need directions, ask "Kaha cha?" (Where is...?).
#
# ---
#
# ### **Day 3: Sunrise in Nagarkot & Return to Kathmandu**
# **Early Morning:**
# - Wake up early to witness the breathtaking sunrise over the Himalayas.
# - Take photos or enjoy quiet reflection.
#
# **Breakfast:**
# - Savor breakfast at your resort while soaking in the views.
#
# **Mid-Morning: Return to Kathmandu**
# - Drive back to Kathmandu (1.5 hours).
#
# **Afternoon: Explore Patan**
# - Visit **Patan Durbar Square**, filled with intricate architecture, temples, and the Patan Museum.
# - Recommended lunch spot: **Cafe Swotha** for a fusion of Nepali and international flavors.
# - Stroll through the streets to see artisans creating wood carvings and metal crafts.
#
# **Evening:**
# - Visit the **Garden of Dreams** for peace and relaxation.
# - Shop for souvenirs in Thamel—pashmina scarves, Nepali tea, and handmade crafts are great options.
# - Enjoy a farewell dinner at **Nepali Chulo**, a traditional restaurant with cultural performances.
#
# **Language Tip:** Use simple Nepali words like "Kripaya" (please) when asking for help or ordering food.
#
# ---
#
# ### **Tips for Your Trip**
# 1. **Transport:** Hire a private vehicle for day trips to Bhaktapur and Nagarkot. Alternatively, book guided tours for convenience.
# 2. **Best Time to Visit:** October to April offers clear skies and great mountain views.
# 3. **Packing:** Bring comfortable walking shoes, layers for varying temperatures, and a camera for stunning landscapes.
# 4. **Offline Tools:** Download Google Maps and Google Translate with Nepali offline language packs for seamless communication and navigation.
#
# ---
#
# Enjoy your adventure in Nepal! The itinerary balances cultural immersion, breathtaking scenery, and relaxation, ensuring a memorable experience.
#
# **TERMINATE**
