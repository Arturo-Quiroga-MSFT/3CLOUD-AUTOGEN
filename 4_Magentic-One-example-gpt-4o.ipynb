# %%
#%pip install "autogen-ext[magentic-one,openai]" 
#%pip install gradio
# If using the MultimodalWebSurfer, you also need to install playwright dependencies:

# %% [markdown]
# ## Magentic One Overview
#
# Magentic-One is a generalist multi-agent system for solving open-ended web and file-based tasks across a variety of domains. It represents a significant step forward for multi-agent systems, achieving competitive performance on a number of agentic benchmarks (see the technical report for full details).
#
# When originally released in November 2024 Magentic-One was implemented directly on the autogen-core library. We have now ported Magentic-One to use autogen-agentchat, providing a more modular and easier to use interface.
#
# Using Magentic-One involves interacting with a digital world designed for humans, which carries inherent risks. To minimize these risks, consider the following precautions:
#
# - Use Containers: Run all tasks in docker containers to isolate the agents and prevent direct system attacks.
#
# - Virtual Environment: Use a virtual environment to run the agents and prevent them from accessing sensitive data.
#
# - Monitor Logs: Closely monitor logs during and after execution to detect and mitigate risky behavior.
#
# - Human Oversight: Run the examples with a human in the loop to supervise the agents and prevent unintended consequences.
#
# - Limit Access: Restrict the agents’ access to the internet and other resources to prevent unauthorized actions.
#
# - Safeguard Data: Ensure that the agents do not have access to sensitive data or resources that could be compromised. Do not share sensitive information with the agents. Be aware that agents may occasionally attempt risky actions, such as recruiting humans for help or accepting cookie agreements without human involvement. Always ensure agents are monitored and operate within a controlled environment to prevent unintended consequences. Moreover, be cautious that Magentic-One may be susceptible to prompt injection attacks from webpages.

# %% [markdown]
# ## Import Required Dependencies

# %%
import asyncio
from autogen_ext.models.openai import AzureOpenAIChatCompletionClient
from autogen_agentchat.agents import AssistantAgent
from autogen_agentchat.teams import MagenticOneGroupChat
from autogen_agentchat.ui import Console
from autogen_ext.agents.web_surfer import MultimodalWebSurfer
from autogen_ext.agents.file_surfer import FileSurfer
from autogen_ext.agents.magentic_one import MagenticOneCoderAgent
from autogen_agentchat.agents import CodeExecutorAgent
from autogen_ext.code_executors.local import LocalCommandLineCodeExecutor

# %% [markdown]
# ## Create a Model Client

# %%
model_client = AzureOpenAIChatCompletionClient(
    azure_deployment="gpt-4o",
    azure_endpoint="https://aq-aoai-swedencentral.openai.azure.com/",
    model="gpt-4o",
    api_version="2025-03-01-preview",
    api_key="3ShjYyRHd6t0VthIuoOUe1GEnwlj1tkNSHkOs6IrO1CxKQ3gHmsIJQQJ99BAACfhMk5XJ3w3AAABACOG3ddZ",
    temperature=0.7,
)

# %% [markdown]
# ## Create Basic Team with one Assistant only

# %%
async def main() -> None:
    assistant = AssistantAgent(
        "Assistant",
        model_client=model_client,
    )
    team = MagenticOneGroupChat([assistant], model_client=model_client)
    await Console(team.run_stream(task="Provide a different proof for Fermat's Last Theorem"))
    await model_client.close()


await main()

# %% [markdown]
# ## Create a team with a multimodal websurfer
#
# - WebSurfer: A helpful assistant with access to a web browser. Ask them to perform web searches, open pages, and interact with content (e.g., clicking links, scrolling the viewport, filling in form fields, etc.). It can also summarize the entire page, or answer questions based on the content of the page. It can also be asked to sleep and wait for pages to load, in cases where the page seems not yet fully loaded.

# %%
async def main() -> None:
    surfer = MultimodalWebSurfer(
        "WebSurfer",
        model_client=model_client,
    )

    team = MagenticOneGroupChat([surfer], model_client=model_client)
    await Console(team.run_stream(task="What is the UV index in Melbourne today?"))




await main()

# %% [markdown]
# ## Create a multi-agent team with the following capabilities
#
# - WebSurfer: A helpful assistant with access to a web browser. Ask them to perform web searches, open pages, and interact with content (e.g., clicking links, scrolling the viewport, filling in form fields, etc.). It can also summarize the entire page, or answer questions based on the content of the page. It can also be asked to sleep and wait for pages to load, in cases where the page seems not yet fully loaded.
#
# - FileSurfer: An agent that can handle local files.
#
# - Coder: A helpful and general-purpose AI assistant that has strong language skills, Python skills, and Linux command line skills.
#
# - ComputerTerminal: A computer terminal that performs no other action than running Python scripts (provided to it quoted in python code blocks), or sh shell scripts (provided to it quoted in sh code blocks).

# %%
async def main() -> None:
    surfer = MultimodalWebSurfer(
        "WebSurfer",
        model_client=model_client,
    )

    file_surfer = FileSurfer( "FileSurfer",model_client=model_client)
    coder = MagenticOneCoderAgent("Coder",model_client=model_client)
    terminal = CodeExecutorAgent("ComputerTerminal",code_executor=LocalCommandLineCodeExecutor())
    
    team = MagenticOneGroupChat([surfer, file_surfer, coder, terminal], model_client=model_client)

    await Console(team.run_stream(task="What is the UV index in Melbourne today?"))



await main()
# Out:
# /Users/arturoquiroga/AUTOGEN for 3CLOUD/.venv/lib/python3.13/site-packages/autogen_agentchat/teams/_group_chat/_magentic_one/_magentic_one_orchestrator.py:158: UserWarning: Resolved model mismatch: gpt-4o-2024-08-06 != gpt-4o-2024-11-20. Model mapping in autogen_ext.models.openai may be incorrect. Set the model to gpt-4o-2024-11-20 to enhance token/cost estimation and suppress this warning.
#   response = await self._model_client.create(
# /Users/arturoquiroga/AUTOGEN for 3CLOUD/.venv/lib/python3.13/site-packages/autogen_agentchat/teams/_group_chat/_magentic_one/_magentic_one_orchestrator.py:171: UserWarning: Resolved model mismatch: gpt-4o-2024-08-06 != gpt-4o-2024-11-20. Model mapping in autogen_ext.models.openai may be incorrect. Set the model to gpt-4o-2024-11-20 to enhance token/cost estimation and suppress this warning.
#   response = await self._model_client.create(
# ---------- user ----------
# What is the UV index in Melbourne today?
# ---------- MagenticOneOrchestrator ----------
#
# We are working to address the following user request:
#
# What is the UV index in Melbourne today?
#
#
# To answer this request we have assembled the following team:
#
# WebSurfer: A helpful assistant with access to a web browser. Ask them to perform web searches, open pages, and interact with content (e.g., clicking links, scrolling the viewport, filling in form fields, etc.). It can also summarize the entire page, or answer questions based on the content of the page. It can also be asked to sleep and wait for pages to load, in cases where the page seems not yet fully loaded.
# FileSurfer: An agent that can handle local files.
# Coder: A helpful and general-purpose AI assistant that has strong language skills, Python skills, and Linux command line skills.
# ComputerTerminal: A computer terminal that performs no other action than running Python scripts (provided to it quoted in ```python code blocks), or sh shell scripts (provided to it quoted in ```sh code blocks).
#
#
# Here is an initial fact sheet to consider:
#
# ### 1. GIVEN OR VERIFIED FACTS
# - The request asks for the UV index in Melbourne today.
# - The location specified is Melbourne.
# - The timeframe specified is "today."
#
# ### 2. FACTS TO LOOK UP
# - The current UV index in Melbourne today.
# - This information can likely be found on authoritative meteorological websites such as:
#   - Australian Bureau of Meteorology (BOM)
#   - World Meteorological Organization (WMO)
#   - Weather tracking services like Weather.com or AccuWeather.
#
# ### 3. FACTS TO DERIVE
# - The UV index might need to be contextualized if additional factors such as cloud cover or pollutants are relevant and influence the measurement.
#
# ### 4. EDUCATED GUESSES
# - Melbourne, being in Australia, typically experiences high UV indexes during its sunny seasons due to its geographic location and proximity to the ozone hole over Antarctica.
# - If the request is made during Australian summer (December-February), the UV index is likely to be high, potentially above 7 or 8.
#
#
# Here is the plan to follow as best as possible:
#
# - **Step 1**: Assign **WebSurfer** to search for the current UV index in Melbourne today, using authoritative meteorological sources such as the Australian Bureau of Meteorology (BOM) or other reliable weather websites.
# - **Step 2**: Confirm that the information is up-to-date and specific to today's date.
# - **Step 3**: Report the findings to the user in a concise and clear format.
#
# ---------- MagenticOneOrchestrator ----------
# Please search for the current UV index in Melbourne today using reliable sources such as the Australian Bureau of Meteorology (BOM) or other trusted weather websites, and report back with the information.
# /Users/arturoquiroga/AUTOGEN for 3CLOUD/.venv/lib/python3.13/site-packages/autogen_agentchat/teams/_group_chat/_magentic_one/_magentic_one_orchestrator.py:298: UserWarning: Resolved model mismatch: gpt-4o-2024-08-06 != gpt-4o-2024-11-20. Model mapping in autogen_ext.models.openai may be incorrect. Set the model to gpt-4o-2024-11-20 to enhance token/cost estimation and suppress this warning.
#   response = await self._model_client.create(self._get_compatible_context(context), json_output=True)
# /Users/arturoquiroga/AUTOGEN for 3CLOUD/.venv/lib/python3.13/site-packages/autogen_ext/agents/web_surfer/_multimodal_web_surfer.py:612: UserWarning: Resolved model mismatch: gpt-4o-2024-08-06 != gpt-4o-2024-11-20. Model mapping in autogen_ext.models.openai may be incorrect. Set the model to gpt-4o-2024-11-20 to enhance token/cost estimation and suppress this warning.
#   response = await self._model_client.create(
# ---------- WebSurfer ----------
# I typed 'current UV index in Melbourne today' into the browser search bar.
#
# The web browser is open to the page [current UV index in Melbourne today - Search](https://www.bing.com/search?q=current+UV+index+in+Melbourne+today&FORM=QBLH).
# The viewport shows 31% of the webpage, and is positioned at the top of the page
# The following text is visible in the viewport:
#
# By using this site you agree to the use of cookies for analytics, personalized content, and ads.
# Learn more about third party cookies
# |
# Microsoft Privacy Policy
# Skip to content
# current UV index in Melbourne todayFrançaisMobileAll
# Search
# News
# Images
# Videos
# Maps
# Copilot
# More
# Tools
# About 971,000 resultsMelbourne, Victoria, AustraliaUpdated a few minutes ago
# Share
# Print
# Feedback
# 20
# °C
# F31°16°
# Wind: 8 KMPH
# Humidity: 55%
# Mostly cloudy
# Fri 18, 12:22 a.m.
# 1 AM
# 4 AM
# 7 AM
# 10 AM
# 1 PM
# 4 PM
# 7 PM
# 10 PM
# 1 AM
# 4 AM
# 7 AM
# 10 AM
# 1 PM
# 4 PM
# 7 PM
# 10 PM
# Fri 1831°16°Sat 1928°21°Sun 2026°12°Mon 2119°15°Tue 2219°15°Wed 2322°13°Thu 2424°14°Fri 2518°11°Sat 2617°11°Sun 2717°9°20°
# 1%
# 1 AM
# 19°
# 5%
# 4 AM
# 19°
# 1%
# 7 AM
# 26°
# 10 AM
# 29°
# 1 PM
# 31°
# 4 PM
# 22°
# 7 PM
# 19°
# 1%
# 10 PM
# 18°
# 1 AM
# 17°
# 4 AM
# 16°
# 7 AM
# 24°
# 10 AM
# 28°
# 1 PM
# 28°
# 2%
# 4 PM
# 25°
# 1%
# 7 PM
# 22°
# 3%
# 10 PM
# Detailed forecast · Images by GettyShow background
# UV index
# No forecast
# Gentle breeze
# 8 KMPH, N
# Sunrise
# 06:48 AM
# Sunset
# 05:50 PM
# Feedback
# uvindex.io
# https://uvindex.io › melbourne
# Temperature
# Radar
# Wind
# Launch MSN weather map
# More about Melbourne weather
# MSN
# Weather.com
# WundergroundRow
# Accuweather
# Historical weather and averages
# Temperature
# Rain
# Avg Low
# Avg High
# Rec Low
# Rec High
# Apr.
# 11°
# 20°
# 2°(2009)34°(2005)May
# 9°
# 17°
# 2°(2008)27°(2002)Jun.
# 7°
# 14°
# 0°(1998)22°(2005)See full year
#
# The following metadata was extracted from the webpage:
#
# {
#     "meta_tags": {
#         "referrer": "origin-when-cross-origin",
#         "SystemEntropyOriginTrialToken": "A5is4nwJJVnhaJpUr1URgj4vvAXSiHoK0VBbM9fawMskbDUj9WUREpa3JzGAo6xd1Cp2voQEG1h6NQ71AsMznU8AAABxeyJvcmlnaW4iOiJodHRwczovL3d3dy5iaW5nLmNvbTo0NDMiLCJmZWF0dXJlIjoiTXNVc2VyQWdlbnRMYXVuY2hOYXZUeXBlIiwiZXhwaXJ5IjoxNzUzNzQ3MjAwLCJpc1N1YmRvbWFpbiI6dHJ1ZX0=",
#         "ConfidenceOriginTrialToken": "Aqw360MHzRcmtEVv55zzdIWcTk2BBYHcdBAOysNJZP4qkN8M+5vUq36ITHFVst8LiX36KBZJXB8xvyBgdK2z5Q0AAAB6eyJvcmlnaW4iOiJodHRwczovL2JpbmcuY29tOjQ0MyIsImZlYXR1cmUiOiJQZXJmb3JtYW5jZU5hdmlnYXRpb25UaW1pbmdDb25maWRlbmNlIiwiZXhwaXJ5IjoxNzYwNDAwMDAwLCJpc1N1YmRvbWFpbiI6dHJ1ZX0=",
#         "og:description": "Intelligent search from Bing makes it easier to quickly find what you\u2019re looking for and rewards you.",
#         "og:site_name": "Bing",
#         "og:title": "current UV index in Melbourne today - Bing",
#         "og:url": "https://www.bing.com/search?q=current+UV+index+in+Melbourne+today&FORM=QBLH",
#         "fb:app_id": "3732605936979161",
#         "og:image": "http://www.bing.com/sa/simg/facebook_sharing_5.png",
#         "og:type": "website",
#         "og:image:width": "600",
#         "og:image:height": "315"
#     }
# }
#
# Here is a screenshot of the page.
#
# ---------- MagenticOneOrchestrator ----------
# Please search for Melbourne's UV index today on the Australian Bureau of Meteorology (BOM) website or other authoritative meteorological sources, and report back with the information.
# /Users/arturoquiroga/AUTOGEN for 3CLOUD/.venv/lib/python3.13/site-packages/autogen_agentchat/teams/_group_chat/_magentic_one/_magentic_one_orchestrator.py:298: UserWarning: Resolved model mismatch: gpt-4o-2024-08-06 != gpt-4o-2024-11-20. Model mapping in autogen_ext.models.openai may be incorrect. Set the model to gpt-4o-2024-11-20 to enhance token/cost estimation and suppress this warning.
#   response = await self._model_client.create(self._get_compatible_context(context), json_output=True)
# ---------- WebSurfer ----------
# I clicked 'Bureau of Meteorology'.
#
# The web browser is open to the page [Melbourne Ultraviolet (UV) Index Forecast Graph](http://www.bom.gov.au/vic/uv/melbourne.shtml).
# The viewport shows 76% of the webpage, and is positioned at the top of the page
# The following text is visible in the viewport:
#
# HomeAboutMediaContactsNSW
# VIC
# QLD
# WA
# SA
# TAS
# ACT
# NT
# Australia
# Antarctica
#  Until the outcome of the 2025 federal election, the Australian Government is operating under
# caretaker conventionsBureau Home >
# Australia >
# Victoria >
# UV Index Forcast for Vic >
# Melbourne Ultraviolet (UV) Index Forecast GraphMelbourne Ultraviolet (UV) Index Forecast Graph
# UV Home About the UV Index FAQ More UV Info. Data Services Average UV indexThe Melbourne UV forecast and sun protection times are now available in the
# MetEye Text Views.
# More information about changes to UV products.
# Check and Protect
# It is important for all Australians or visitors to Australia, to look and listen for UV Index levels in local weather forecasts.
# Remember
# You should use a combination of sun protection measures to keep you safe from UV radiation - never rely on just one.
# Further Information
# SunSmartSunSmart App Vitamin D deficiencyUV Measurements - ARPANSA
#
# The following metadata was extracted from the webpage:
#
# {
#     "meta_tags": {
#         "language": "english",
#         "DC.Publisher": "corporateName=Bureau of Meteorology",
#         "DC.Format": "text/html",
#         "DC.Coverage.jurisdiction": "Commonwealth of Australia",
#         "DC.Rights": "http://www.bom.gov.au/other/copyright.shtml",
#         "DC.Language": "en",
#         "AGLS.Audience": "All"
#     }
# }
#
# Here is a screenshot of the page.
#
# ---------- MagenticOneOrchestrator ----------
# Search for the UV index value specifically for today in Melbourne using the Bureau of Meteorology's website or another authoritative source, and report back with the specific value.
# ---------- WebSurfer ----------
# The webpage "Melbourne Ultraviolet (UV) Index Forecast Graph" from the Australian Government Bureau of Meteorology provides information about the UV index forecast and sun protection times for Melbourne. It includes a UV index scale ranging from "low" (1-2) to "extreme" (11+), with corresponding recommendations for sun protection measures, such as wearing sun-protective clothing, applying sunscreen, using a hat, seeking shade, and wearing sunglasses. The page emphasizes the importance of checking UV index levels and using multiple sun protection strategies to stay safe from UV radiation.
#
# Additionally, the page links to resources like the SunSmart program, SunSmart app, and information on vitamin D deficiency and UV measurements. Users are directed to the "MetEye Text Views" for detailed Melbourne UV forecasts and informed about changes to UV-related products. The content encourages proactive sun safety to prevent overexposure to harmful UV rays.
# /Users/arturoquiroga/AUTOGEN for 3CLOUD/.venv/lib/python3.13/site-packages/autogen_ext/agents/web_surfer/_multimodal_web_surfer.py:951: UserWarning: Resolved model mismatch: gpt-4o-2024-08-06 != gpt-4o-2024-11-20. Model mapping in autogen_ext.models.openai may be incorrect. Set the model to gpt-4o-2024-11-20 to enhance token/cost estimation and suppress this warning.
#   response = await self._model_client.create(messages, cancellation_token=cancellation_token)
# ---------- MagenticOneOrchestrator ----------
# Please navigate deeper within the Bureau of Meteorology website, using links like 'MetEye Text Views' or any other relevant UV forecast tools, to locate the specific UV index value for Melbourne today.
# ---------- WebSurfer ----------
# I clicked 'MetEye Text Views'.
#
# The web browser is open to the page [Melbourne Forecast - Bureau of Meteorology](http://www.bom.gov.au/places/vic/melbourne/forecast/).
# The viewport shows 43% of the webpage, and is positioned at the top of the page
# The following text is visible in the viewport:
#
# HomeAboutMediaContactsNSW
# VIC
# QLD
# WA
# SA
# TAS
# ACT
# NT
# Australia
# Antarctica
#  Until the outcome of the 2025 federal election, the Australian Government is operating under
# caretaker conventionsHome
# PlacesVictoriaMelbourneMelbourne ForecastMelbourne Forecast
# (beta)Map View
# MetEye
# No warnings for Victoria
# Change location
# Find Me
# Forecast issued at 4:20 pm AEST on Thursday 17 April 2025.
# Forecast for the rest of Friday
# Min
# 19 °C
# Max
# 30 °C
# Partly cloudy.
# Possible rainfall:
# 0 mm
# Chance of any rain:
# 10%
# Melbourne area
# Partly cloudy. Winds north to northwesterly 25 to 40 km/h tending southeast to southwesterly 15 to 20 km/h in the evening then becoming light in the late evening.
# Fire Danger
# High
# Sun protection recommended from 10:10 am to 2:20 pm, UV Index predicted to reach 4 [Moderate]
# Saturday 19 April
# Min
# 15 °C
# Max
# 28 °C
# Partly cloudy.
# Possible rainfall:
# 0 mm
# Chance of any rain:
# 20%
# Melbourne area
# Partly cloudy. The chance of fog about the nearby hills in the early morning. Slight chance of a shower, most likely at night. Light winds becoming northeasterly 15 to 25 km/h in the early morning then tending northerly 20 to 30 km/h in the morning.
# Sun protection recommended from 10:20 am to 2:20 pm, UV Index predicted to reach 4 [Moderate]
# Sunday 20 April
# Min
# 20 °C
# Max
# 25 °C
# Showers.
# Possible rainfall:
# 1 to 8 mm
# Melbourne area
# Partly cloudy. High chance of showers. Winds northerly 20 to 30 km/h tending northwesterly 15 to 25 km/h during the afternoon then becoming light during the evening.
# Weather Overview
# Detailed 3-Hourly Forecast
# Extended Forecast (7-day)
# Current and Past Weather
# Radar
#
# The following metadata was extracted from the webpage:
#
# {
#     "meta_tags": {
#         "viewport": "width=device-width",
#         "DC.Identifier": "http://www.bom.gov.au/vic/melbourne/",
#         "DC.Title": "Melbourne weather and warnings information",
#         "DC.Creator": "corporateName=Bureau of Meteorology",
#         "DC.Subject": "Weather forecast-Melbourne; Severe weather warnings; Satellite meteorology; Radar meteorology",
#         "DC.Publisher": "corporateName=Bureau of Meteorology",
#         "DC.Date.created": "2000",
#         "DC.Description": "Provides access to Australian weather forecasts, weather observations, flood warnings and high sea forecasts from each state and territory provided by the Bureau of Meteorology",
#         "DC.Type.documentType": "Web page; map",
#         "DC.Format": "text/html",
#         "DC.Coverage.jurisdiction": "Commonwealth of Australia",
#         "DC.Rights": "http://www.bom.gov.au/other/copyright.shtml",
#         "AGLS.Function": "; Earth Sciences; Atmospheric sciences; Hydrology; Oceanography",
#         "AGLS.Audience": "All",
#         "DC.Language": "en",
#         "DC.Type.aggregationLevel": "collection",
#         "AGLS.Availability": "corporateName=Bureau of Meteorology; address=GPO Box 1289K, Melbourne, Victoria; postcode=3001; contact=tel 03 9669 4000; contact=fax 03 9669 4699; contact=ABN 92637533532",
#         "keywords": "Weather forecasts; Weather warnings; Weather observations; Tropical cyclone warnings; Flood warnings; Satellite imagery; Radar imagery; Current and forecast charts",
#         "description": "Provides access to Melbourne weather forecasts, warnings, observations and radar and satellite imagery provided by the Bureau of Meteorology"
#     }
# }
#
# Here is a screenshot of the page.
#
# ---------- MagenticOneOrchestrator ----------
# The UV index in Melbourne today is predicted to reach 4, which is considered "Moderate." Sun protection is recommended between 10:10 AM and 2:20 PM. Make sure to use sun protection measures like sunscreen, a hat, and sunglasses during this time.
# /Users/arturoquiroga/AUTOGEN for 3CLOUD/.venv/lib/python3.13/site-packages/autogen_agentchat/teams/_group_chat/_magentic_one/_magentic_one_orchestrator.py:440: UserWarning: Resolved model mismatch: gpt-4o-2024-08-06 != gpt-4o-2024-11-20. Model mapping in autogen_ext.models.openai may be incorrect. Set the model to gpt-4o-2024-11-20 to enhance token/cost estimation and suppress this warning.
#   response = await self._model_client.create(
