# %%
#%pip install -U "autogen-agentchat"
#%pip install -U "autogen-agentchat[azure]"
#%pip install -U autogenstudio

# %% [markdown]
# # Example using the ROUND ROBIN GROUPCHAT team

# %%
from autogen_agentchat.agents import AssistantAgent
from autogen_agentchat.conditions import TextMentionTermination
from autogen_agentchat.teams import RoundRobinGroupChat
from autogen_agentchat.ui import Console
from autogen_ext.models.openai import AzureOpenAIChatCompletionClient

# %% [markdown]
# ## with o1 reasoning model

# %%
model_client = AzureOpenAIChatCompletionClient(
    azure_deployment="o1",
    azure_endpoint="https://aq-aoai-swedencentral.openai.azure.com/",
    model="o1",
    api_version="2025-03-01-preview",
    api_key="3ShjYyRHd6t0VthIuoOUe1GEnwlj1tkNSHkOs6IrO1CxKQ3gHmsIJQQJ99BAACfhMk5XJ3w3AAABACOG3ddZ",
 #   temperature=0.7,
)

# %%
#%pip install yfinance matplotlib pytz numpy pandas python-dotenv requests bs4

# %%
def google_search_tool(query: str, num_results: int = 2, max_chars: int = 500) -> list:  # type: ignore[type-arg]
    import os
    import time

    import requests
    from bs4 import BeautifulSoup
    from dotenv import load_dotenv

    load_dotenv()

    api_key = os.getenv("GOOGLE_API_KEY")
    search_engine_id = os.getenv("GOOGLE_SEARCH_ENGINE_ID")

    if not api_key or not search_engine_id:
        raise ValueError("API key or Search Engine ID not found in environment variables")

    url = "https://customsearch.googleapis.com/customsearch/v1"
    params = {"key": str(api_key), "cx": str(search_engine_id), "q": str(query), "num": str(num_results)}

    response = requests.get(url, params=params)

    if response.status_code != 200:
        print(response.json())
        raise Exception(f"Error in API request: {response.status_code}")

    results = response.json().get("items", [])

    def get_page_content(url: str) -> str:
        try:
            response = requests.get(url, timeout=10)
            soup = BeautifulSoup(response.content, "html.parser")
            text = soup.get_text(separator=" ", strip=True)
            words = text.split()
            content = ""
            for word in words:
                if len(content) + len(word) + 1 > max_chars:
                    break
                content += " " + word
            return content.strip()
        except Exception as e:
            print(f"Error fetching {url}: {str(e)}")
            return ""

    enriched_results = []
    for item in results:
        body = get_page_content(item["link"])
        enriched_results.append(
            {"title": item["title"], "link": item["link"], "snippet": item["snippet"], "body": body}
        )
        time.sleep(1)  # Be respectful to the servers

    return enriched_results

# %%
def stock_analysis_tool(ticker: str) -> dict:  # type: ignore[type-arg]
    import os
    from datetime import datetime, timedelta

    import matplotlib.pyplot as plt
    import numpy as np
    import pandas as pd
    import yfinance as yf
    from pytz import timezone  # type: ignore

    stock = yf.Ticker(ticker)

    # Get historical data (1 year of data to ensure we have enough for 200-day MA)
    end_date = datetime.now(timezone("UTC"))
    start_date = end_date - timedelta(days=365)
    hist = stock.history(start=start_date, end=end_date)

    # Ensure we have data
    if hist.empty:
        return {"error": "No historical data available for the specified ticker."}

    # Compute basic statistics and additional metrics
    current_price = stock.info.get("currentPrice", hist["Close"].iloc[-1])
    year_high = stock.info.get("fiftyTwoWeekHigh", hist["High"].max())
    year_low = stock.info.get("fiftyTwoWeekLow", hist["Low"].min())

    # Calculate 50-day and 200-day moving averages
    ma_50 = hist["Close"].rolling(window=50).mean().iloc[-1]
    ma_200 = hist["Close"].rolling(window=200).mean().iloc[-1]

    # Calculate YTD price change and percent change
    ytd_start = datetime(end_date.year, 1, 1, tzinfo=timezone("UTC"))
    ytd_data = hist.loc[ytd_start:]  # type: ignore[misc]
    if not ytd_data.empty:
        price_change = ytd_data["Close"].iloc[-1] - ytd_data["Close"].iloc[0]
        percent_change = (price_change / ytd_data["Close"].iloc[0]) * 100
    else:
        price_change = percent_change = np.nan

    # Determine trend
    if pd.notna(ma_50) and pd.notna(ma_200):
        if ma_50 > ma_200:
            trend = "Upward"
        elif ma_50 < ma_200:
            trend = "Downward"
        else:
            trend = "Neutral"
    else:
        trend = "Insufficient data for trend analysis"

    # Calculate volatility (standard deviation of daily returns)
    daily_returns = hist["Close"].pct_change().dropna()
    volatility = daily_returns.std() * np.sqrt(252)  # Annualized volatility

    # Create result dictionary
    result = {
        "ticker": ticker,
        "current_price": current_price,
        "52_week_high": year_high,
        "52_week_low": year_low,
        "50_day_ma": ma_50,
        "200_day_ma": ma_200,
        "ytd_price_change": price_change,
        "ytd_percent_change": percent_change,
        "trend": trend,
        "volatility": volatility,
    }

    # Convert numpy types to Python native types for better JSON serialization
    for key, value in result.items():
        if isinstance(value, np.generic):
            result[key] = value.item()

    # Generate plot
    plt.figure(figsize=(12, 6))
    plt.plot(hist.index, hist["Close"], label="Close Price")
    plt.plot(hist.index, hist["Close"].rolling(window=50).mean(), label="50-day MA")
    plt.plot(hist.index, hist["Close"].rolling(window=200).mean(), label="200-day MA")
    plt.title(f"{ticker} Stock Price (Past Year)")
    plt.xlabel("Date")
    plt.ylabel("Price ($)")
    plt.legend()
    plt.grid(True)

    # Save plot to file
    os.makedirs("coding", exist_ok=True)
    plot_file_path = f"coding/{ticker}_stockprice.png"
    plt.savefig(plot_file_path)
    print(f"Plot saved as {plot_file_path}")
    result["plot_file_path"] = plot_file_path

    return result

# %%
search_agent = AssistantAgent(
    name="Google_Search_Agent",
    model_client=model_client,
    tools=[google_search_tool],
    description="Search Google for information, returns top 2 results with a snippet and body content",
    system_message="You are a helpful AI assistant. Solve tasks using your tools.",
)

stock_analysis_agent = AssistantAgent(
    name="Stock_Analysis_Agent",
    model_client=model_client,
    tools=[stock_analysis_tool],
    description="Analyze stock data and generate a plot",
    system_message="Perform data analysis.",
)

report_agent = AssistantAgent(
    name="Report_Agent",
    model_client=model_client,
    description="Generate a report based the search and results of stock analysis",
    system_message="You are a helpful assistant that can generate a comprehensive report on a given topic based on search and stock analysis. When you done with generating the report, reply with TERMINATE.",
)

# %%
team = RoundRobinGroupChat([stock_analysis_agent, search_agent, report_agent], max_turns=3)

# %%
stream = team.run_stream(task="Write a financial report on Microsoft")
await Console(stream)

await model_client.close()
# Out:
# ---------- user ----------
# Write a financial report on Microsoft
# ---------- Stock_Analysis_Agent ----------
# [FunctionCall(id='call_jeKDY1cV5OzA1tQ3xPc5HbDX', arguments='{"ticker":"MSFT"}', name='stock_analysis_tool')]
# Plot saved as coding/MSFT_stockprice.png
# ---------- Stock_Analysis_Agent ----------
# [FunctionExecutionResult(content="{'ticker': 'MSFT', 'current_price': 367.78, '52_week_high': 468.35, '52_week_low': 344.79, '50_day_ma': 390.6660516357422, '200_day_ma': 416.31536514282226, 'ytd_price_change': -49.962371826171875, 'ytd_percent_change': -11.96009199491956, 'trend': 'Downward', 'volatility': 0.2454096273201881, 'plot_file_path': 'coding/MSFT_stockprice.png'}", name='stock_analysis_tool', call_id='call_jeKDY1cV5OzA1tQ3xPc5HbDX', is_error=False)]
# ---------- Stock_Analysis_Agent ----------
# {'ticker': 'MSFT', 'current_price': 367.78, '52_week_high': 468.35, '52_week_low': 344.79, '50_day_ma': 390.6660516357422, '200_day_ma': 416.31536514282226, 'ytd_price_change': -49.962371826171875, 'ytd_percent_change': -11.96009199491956, 'trend': 'Downward', 'volatility': 0.2454096273201881, 'plot_file_path': 'coding/MSFT_stockprice.png'}
# ---------- Google_Search_Agent ----------
# Below is a concise financial report on Microsoft Corporation (ticker: MSFT), incorporating both recent share price indicators and broader business context. This report reflects publicly available data and does not constitute investment advice.
#
# 1. Overview of Microsoft Corporation
#    • Business Segments: Microsoft operates in Productivity & Business Processes (including Office 365, LinkedIn, and Dynamics), Intelligent Cloud (Azure, Windows Server, SQL Server), and More Personal Computing (Windows OS, Surface devices, Xbox, and Bing).
#    • Competitive Position: Microsoft remains one of the world’s leading technology companies, with strengths in cloud services (Azure competing with Amazon Web Services and Google Cloud), software suites (Microsoft 365 suite), and diverse hardware and gaming solutions.
#
# 2. Share Price Performance
#    • Current Price: US$367.78
#    • 52-Week Range: US$344.79 (low) – US$468.35 (high)
#    • Moving Averages:
#      – 50-Day MA: US$390.67
#      – 200-Day MA: US$416.32
#    • YTD Price Change: –US$49.96, or –11.96% year-to-date
#
#    Observations:
#    • The stock is trading below both its 50-day and 200-day moving averages, suggesting near-term and mid-term downward momentum.
#    • The current price is closer to its 52-week low than its high, reflecting a period of relative weakness.
#
# 3. Price Trend and Volatility
#    • Trend: Downward in recent weeks, as indicated by the negative year-to-date price change and the break below key moving averages.
#    • Volatility: 0.2454 (approx. 24.5% annualized). This measure is moderately high for a large-cap technology stock, indicating notable price swings, likely driven by macroeconomic factors (e.g., interest rate changes, inflationary pressures, and overall tech sentiment).
#
# 4. Financial Strength and Recent Considerations
#    • Balance Sheet: Microsoft maintains a strong balance sheet, historically demonstrating robust cash flows and moderate debt levels.
#    • Revenue Growth Drivers: Long-term growth is fueled by Microsoft’s continued shift to cloud-based solutions (Azure), subscription-based products (Microsoft 365), and its expanding portfolio (LinkedIn, GitHub, and gaming).
#    • Risks and Challenges:
#      – Slowed PC shipments can temper Windows OS sales.
#      – Competition in the cloud market is fierce, potentially affecting Azure’s market share.
#      – Regulatory scrutiny, especially around large tech companies’ dominance and acquisitions (e.g., Activision Blizzard deal).
#
# 5. Strategic Initiatives
#    • Cloud & AI: Ongoing investment in artificial intelligence and integration of AI features across Microsoft’s product ecosystem (e.g., Copilot in Microsoft 365).
#    • Expansion through Acquisitions: A key driver of growth and diversification, though subject to regulatory compliance.
#    • Diversification: Gaming (Xbox, Xbox Game Pass) and hardware (Surface) help spread revenue streams beyond traditional software licensing.
#
# 6. Conclusion
#    • Microsoft’s robust portfolio, steady revenue streams, and strong cash flows suggest it remains in a sound financial position despite recent share price weakness.
#    • Market volatility in the technology sector and macroeconomic headwinds seem to weigh on the current stock price, pushing MSFT below its short- and long-term moving averages.
#    • Long-term prospects will hinge on Microsoft’s ability to expand its cloud offerings, strengthen its AI integrations, and manage competition effectively.
#
# Disclaimer: This report is for informational purposes only and does not constitute financial or investment advice. Stock prices and fundamentals can change rapidly. Always conduct your own due diligence or consult a licensed financial advisor before making investment decisions.
# ---------- Report_Agent ----------
# Below is a comprehensive financial report on Microsoft Corporation (ticker: MSFT), integrating recent stock analysis data and broader business insights. This report is for informational purposes only and does not constitute investment advice.
#
# 1. Overview of the Business
# • Core Segments: Microsoft operates in three main segments:
#   – Productivity & Business Processes: Office 365, Dynamics, and LinkedIn.
#   – Intelligent Cloud: Azure, Windows Server, SQL Server.
#   – More Personal Computing: Windows OS, Surface devices, Xbox, and Bing.
# • Position in the Market: With its wide range of software, services, and hardware, the company is regarded as one of the most diversified tech majors. Key growth drivers include cloud-based solutions, subscription-based offerings, and a focus on artificial intelligence.
#
# 2. Recent Share Price Performance
# • Current Stock Price: US$367.78
# • 52-Week Range: US$344.79 (low) – US$468.35 (high)
# • Moving Averages:
#   – 50-Day Moving Average (MA): US$390.67
#   – 200-Day MA: US$416.32
# • Year-to-Date (YTD) Performance: The stock price is down approximately US$49.96 from the start of the year, representing a –11.96% change.
# • Key Observation: The price is trading below both its 50-day and 200-day averages, indicating recent downward momentum. It is also closer to its 52-week low than its high, highlighting near-term negative market sentiment.
#
# 3. Technical Trend and Volatility
# • Trend: Downward, as the stock has breached key moving averages and has a negative YTD return.
# • Volatility: ~24.5% annualized, which is moderately high for a large-cap tech stock. Market volatility may be tied to macroeconomic challenges such as inflation, interest rate concerns, and shifting investor sentiment on technology.
#
# 4. Financial Strength and Key Drivers
# • Balance Sheet: Microsoft is known for a robust balance sheet, characterized by steady cash generation and moderate debt levels.
# • Cloud and AI: Azure’s continued growth, alongside Microsoft 365, is central to the company’s long-term expansion. AI integrations (e.g., Copilot in Microsoft 365) also drive new revenue opportunities.
# • Diversification: Its portfolio extends into gaming (Xbox, Game Pass), professional networking (LinkedIn), and code repositories (GitHub), mitigating dependence on any single product line.
# • Potential Risks:
#   – Strong competition in cloud from Amazon Web Services and Google Cloud.
#   – Regulatory scrutiny on big tech acquisitions (e.g., Activision Blizzard) and antitrust matters.
#   – Slower PC shipments could weigh on Windows OS licensing revenue.
#
# 5. Strategic Initiatives and Outlook
# • Emphasis on AI and Cloud: Microsoft invests heavily in AI across existing platforms to differentiate its offerings and unlock new revenue streams.
# • Ongoing M&A: Strategic acquisitions support Microsoft’s expansion in gaming, software, and emerging technologies, but may face heightened regulatory review.
# • Long-Term Prospects: Despite near-term price weakness, Microsoft’s broad set of offerings, recurring revenue from subscriptions, and strong financial position continue to support its long-run growth potential.
#
# Conclusion:
# Microsoft’s recent share price reflects broader tech sector volatility and macroeconomic headwinds. Nonetheless, its high-margin software and cloud services, strong brand recognition, and focus on AI-driven innovation suggest the company is well-positioned for future growth. As always, potential investors should monitor competitive dynamics in cloud computing, regulatory developments, and global economic conditions.
#
# Disclaimer:
# This report is provided for informational purposes only and should not be considered financial or investment advice. Always conduct personal due diligence or consult a qualified financial advisor before making investment decisions.
#
# TERMINATE
