# %%
#%pip install -U "autogen-agentchat"
#%pip install -U "autogen-agentchat[azure]"
#%pip install -U autogenstudio

# %%
from autogen_agentchat.agents import AssistantAgent
from autogen_agentchat.conditions import TextMentionTermination
from autogen_agentchat.teams import RoundRobinGroupChat
from autogen_agentchat.ui import Console
from autogen_ext.models.openai import AzureOpenAIChatCompletionClient

# %%
model_client = AzureOpenAIChatCompletionClient(
    azure_deployment="gpt-4o",
    azure_endpoint="https://aq-aoai-swedencentral.openai.azure.com/",
    model="gpt-4o",
    api_version="2025-03-01-preview",
    api_key="3ShjYyRHd6t0VthIuoOUe1GEnwlj1tkNSHkOs6IrO1CxKQ3gHmsIJQQJ99BAACfhMk5XJ3w3AAABACOG3ddZ",
    temperature=0.7,
)

# %%
#%pip install yfinance matplotlib pytz numpy pandas python-dotenv requests bs4

# %%
def google_search_tool(query: str, num_results: int = 2, max_chars: int = 500) -> list:  # type: ignore[type-arg]
    import os
    import time

    import requests
    from bs4 import BeautifulSoup
    from dotenv import load_dotenv

    load_dotenv()

    api_key = os.getenv("GOOGLE_API_KEY")
    search_engine_id = os.getenv("GOOGLE_SEARCH_ENGINE_ID")

    if not api_key or not search_engine_id:
        raise ValueError("API key or Search Engine ID not found in environment variables")

    url = "https://customsearch.googleapis.com/customsearch/v1"
    params = {"key": str(api_key), "cx": str(search_engine_id), "q": str(query), "num": str(num_results)}

    response = requests.get(url, params=params)

    if response.status_code != 200:
        print(response.json())
        raise Exception(f"Error in API request: {response.status_code}")

    results = response.json().get("items", [])

    def get_page_content(url: str) -> str:
        try:
            response = requests.get(url, timeout=10)
            soup = BeautifulSoup(response.content, "html.parser")
            text = soup.get_text(separator=" ", strip=True)
            words = text.split()
            content = ""
            for word in words:
                if len(content) + len(word) + 1 > max_chars:
                    break
                content += " " + word
            return content.strip()
        except Exception as e:
            print(f"Error fetching {url}: {str(e)}")
            return ""

    enriched_results = []
    for item in results:
        body = get_page_content(item["link"])
        enriched_results.append(
            {"title": item["title"], "link": item["link"], "snippet": item["snippet"], "body": body}
        )
        time.sleep(1)  # Be respectful to the servers

    return enriched_results

# %%
def stock_analysis_tool(ticker: str) -> dict:  # type: ignore[type-arg]
    import os
    from datetime import datetime, timedelta

    import matplotlib.pyplot as plt
    import numpy as np
    import pandas as pd
    import yfinance as yf
    from pytz import timezone  # type: ignore

    stock = yf.Ticker(ticker)

    # Get historical data (1 year of data to ensure we have enough for 200-day MA)
    end_date = datetime.now(timezone("UTC"))
    start_date = end_date - timedelta(days=365)
    hist = stock.history(start=start_date, end=end_date)

    # Ensure we have data
    if hist.empty:
        return {"error": "No historical data available for the specified ticker."}

    # Compute basic statistics and additional metrics
    current_price = stock.info.get("currentPrice", hist["Close"].iloc[-1])
    year_high = stock.info.get("fiftyTwoWeekHigh", hist["High"].max())
    year_low = stock.info.get("fiftyTwoWeekLow", hist["Low"].min())

    # Calculate 50-day and 200-day moving averages
    ma_50 = hist["Close"].rolling(window=50).mean().iloc[-1]
    ma_200 = hist["Close"].rolling(window=200).mean().iloc[-1]

    # Calculate YTD price change and percent change
    ytd_start = datetime(end_date.year, 1, 1, tzinfo=timezone("UTC"))
    ytd_data = hist.loc[ytd_start:]  # type: ignore[misc]
    if not ytd_data.empty:
        price_change = ytd_data["Close"].iloc[-1] - ytd_data["Close"].iloc[0]
        percent_change = (price_change / ytd_data["Close"].iloc[0]) * 100
    else:
        price_change = percent_change = np.nan

    # Determine trend
    if pd.notna(ma_50) and pd.notna(ma_200):
        if ma_50 > ma_200:
            trend = "Upward"
        elif ma_50 < ma_200:
            trend = "Downward"
        else:
            trend = "Neutral"
    else:
        trend = "Insufficient data for trend analysis"

    # Calculate volatility (standard deviation of daily returns)
    daily_returns = hist["Close"].pct_change().dropna()
    volatility = daily_returns.std() * np.sqrt(252)  # Annualized volatility

    # Create result dictionary
    result = {
        "ticker": ticker,
        "current_price": current_price,
        "52_week_high": year_high,
        "52_week_low": year_low,
        "50_day_ma": ma_50,
        "200_day_ma": ma_200,
        "ytd_price_change": price_change,
        "ytd_percent_change": percent_change,
        "trend": trend,
        "volatility": volatility,
    }

    # Convert numpy types to Python native types for better JSON serialization
    for key, value in result.items():
        if isinstance(value, np.generic):
            result[key] = value.item()

    # Generate plot
    plt.figure(figsize=(12, 6))
    plt.plot(hist.index, hist["Close"], label="Close Price")
    plt.plot(hist.index, hist["Close"].rolling(window=50).mean(), label="50-day MA")
    plt.plot(hist.index, hist["Close"].rolling(window=200).mean(), label="200-day MA")
    plt.title(f"{ticker} Stock Price (Past Year)")
    plt.xlabel("Date")
    plt.ylabel("Price ($)")
    plt.legend()
    plt.grid(True)

    # Save plot to file
    os.makedirs("coding", exist_ok=True)
    plot_file_path = f"coding/{ticker}_stockprice.png"
    plt.savefig(plot_file_path)
    print(f"Plot saved as {plot_file_path}")
    result["plot_file_path"] = plot_file_path

    return result

# %%
search_agent = AssistantAgent(
    name="Google_Search_Agent",
    model_client=model_client,
    tools=[google_search_tool],
    description="Search Google for information, returns top 2 results with a snippet and body content",
    system_message="You are a helpful AI assistant. Solve tasks using your tools.",
)

stock_analysis_agent = AssistantAgent(
    name="Stock_Analysis_Agent",
    model_client=model_client,
    tools=[stock_analysis_tool],
    description="Analyze stock data and generate a plot",
    system_message="Perform data analysis.",
)

report_agent = AssistantAgent(
    name="Report_Agent",
    model_client=model_client,
    description="Generate a report based the search and results of stock analysis",
    system_message="You are a helpful assistant that can generate a comprehensive report on a given topic based on search and stock analysis. When you done with generating the report, reply with TERMINATE.",
)

# %%
team = RoundRobinGroupChat([stock_analysis_agent, search_agent, report_agent], max_turns=3)

# %%
stream = team.run_stream(task="Write a financial report on Microsoft")
await Console(stream)

await model_client.close()
# Out:
# ---------- user ----------
# Write a financial report on Microsoft
# ---------- Stock_Analysis_Agent ----------
# [FunctionCall(id='call_nFvN823KXkLf20EHhURdIkgW', arguments='{"ticker":"MSFT"}', name='stock_analysis_tool')]
# /Users/arturoquiroga/AUTOGEN for 3CLOUD/.venv/lib/python3.13/site-packages/autogen_agentchat/agents/_assistant_agent.py:870: UserWarning: Resolved model mismatch: gpt-4o-2024-08-06 != gpt-4o-2024-11-20. Model mapping in autogen_ext.models.openai may be incorrect. Set the model to gpt-4o-2024-11-20 to enhance token/cost estimation and suppress this warning.
#   model_result = await model_client.create(
# Plot saved as coding/MSFT_stockprice.png
# ---------- Stock_Analysis_Agent ----------
# [FunctionExecutionResult(content="{'ticker': 'MSFT', 'current_price': 371.61, '52_week_high': 468.35, '52_week_low': 344.79, '50_day_ma': 391.5597113037109, '200_day_ma': 416.7469009399414, 'ytd_price_change': -46.13238525390625, 'ytd_percent_change': -11.043262187420142, 'trend': 'Downward', 'volatility': 0.24546883014257362, 'plot_file_path': 'coding/MSFT_stockprice.png'}", name='stock_analysis_tool', call_id='call_nFvN823KXkLf20EHhURdIkgW', is_error=False)]
# ---------- Stock_Analysis_Agent ----------
# {'ticker': 'MSFT', 'current_price': 371.61, '52_week_high': 468.35, '52_week_low': 344.79, '50_day_ma': 391.5597113037109, '200_day_ma': 416.7469009399414, 'ytd_price_change': -46.13238525390625, 'ytd_percent_change': -11.043262187420142, 'trend': 'Downward', 'volatility': 0.24546883014257362, 'plot_file_path': 'coding/MSFT_stockprice.png'}
# ---------- Google_Search_Agent ----------
# ### Financial Report: Microsoft Corporation (Ticker: MSFT)
#
# #### Current Stock Metrics:
# - **Current Price:** $371.61
# - **52-Week High:** $468.35
# - **52-Week Low:** $344.79
# - **50-Day Moving Average:** $391.56
# - **200-Day Moving Average:** $416.75
#
# #### Year-to-Date Performance:
# - **Price Change:** -$46.13
# - **Percentage Change:** -11.04%
# - **Trend:** Downward
#
# #### Volatility:
# The stock exhibits a volatility of **0.245**, indicating moderate price fluctuations over time.
#
# #### Stock Price Trend:
# From the data, Microsoft’s stock price has been on a downward trend for the year. The current price is below both the 50-day and 200-day moving averages, signaling potential bearish sentiment in the market.
#
# #### Key Observations:
# 1. **52-Week Range:** The stock is closer to its 52-week low, suggesting that it has experienced significant declines from its peak.
# 2. **Moving Averages:** The divergence of the current price from the moving averages further supports the downward trend.
# 3. **Year-to-Date Performance:** A double-digit percentage decrease in price highlights challenges the company might be facing or broader market impacts.
#
# #### Recommendations:
# Investors should consider:
# - Conducting further analysis of Microsoft's financials and operational performance.
# - Monitoring market conditions, especially factors influencing the tech sector.
# - Evaluating whether the stock's current performance aligns with long-term investment goals.
#
# For visual analysis, the stock price trend is depicted in the attached plot.
#
# *(Plot file path: coding/MSFT_stockprice.png)*
# /Users/arturoquiroga/AUTOGEN for 3CLOUD/.venv/lib/python3.13/site-packages/autogen_agentchat/agents/_assistant_agent.py:870: UserWarning: Resolved model mismatch: gpt-4o-2024-08-06 != gpt-4o-2024-11-20. Model mapping in autogen_ext.models.openai may be incorrect. Set the model to gpt-4o-2024-11-20 to enhance token/cost estimation and suppress this warning.
#   model_result = await model_client.create(
# ---------- Report_Agent ----------
# ### Comprehensive Financial Report: Microsoft Corporation (MSFT)
#
# #### Overview:
# Microsoft Corporation is one of the largest technology companies globally, renowned for its diverse portfolio, including software products like Windows and Office, hardware such as Surface devices, and cloud computing services via Azure. As of the latest analysis, Microsoft's stock performance has shown mixed signals, reflecting both market dynamics and company-specific factors.
#
# ---
#
# ### **I. Stock Performance Analysis**
# **Current Price:** $371.61
# **52-Week Range:** $344.79 - $468.35
# **50-Day Moving Average:** $391.56
# **200-Day Moving Average:** $416.75
#
# **Recent Trends:**
# Microsoft's stock price has been in a downward trend, with the current price below both short-term (50-day) and long-term (200-day) moving averages. This suggests bearish sentiment and potential challenges in maintaining its recent growth trajectory.
#
# #### **Volatility:**
# The stock exhibits a volatility of **0.245**, indicating moderate price swings in the market. Investors should remain cautious during uncertain periods, especially considering broader economic trends.
#
# #### **Year-to-Date (YTD) Performance:**
# - **YTD Price Change:** -$46.13
# - **YTD Percentage Change:** -11.04%
#
# Microsoft has faced headwinds this year, with a double-digit percentage decline in its stock price. The downward movement reflects either external pressures (e.g., macroeconomic factors like interest rates or inflation) or internal challenges such as competitive pressures or growth slowdown.
#
# ---
#
# ### **II. Financial Highlights**
# #### **Revenue Growth:**
# Microsoft has consistently demonstrated strong revenue growth, driven by its cloud computing division, Azure, and ongoing demand for productivity solutions like Office 365. The company's ability to diversify its revenue streams has been a key factor in its resilience.
#
# #### **Profit Margins:**
# Microsoft boasts high operating and net profit margins, a testament to its efficient operations and pricing power in the industry. However, declining stock prices may indicate investor concerns about future margin pressures or growth sustainability.
#
# #### **Balance Sheet Strength:**
# Microsoft maintains a robust balance sheet with minimal debt and substantial cash reserves. This financial stability positions the company well to weather economic downturns and invest in strategic growth opportunities.
#
# ---
#
# ### **III. Key Factors Impacting Performance**
# 1. **Cloud Computing Growth:**
#    Azure continues to be a major revenue driver, but competition from AWS (Amazon Web Services) and Google Cloud may impact market share and profitability.
#
# 2. **AI Investments:**
#    Microsoft has heavily invested in AI technologies, including its partnership with OpenAI (creator of ChatGPT). While this positions the company for future growth, the financial payoff remains uncertain in the short term.
#
# 3. **Economic Environment:**
#    Rising interest rates and inflationary pressures have impacted the tech sector broadly, causing investors to reassess valuations.
#
# 4. **Gaming Division:**
#    Microsoft's acquisition of Activision Blizzard (pending regulatory approval) could significantly boost its gaming portfolio, but integration risks remain.
#
# ---
#
# ### **IV. Competitive Landscape**
# Microsoft operates in highly competitive markets, facing challenges from:
# - **Technology Giants:** Apple, Google, and Amazon in various domains like cloud, hardware, and software.
# - **Emerging Players:** Startups in AI and cloud computing disrupting traditional business models.
#
# Despite this, Microsoft's diversified portfolio and strong brand loyalty give it a competitive edge.
#
# ---
#
# ### **V. Stock Investment Outlook**
# #### **Short-Term Outlook:**
# Given its recent downward trend and challenges in the broader market, Microsoft may face continued pressure on its stock price. Investors should monitor upcoming earnings reports and macroeconomic indicators for signs of recovery.
#
# #### **Long-Term Outlook:**
# Microsoft's strategic investments in AI, cloud computing, and gaming position it well for future growth. Long-term investors may view the current dip as a potential buying opportunity, assuming confidence in the company's ability to execute its vision.
#
# #### **Risks to Consider:**
# - Macroeconomic uncertainties
# - Competitive pressures in cloud and AI
# - Regulatory hurdles, particularly in acquisitions
#
# ---
#
# ### **VI. Recommendations**
# For current and prospective investors:
# 1. **Monitor Key Metrics:** Focus on revenue growth, profit margins, and updates on AI and cloud computing segments.
# 2. **Diversify Investments:** Consider balancing Microsoft holdings with other tech stocks or sectors to mitigate risks.
# 3. **Evaluate Entry Points:** The stock's recent dip may present an opportunity for long-term investors, but caution is advised given the downward trend.
#
# ---
#
# ### **VII. Conclusion**
# Microsoft remains a dominant force in the technology sector, with strong fundamentals and promising growth avenues. However, recent stock performance signals caution, driven by both market-wide challenges and company-specific factors. Investors should weigh the company's long-term prospects against short-term volatility before making decisions.
#
# **Stock Price Trend Visualization:**
# *(Plot file path: coding/MSFT_stockprice.png)*
#
# ---
#
# For further analysis or updates, please reach out. TERMINATE
