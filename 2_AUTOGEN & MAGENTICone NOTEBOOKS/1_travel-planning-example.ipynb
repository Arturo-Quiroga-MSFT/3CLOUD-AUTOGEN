# %%
#%pip install -U "autogen-agentchat"
#%pip install -U "autogen-agentchat[azure]"
#%pip install -U autogenstudio
# %pip install python-dotenv

# %% [markdown]
# ## Example team of AI Assistant agents in a ROUND ROBIN CHATGROUP team

# %%
from autogen_agentchat.agents import AssistantAgent
from autogen_agentchat.conditions import TextMentionTermination
from autogen_agentchat.teams import RoundRobinGroupChat
from autogen_agentchat.ui import Console
from autogen_ext.models.openai import AzureOpenAIChatCompletionClient
from dotenv import load_dotenv
load_dotenv()
import yaml

# %% [markdown]
# ## load the modelconfig

# %%
with open("model_config.yaml", "r") as f:
        model_config = yaml.safe_load(f)
model_client = AzureOpenAIChatCompletionClient.load_component(model_config)

# %% [markdown]
# ## Define 4 agents  == Planner-agent - Local-agent - Language-agent - Trip-summary-agent

# %%
planner_agent = AssistantAgent(
    "planner_agent",
    model_client=model_client,
    description="A helpful assistant that can plan trips.",
    system_message="You are a helpful assistant that can suggest a travel plan for a user based on their request.",
)

local_agent = AssistantAgent(
    "local_agent",
    model_client=model_client,
    description="A local assistant that can suggest local activities or places to visit.",
    system_message="You are a helpful assistant that can suggest authentic and interesting local activities or places to visit for a user and can utilize any context information provided.",
)

language_agent = AssistantAgent(
    "language_agent",
    model_client=model_client,
    description="A helpful assistant that can provide language tips for a given destination.",
    system_message="You are a helpful assistant that can review travel plans, providing feedback on important/critical tips about how best to address language or communication challenges for the given destination. If the plan already includes language tips, you can mention that the plan is satisfactory, with rationale.",
)

travel_summary_agent = AssistantAgent(
    "travel_summary_agent",
    model_client=model_client,
    description="A helpful assistant that can summarize the travel plan.",
    system_message="You are a helpful assistant that can take in all of the suggestions and advice from the other agents and provide a detailed final travel plan. You must ensure that the final plan is integrated and complete. YOUR FINAL RESPONSE MUST BE THE COMPLETE PLAN. When the plan is complete and all perspectives are integrated, you can respond with TERMINATE.",
)

# %% [markdown]
# ## user question

# %%
termination = TextMentionTermination("TERMINATE")
group_chat = RoundRobinGroupChat(
    [planner_agent, local_agent, language_agent, travel_summary_agent], termination_condition=termination
)
await Console(group_chat.run_stream(task="Plan a 3 day trip to Nepal."))

await model_client.close()
# Out:
# ---------- TextMessage (user) ----------
# Plan a 3 day trip to Nepal.
# ---------- TextMessage (planner_agent) ----------
# Absolutely! Nepal is a breathtaking country with a mix of stunning natural landscapes, rich culture, and majestic Himalayan views. Here’s a 3-day itinerary to help you make the most of your short trip to Nepal.
#
# ---
#
# ### **Day 1: Kathmandu - Cultural Immersion**
# **Morning:**
# - **Arrival in Kathmandu:** Land at Tribhuvan International Airport. Check in to your hotel (choose between Thamel, the tourist hub, or quieter neighborhoods such as Boudhanath).
# - **Visit Swayambhunath (Monkey Temple):** Enjoy panoramic views of Kathmandu Valley as you explore this ancient stupa, adorned with vibrant prayer flags and surrounded by monkeys.
#
# **Afternoon:**
# - **Patan Durbar Square:** Take a short drive to the historic city of Patan, known for its intricate Newari architecture and ancient temples. Explore the Patan Museum for insights into Nepal's history and culture.
#
# **Evening:**
# - **Boudhanath Stupa:** One of the largest spherical stupas in the world, this UNESCO site is a spiritual hub for Tibetan Buddhism. Spend time walking around the stupa, soaking in the tranquil ambiance and colorful butter lamps.
# - **Dinner:** Try Nepali cuisine at a local restaurant—sample dishes like momo (dumplings), dal bhat (lentils and rice), and yak cheese.
#
# ---
#
# ### **Day 2: Nagarkot & Bhaktapur - Scenic Views & Ancient Heritage**
# **Morning:**
# - **Nagarkot Sunrise:** Wake up early and drive to Nagarkot (about 1.5 hours from Kathmandu) to catch the iconic sunrise over the Himalayas, including views of Mount Everest on clear days.
# - **Breakfast in Nagarkot:** Enjoy a meal at a cozy mountain-view café before heading to Bhaktapur.
#
# **Late Morning/Afternoon:**
# - **Explore Bhaktapur Durbar Square:** Wander through the medieval streets of Bhaktapur, a preserved ancient city filled with pagodas, temples, and palaces. Don’t miss the Nyatapola Temple and the stunning pottery square.
# - **Local Lunch:** Relish Bhaktapur’s famous Juju Dhau (king curd) in one of the local eateries.
#
# **Evening:**
# - Return to Kathmandu and take a leisurely evening stroll in Thamel. Shop for souvenirs like pashmina shawls, singing bowls, or trekking gear.
#
# ---
#
# ### **Day 3: Adventure & Relaxation**
# **Morning:**
# - **Pashupatinath Temple:** Start the day by visiting Nepal's holiest Hindu temple dedicated to Lord Shiva alongside the Bagmati River. Observe local rituals and the vibrant culture.
# - **Mini Trek or Adventure Activity:** Depending on your interests, opt for a short trek near Kathmandu (like the Shivapuri National Park hike) or an adventurous activity (paragliding, mountain biking, or a helicopter tour of Mount Everest).
#
# **Afternoon:**
# - **Relaxation:** Treat yourself to a traditional Ayurvedic massage or spa to unwind after your exploration.
# - **Lunch:** Have lunch at a rooftop restaurant in Kathmandu with views over the city.
#
# **Evening:**
# - **Souvenir Shopping & Farewell Dinner:** Spend your final hours shopping for gifts and handicrafts at Asan Bazaar or Thamel. Wrap up your trip with a special farewell dinner featuring live traditional music and dance.
#
# ---
#
# ### **Tips for the Trip:**
# - **Travel Season:** Autumn (September–November) and spring (March–May) are ideal for clear mountain views and pleasant weather.
# - **Packing Essentials:** Bring comfortable walking shoes, layers for cool mornings and evenings, sunscreen, and a hat.
# - **Transportation:** Local taxis or private car rentals work best for short trips. Alternatively, hire a guide to enhance your experience.
#
# Enjoy your unforgettable 3-day adventure in Nepal filled with culture, nature, and relaxation! Would you like recommendations for hotels or specific activities?
# /Users/arturoquiroga/3CLOUD-AUTOGEN/.venv/lib/python3.13/site-packages/autogen_agentchat/agents/_assistant_agent.py:955: UserWarning: Resolved model mismatch: gpt-4o-2024-08-06 != gpt-4o-2024-11-20. Model mapping in autogen_ext.models.openai may be incorrect. Set the model to gpt-4o-2024-11-20 to enhance token/cost estimation and suppress this warning.
#   model_result = await model_client.create(
# ---------- TextMessage (local_agent) ----------
# If you'd like, I can recommend accommodation and add more details for your 3-day itinerary. Or, if you're into a specific activity (trekking, cultural tours, spiritual retreats, etc.), let me know so I can customize your trip further!
# If you'd like, I can recommend accommodation and add more details for your 3-day itinerary. Or, if you're into a specific activity (trekking, cultural tours, spiritual retreats, etc.), let me know so I can customize your trip further!
# ---------- TextMessage (language_agent) ----------
# Your 3-day Nepal itinerary is well-rounded and offers diverse experiences in culture, nature, and adventure. To enhance your trip, let me provide some language and communication tips as Nepal is a multilingual country where Nepali is the official language:
#
# ### **Language Tips:**
# 1. **Key Phrases to Learn in Nepali:**
#    - **Hello**: Namaste
#    - **Thank you**: Dhanyabad
#    - **Excuse me/Sorry**: Maaf garnuhos
#    - **How much does this cost?**: Yo kati ho?
#    - **Where is the bathroom?**: Charpi kaha ho?
#    - **Yes**: Ho / **No**: Hoina
#
# 2. **English is Common in Tourist Areas:**
#    - While Nepali is the primary language, English is widely spoken in Kathmandu, Thamel, and tourist-centric areas. Most signs and menus are also bilingual.
#
# 3. **Communication Challenges in Smaller Towns:**
#    - When visiting places like Bhaktapur or Nagarkot, having a pocket dictionary or a language translation app (such as Google Translate) can help bridge any gap.
#
# 4. **Hiring a Guide:**
#    - Consider hiring a local guide for the cultural and historical sites like Bhaktapur or Pashupatinath. Guides often speak English and provide valuable context about the history and traditions.
#
# 5. **Politeness in Communication:**
#    - Always start any interaction with "Namaste" and a slight bow—it’s a gesture of respect that the locals appreciate. When negotiating prices or asking for favors, politeness goes a long way.
#
# ### **Feedback on the Itinerary:**
# Your itinerary already includes opportunities to engage with locals at cultural sites, markets, and restaurants. Learning basic Nepali phrases and being prepared with translation tools will ensure smooth interactions. If you'd like to add a more immersive experience, consider joining a short cooking or craft workshop to interact with locals in a meaningful way.
#
# Would you like assistance in finding guides or additional communication tools for your trip?
# ---------- TextMessage (travel_summary_agent) ----------
# Here is the finalized comprehensive 3-day travel plan for Nepal, incorporating cultural exploration, scenic beauty, adventure, relaxation, and communication tips. This plan ensures your journey is well-balanced, meaningful, and hassle-free.
#
# ---
#
# ### **Day 1: Kathmandu - Cultural Immersion**
# **Morning:**
# - **Arrival in Kathmandu:** Land at Tribhuvan International Airport, where you’ll be greeted with views of the vibrant city. Arrange an airport transfer to your hotel in Thamel (the tourist hub) or the serene neighborhood near Boudhanath Stupa, depending on your preference.
# - **Visit Swayambhunath (Monkey Temple):** A short drive will take you to this iconic stupa. Explore the area, adorned with prayer wheels, colorful flags, and monkeys, and enjoy panoramic views of Kathmandu Valley.
#
# **Afternoon:**
# - **Patan Durbar Square:** Travel to the historic city of Patan (approx. 30 minutes by car). Admire the traditional Newari architecture and visit the Patan Museum for insights into Newar history, art, and culture.
#
# **Evening:**
# - **Boudhanath Stupa:** Spend your evening walking around the majestic stupa, lighting butter lamps, and interacting with pilgrims. This UNESCO World Heritage site is perfect for soaking in spiritual ambiance.
# - **Dinner:** Head to a local restaurant to enjoy authentic Nepali cuisine such as momo (dumplings), dal bhat (lentils and rice platter), and Newari specialties like chatamari (Nepali pizza).
#
# ---
#
# ### **Day 2: Nagarkot & Bhaktapur - Scenic Views & Ancient Heritage**
# **Early Morning:**
# - **Nagarkot Sunrise:** Make an early start to catch the sunrise over the Himalayas. Distant views of Mount Everest may be visible on clear days. Spend some time enjoying the fresh mountain air.
# - **Breakfast:** Enjoy a hearty breakfast at a scenic mountain café in Nagarkot.
#
# **Late Morning/Afternoon:**
# - **Bhaktapur Durbar Square:** Drive to Bhaktapur, known for its well-preserved medieval architecture. Walk through pottery square, admire Nyatapola Temple, and explore hidden alleyways.
# - **Lunch:** Relish Bhaktapur’s famous “Juju Dhau” (king curd) paired with a traditional meal at a local eatery.
#
# **Evening:**
# - Return to Kathmandu. Explore Thamel’s buzzing streets for souvenirs such as singing bowls, pashmina shawls, and handmade crafts.
#
# ---
#
# ### **Day 3: Adventure & Farewell**
# **Morning:**
# - **Pashupatinath Temple:** Begin your day at this sacred Hindu site where you can observe local rituals and soak up the spiritual energy.
# - **Mini Trek or Adventure Activity:** Depending on your interest:
#    - Opt for a short hike in Shivapuri National Park, which is close to Kathmandu and offers serene natural trails.
#    - Alternatively, try paragliding or take a scenic helicopter tour of Mount Everest for an unforgettable aerial view.
#
# **Afternoon:**
# - **Relaxation:** Treat yourself to a traditional Nepali Ayurvedic spa or massage to unwind after your adventure.
# - **Lunch:** Head to a rooftop restaurant overlooking the city to enjoy contemporary Nepali cuisine.
#
# **Evening:**
# - **Souvenir Shopping:** Visit Asan Bazaar or Thamel to purchase gifts like woodcraft items, Himalayan tea, or trekking gear.
# - **Farewell Dinner:** Wrap up your trip with a special dinner featuring cultural dance performances. Enjoy dishes like kwati (traditional lentil soup) or sel roti (Nepali rice doughnuts).
#
# ---
#
# ### **Tips for the Trip:**
# 1. **Travel Season:** Visit Nepal during spring (March–May) or autumn (September–November) for pleasant weather and clear mountain views.
# 2. **Packing Essentials:** Comfortable shoes, lightweight clothing for the day, layers for cool mornings/evenings, sunscreen, and a reusable water bottle.
# 3. **Local Transportation:** Taxis or private car rentals are recommended for convenience. You can also hire an experienced guide.
# 4. **Language Essentials:**
#    - Learn basic Nepali phrases:
#      - **Namaste** (Hello)
#      - **Dhanyabad** (Thank you)
#      - **Maaf garnuhos** (Sorry/Excuse me)
#    - English is widely spoken in tourist areas, but a translation app may be useful in Bhaktapur or Nagarkot.
# 5. **Cultural Etiquette:** Always greet locals with “Namaste,” avoid touching items with your feet, and dress modestly at religious sites.
#
# ---
#
# ### **Optional Add-Ons:**
# - **Workshop:** If you’d like a more immersive experience, join a short cooking class or try pottery in Bhaktapur.
# - **Accommodation Suggestions:**
#    - **Kathmandu:** Hotel Shambala or Hyatt Regency for luxury stays; Thamel Guest House for budget-friendly options.
#    - **Nagarkot:** Club Himalaya or Hotel View Point for comfortable stays with stunning vistas.
#
# Nepal awaits with its rich culture, spiritual energy, and natural beauty. Enjoy this 3-day trip packed with unique experiences and memorable moments!
#
# TERMINATE
