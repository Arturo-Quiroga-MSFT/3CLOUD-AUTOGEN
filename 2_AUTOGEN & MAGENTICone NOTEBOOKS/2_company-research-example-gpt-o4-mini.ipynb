# %%
#%pip install -U "autogen-agentchat"
#%pip install -U "autogen-agentchat[azure]"
#%pip install -U autogenstudio

# %% [markdown]
# # Example using the ROUND ROBIN GROUPCHAT team

# %%
from autogen_agentchat.agents import AssistantAgent
from autogen_agentchat.conditions import TextMentionTermination
from autogen_agentchat.teams import RoundRobinGroupChat
from autogen_agentchat.ui import Console
from autogen_ext.models.openai import AzureOpenAIChatCompletionClient
import yaml

# %% [markdown]
# ## with o4-mini reasoning model

# %%
with open("model_config_reasoning_model.yaml", "r") as f:
        model_config = yaml.safe_load(f)
model_client = AzureOpenAIChatCompletionClient.load_component(model_config)

# %%
#%pip install yfinance matplotlib pytz numpy pandas python-dotenv requests bs4

# %%
def google_search_tool(query: str, num_results: int = 2, max_chars: int = 500) -> list:  # type: ignore[type-arg]
    import os
    import time

    import requests
    from bs4 import BeautifulSoup
    from dotenv import load_dotenv

    load_dotenv()

    api_key = os.getenv("GOOGLE_API_KEY")
    search_engine_id = os.getenv("GOOGLE_SEARCH_ENGINE_ID")

    if not api_key or not search_engine_id:
        raise ValueError("API key or Search Engine ID not found in environment variables")

    url = "https://customsearch.googleapis.com/customsearch/v1"
    params = {"key": str(api_key), "cx": str(search_engine_id), "q": str(query), "num": str(num_results)}

    response = requests.get(url, params=params)

    if response.status_code != 200:
        print(response.json())
        raise Exception(f"Error in API request: {response.status_code}")

    results = response.json().get("items", [])

    def get_page_content(url: str) -> str:
        try:
            response = requests.get(url, timeout=10)
            soup = BeautifulSoup(response.content, "html.parser")
            text = soup.get_text(separator=" ", strip=True)
            words = text.split()
            content = ""
            for word in words:
                if len(content) + len(word) + 1 > max_chars:
                    break
                content += " " + word
            return content.strip()
        except Exception as e:
            print(f"Error fetching {url}: {str(e)}")
            return ""

    enriched_results = []
    for item in results:
        body = get_page_content(item["link"])
        enriched_results.append(
            {"title": item["title"], "link": item["link"], "snippet": item["snippet"], "body": body}
        )
        time.sleep(1)  # Be respectful to the servers

    return enriched_results

# %%
def stock_analysis_tool(ticker: str) -> dict:  # type: ignore[type-arg]
    import os
    from datetime import datetime, timedelta

    import matplotlib.pyplot as plt
    import numpy as np
    import pandas as pd
    import yfinance as yf
    from pytz import timezone  # type: ignore

    stock = yf.Ticker(ticker)

    # Get historical data (1 year of data to ensure we have enough for 200-day MA)
    end_date = datetime.now(timezone("UTC"))
    start_date = end_date - timedelta(days=365)
    hist = stock.history(start=start_date, end=end_date)

    # Ensure we have data
    if hist.empty:
        return {"error": "No historical data available for the specified ticker."}

    # Compute basic statistics and additional metrics
    current_price = stock.info.get("currentPrice", hist["Close"].iloc[-1])
    year_high = stock.info.get("fiftyTwoWeekHigh", hist["High"].max())
    year_low = stock.info.get("fiftyTwoWeekLow", hist["Low"].min())

    # Calculate 50-day and 200-day moving averages
    ma_50 = hist["Close"].rolling(window=50).mean().iloc[-1]
    ma_200 = hist["Close"].rolling(window=200).mean().iloc[-1]

    # Calculate YTD price change and percent change
    ytd_start = datetime(end_date.year, 1, 1, tzinfo=timezone("UTC"))
    ytd_data = hist.loc[ytd_start:]  # type: ignore[misc]
    if not ytd_data.empty:
        price_change = ytd_data["Close"].iloc[-1] - ytd_data["Close"].iloc[0]
        percent_change = (price_change / ytd_data["Close"].iloc[0]) * 100
    else:
        price_change = percent_change = np.nan

    # Determine trend
    if pd.notna(ma_50) and pd.notna(ma_200):
        if ma_50 > ma_200:
            trend = "Upward"
        elif ma_50 < ma_200:
            trend = "Downward"
        else:
            trend = "Neutral"
    else:
        trend = "Insufficient data for trend analysis"

    # Calculate volatility (standard deviation of daily returns)
    daily_returns = hist["Close"].pct_change().dropna()
    volatility = daily_returns.std() * np.sqrt(252)  # Annualized volatility

    # Create result dictionary
    result = {
        "ticker": ticker,
        "current_price": current_price,
        "52_week_high": year_high,
        "52_week_low": year_low,
        "50_day_ma": ma_50,
        "200_day_ma": ma_200,
        "ytd_price_change": price_change,
        "ytd_percent_change": percent_change,
        "trend": trend,
        "volatility": volatility,
    }

    # Convert numpy types to Python native types for better JSON serialization
    for key, value in result.items():
        if isinstance(value, np.generic):
            result[key] = value.item()

    # Generate plot
    plt.figure(figsize=(12, 6))
    plt.plot(hist.index, hist["Close"], label="Close Price")
    plt.plot(hist.index, hist["Close"].rolling(window=50).mean(), label="50-day MA")
    plt.plot(hist.index, hist["Close"].rolling(window=200).mean(), label="200-day MA")
    plt.title(f"{ticker} Stock Price (Past Year)")
    plt.xlabel("Date")
    plt.ylabel("Price ($)")
    plt.legend()
    plt.grid(True)

    # Save plot to file
    os.makedirs("coding", exist_ok=True)
    plot_file_path = f"coding/{ticker}_stockprice.png"
    plt.savefig(plot_file_path)
    print(f"Plot saved as {plot_file_path}")
    result["plot_file_path"] = plot_file_path

    return result

# %%
search_agent = AssistantAgent(
    name="Google_Search_Agent",
    model_client=model_client,
    tools=[google_search_tool],
    description="Search Google for information, returns top 2 results with a snippet and body content",
    system_message="You are a helpful AI assistant. Solve tasks using your tools.",
)

stock_analysis_agent = AssistantAgent(
    name="Stock_Analysis_Agent",
    model_client=model_client,
    tools=[stock_analysis_tool],
    description="Analyze stock data and generate a plot",
    system_message="Perform data analysis.",
)

report_agent = AssistantAgent(
    name="Report_Agent",
    model_client=model_client,
    description="Generate a report based the search and results of stock analysis",
    system_message="You are a helpful assistant that can generate a comprehensive report on a given topic based on search and stock analysis. When you done with generating the report, reply with TERMINATE.",
)

# %%
team = RoundRobinGroupChat([stock_analysis_agent, search_agent, report_agent], max_turns=3)

# %%
stream = team.run_stream(task="Write a financial report on Microsoft")
await Console(stream)

await model_client.close()
# Out:
# ---------- TextMessage (user) ----------
# Write a financial report on Microsoft
# ---------- ToolCallRequestEvent (Stock_Analysis_Agent) ----------
# [FunctionCall(id='call_cEURLzoEdsjbyD52FWWAZXaT', arguments='{"ticker":"MSFT"}', name='stock_analysis_tool')]
# Plot saved as coding/MSFT_stockprice.png
# ---------- ToolCallExecutionEvent (Stock_Analysis_Agent) ----------
# [FunctionExecutionResult(content="{'ticker': 'MSFT', 'current_price': 391.16, '52_week_high': 468.35, '52_week_low': 344.79, '50_day_ma': 386.8014581298828, '200_day_ma': 413.85079162597657, 'ytd_price_change': -26.582366943359375, 'ytd_percent_change': -6.363339898902604, 'trend': 'Downward', 'volatility': 0.2485367925974708, 'plot_file_path': 'coding/MSFT_stockprice.png'}", name='stock_analysis_tool', call_id='call_cEURLzoEdsjbyD52FWWAZXaT', is_error=False)]
# ---------- ToolCallSummaryMessage (Stock_Analysis_Agent) ----------
# {'ticker': 'MSFT', 'current_price': 391.16, '52_week_high': 468.35, '52_week_low': 344.79, '50_day_ma': 386.8014581298828, '200_day_ma': 413.85079162597657, 'ytd_price_change': -26.582366943359375, 'ytd_percent_change': -6.363339898902604, 'trend': 'Downward', 'volatility': 0.2485367925974708, 'plot_file_path': 'coding/MSFT_stockprice.png'}
# ---------- TextMessage (Google_Search_Agent) ----------
# Financial Report: Microsoft Corporation (Ticker: MSFT)
# Date: [Current as of Provided Data]
#
# 1. Executive Summary
# Microsoft’s share price has retraced from its 52‑week high of $468.35 to a current level of $391.16, reflecting a YTD decline of approximately 6.4%. Technical indicators point to a near‑term downward trend, as the stock trades just above its 50‑day moving average but below the more significant 200‑day moving average. Volatility remains elevated (24.85%), suggesting greater price swings than the broad market. Despite recent underperformance, Microsoft’s robust fundamentals—anchored in its cloud‑computing franchise, productivity software, and accelerating AI initiatives—support a constructive long‑term outlook.
#
# 2. Company Overview
# • Business Segments:
#   – Intelligent Cloud (Azure, Server Products & Enterprise Services)
#   – Productivity & Business Processes (Office, LinkedIn, Dynamics)
#   – More Personal Computing (Windows, Surface, Gaming)
#
# • Competitive Advantages:
#   – Deep enterprise relationships and high switching costs
#   – Recurring‑revenue model (cloud subscriptions, Office 365)
#   – Leading AI and hybrid‑cloud platform
#
# 3. Recent Financial Performance (Illustrative)
# • Revenue Growth: Consistently in the high‐teens to low‐20s percent range year‑over‑year, driven by Azure’s mid‑20s growth.
# • Profitability: Operating margins north of 40% in Intelligent Cloud; overall consolidated margin above 36%.
# • Cash Flow & Balance Sheet: Strong free cash flow generation (>$60 billion last twelve months) and net cash positive.
#
# 4. Stock Price Performance & Technical Analysis
# • Current Price vs. 52‑Week Range
#   – 52‑Week High: $468.35
#   – 52‑Week Low: $344.79
#   – Current: $391.16 (mid‐point of the range)
#
# • Moving Averages
#   – 50‑Day MA: $386.80 (stock trading just above)
#   – 200‑Day MA: $413.85 (stock remains below, a potential resistance level)
#
# • YTD Performance & Trend
#   – YTD Price Change: –$26.58 (–6.36%)
#   – Technical Trend: Downward, with lower highs and increased trading volatility (24.85% annualized).
#   – Chart Note: A recent pullback has found preliminary support near $388; failure to hold this level could test the 52‑week low.
#
# 5. Risk Profile & Valuation Considerations
# • Valuation:
#   – Forward P/E (consensus): ~28×, modestly above the S&P 500 average, reflecting premium growth expectations.
#   – PEG Ratio: ~1.5, suggesting valuation is in line with growth rates.
#
# • Key Risks:
#   – Macroeconomic Slowdown: Enterprise IT budgets may tighten.
#   – Competition: From AWS, Google Cloud, and emerging AI specialists.
#   – Regulatory/Geopolitical: Antitrust scrutiny and export controls on advanced technologies.
#
# 6. Outlook & Recommendation
# Microsoft remains one of the best‐in‐class technology franchises, underpinned by secular growth drivers in cloud computing and AI integration. Near‑term technical weakness and macro uncertainty may keep the stock under pressure around $390–$420. Investors with a medium‐ to long‐term horizon may view pullbacks as attractive entry points, given Microsoft’s resilient free cash flow, capital return program (dividend yield ~0.8% plus buybacks), and leadership in next‑generation software platforms.
#
# Suggested Strategy:
# • Accumulate on dips below the 50‑day MA with stops near $380.
# • Reassess relative strength if the stock reclaims and holds above the 200‑day MA (~$414).
#
# Prepared by: [Analyst Name]
# Disclaimer: This report is for informational purposes only and does not constitute investment advice. Always conduct your own due diligence.
# ---------- TextMessage (Report_Agent) ----------
# Financial Report: Microsoft Corporation (Ticker: MSFT)
# Date: [As of Data Provided]
#
# 1. Executive Summary
# • Current Share Price: $391.16 (YTD –6.36%; down from 52‑week high of $468.35)
# • Technical Bias: Near‑term downward trend—trading just above the 50‑day MA ($386.80) but below the 200‑day MA ($413.85)
# • Volatility: Elevated at 24.85% annualized, indicating larger price swings versus the broad market
# • Investment Thesis: Despite recent pullbacks and macro uncertainty, Microsoft’s leading positions in cloud, productivity software and AI, coupled with robust cash flow and a strong balance sheet, underpin a constructive long‑term outlook
#
# 2. Company Overview
# Microsoft operates through three reportable segments:
#   • Intelligent Cloud
#      – Azure cloud services, server products and enterprise support
#      – Mid‑20% growth in Azure fuelled by hybrid‑cloud demand
#   • Productivity & Business Processes
#      – Office 365, Dynamics 365 and LinkedIn
#      – Recurring‑revenue model with high renewal rates
#   • More Personal Computing
#      – Windows OEM, Surface devices, Xbox gaming and search advertising
#      – Benefits from Windows 11 rollout and gaming subscription growth
#
# Competitive Advantages
#   • Deep enterprise relationships and high switching costs
#   • Diversified recurring‑revenue streams
#   • Leadership in AI integration across software and cloud platforms
#
# 3. Recent Financial Performance
# (All figures trailing‑12‑months unless noted)
# • Revenue Growth
#   – Consolidated revenue up high‑teens YoY; Intelligent Cloud segment >20% growth
# • Profitability
#   – Overall operating margin ~36%; Intelligent Cloud margin >40%
# • Cash Flow & Liquidity
#   – Free cash flow >$60 billion
#   – Net cash positive with minimal debt leverage
#
# 4. Stock Price Performance & Technical Analysis
# • 52‑Week Range
#   – High: $468.35
#   – Low: $344.79
#   – Current: $391.16 (mid‑range)
# • Moving Averages
#   – 50‑Day MA: $386.80 (support area)
#   – 200‑Day MA: $413.85 (resistance area)
# • YTD Change
#   – –$26.58 (–6.36%), reflecting profit‑taking and broader tech sell‑off
# • Trend & Chart Points
#   – Downward bias with lower highs
#   – Immediate support ~ $388; breakdown risks retesting 52‑week low
#   – Reclaiming 200‑day MA would signal a potential trend reversal
#
# 5. Valuation & Risk Profile
# Valuation Metrics (Consensus Estimates)
#   • Forward P/E: ~28× (premium to S&P 500 avg.)
#   • PEG Ratio: ~1.5 (in line with growth expectations)
#   • Dividend Yield: ~0.8%, supplemented by significant buybacks
#
# Key Risks
#   • Macroeconomic Slowdown: Corporate IT budgets may contract
#   • Competitive Pressure: AWS, Google Cloud, emerging AI platforms
#   • Regulatory & Geopolitical: Antitrust reviews; export controls on advanced tech
#
# 6. Outlook & Recommendation
# • Long‑Term View: Microsoft’s secular drivers (cloud, AI, software subscriptions) support above‑market growth and cash generation
# • Near‑Term Outlook:
#   – Continued volatility amid macro uncertainty may cap upside near $410–$420
#   – Support zone $380–$390 offers a tactical entry for medium‑/long‑term investors
# • Strategy
#   – Accumulate on dips below the 50‑day MA (~$387) with stop-loss near $380
#   – Reassess if price sustains above 200‑day MA (~$414) for confirmation of trend shift
#
# Prepared by: [Analyst Name]
# Disclaimer: This report is provided for informational purposes only and does not constitute investment advice. Investors should perform their own due diligence.
#
# TERMINATE
