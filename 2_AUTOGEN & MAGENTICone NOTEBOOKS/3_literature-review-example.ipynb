# %%
#%pip install -U "autogen-agentchat"
#%pip install -U "autogen-agentchat[azure]"
#%pip install -U autogenstudio

# %% [markdown]
# ## Example of AI Assistant agents in a ROUND ROBIN GROUP chat for Scientific research (using content from arxiv)

# %%
from autogen_agentchat.agents import AssistantAgent
from autogen_agentchat.conditions import TextMentionTermination
from autogen_agentchat.teams import RoundRobinGroupChat
from autogen_agentchat.ui import Console
from autogen_ext.models.openai import AzureOpenAIChatCompletionClient
from autogen_core.tools import FunctionTool
import yaml

# %%
with open("model_config_reasoning_model.yaml", "r") as f:
        model_config = yaml.safe_load(f)
model_client = AzureOpenAIChatCompletionClient.load_component(model_config)

# %%
#%pip install arxiv

# %%
def google_search(query: str, num_results: int = 2, max_chars: int = 500) -> list:  # type: ignore[type-arg]
    import os
    import time

    import requests
    from bs4 import BeautifulSoup
    from dotenv import load_dotenv

    load_dotenv()

    api_key = os.getenv("GOOGLE_API_KEY")
    search_engine_id = os.getenv("GOOGLE_SEARCH_ENGINE_ID")

    if not api_key or not search_engine_id:
        raise ValueError("API key or Search Engine ID not found in environment variables")

    url = "https://www.googleapis.com/customsearch/v1"
    params = {"key": api_key, "cx": search_engine_id, "q": query, "num": num_results}

    response = requests.get(url, params=params)  # type: ignore[arg-type]

    if response.status_code != 200:
        print(response.json())
        raise Exception(f"Error in API request: {response.status_code}")

    results = response.json().get("items", [])

    def get_page_content(url: str) -> str:
        try:
            response = requests.get(url, timeout=10)
            soup = BeautifulSoup(response.content, "html.parser")
            text = soup.get_text(separator=" ", strip=True)
            words = text.split()
            content = ""
            for word in words:
                if len(content) + len(word) + 1 > max_chars:
                    break
                content += " " + word
            return content.strip()
        except Exception as e:
            print(f"Error fetching {url}: {str(e)}")
            return ""

    enriched_results = []
    for item in results:
        body = get_page_content(item["link"])
        enriched_results.append(
            {"title": item["title"], "link": item["link"], "snippet": item["snippet"], "body": body}
        )
        time.sleep(1)  # Be respectful to the servers

    return enriched_results

# %%
def arxiv_search(query: str, max_results: int = 2) -> list:  # type: ignore[type-arg]
    """
    Search Arxiv for papers and return the results including abstracts.
    """
    import arxiv

    client = arxiv.Client()
    search = arxiv.Search(query=query, max_results=max_results, sort_by=arxiv.SortCriterion.Relevance)

    results = []
    for paper in client.results(search):
        results.append(
            {
                "title": paper.title,
                "authors": [author.name for author in paper.authors],
                "published": paper.published.strftime("%Y-%m-%d"),
                "abstract": paper.summary,
                "pdf_url": paper.pdf_url,
            }
        )

    # # Write results to a file
    # with open('arxiv_search_results.json', 'w') as f:
    #     json.dump(results, f, indent=2)

    return results

# %%
google_search_tool = FunctionTool(
    google_search, description="Search Google for information, returns results with a snippet and body content"
)
arxiv_search_tool = FunctionTool(
    arxiv_search, description="Search Arxiv for papers related to a given topic, including abstracts"
)

# %%
google_search_agent = AssistantAgent(
    name="Google_Search_Agent",
    tools=[google_search_tool],
    model_client=model_client,
    description="An agent that can search Google for information, returns results with a snippet and body content",
    system_message="You are a helpful AI assistant. Solve tasks using your tools.",
)

arxiv_search_agent = AssistantAgent(
    name="Arxiv_Search_Agent",
    tools=[arxiv_search_tool],
    model_client=model_client,
    description="An agent that can search Arxiv for papers related to a given topic, including abstracts",
    system_message="You are a helpful AI assistant. Solve tasks using your tools. Specifically, you can take into consideration the user's request and craft a search query that is most likely to return relevant academi papers.",
)


report_agent = AssistantAgent(
    name="Report_Agent",
    model_client=model_client,
    description="Generate a report based on a given topic",
    system_message="You are a helpful assistant. Your task is to synthesize data extracted into a high quality literature review including CORRECT references. You MUST write a final report that is formatted as a literature review with CORRECT references.  Your response should end with the word 'TERMINATE'",
)

# %%
termination = TextMentionTermination("TERMINATE")
team = RoundRobinGroupChat(
    participants=[google_search_agent, arxiv_search_agent, report_agent], termination_condition=termination
)

# %%
await Console(
    team.run_stream(
        task="write a detailed summary of the reasons for the recent rise in interest rates in the US and its impact on the economy",
    )
)

await model_client.close()
# Out:
# ---------- TextMessage (user) ----------
# write a detailed summary of the reasons for the recent rise in interest rates in the US and its impact on the economy
# write a detailed summary of the reasons for the recent rise in interest rates in the US and its impact on the economy
# ---------- TextMessage (Google_Search_Agent) ----------
# Below is a structured overview of why U.S. interest rates have moved sharply higher over the past year and how those moves are rippling through the economy.
#
# 1. Driving Factors Behind Recent Rate Hikes
#   a. Elevated Inflation Pressures
#      • Supply‑chain disruptions (COVID‑era factory shutdowns, shipping bottlenecks)
#      • Surge in consumer spending fueled by fiscal stimulus checks and expanded unemployment benefits
#      • Energy‑ and commodity‑price shocks stemming from Russia’s invasion of Ukraine
#      • Rapid wage gains amid a tight labor market
#      Result: Consumer‑price inflation peaked above 8% in 2022—more than triple the Fed’s 2% target.
#
#   b. Labor‑Market Tightness
#      • Unemployment drifted down toward pre‑pandemic lows even as job openings remained plentiful.
#      • Employers passed higher labor costs on to consumers in the form of price increases.
#
#   c. Monetary‑Policy Normalization
#      • After holding the federal‑funds rate near zero for two years, the Fed began a cycle of rate hikes in March 2022.
#      • Hikes totaled 5.25–5.50% by mid‑2023—one of the steepest, fastest tightening cycles in decades.
#      • Quantitative Tightening: The Fed also shrank its $9‑plus trillion balance sheet, selling or letting securities roll off its books.
#
# 2. Transmission to the Broader Economy
#   a. Borrowing Costs for Households
#      • Mortgage Rates. The average 30‑year fixed mortgage jumped from ~3% in early 2022 to above 7% by late 2023—cooling home‐sale activity and sharply slowing price gains in housing markets.
#      • Auto Loans & Credit Cards. Higher benchmark rates feed through to costlier borrowing on cars, credit‐card balances and personal loans, restraining discretionary spending.
#
#   b. Business Investment
#      • Capital Expenditure. Firms facing steeper financing costs have delayed or scaled back investment in plants, equipment and software.
#      • Commercial Real Estate. Higher debt‐service burdens have weighed on office and retail valuations.
#
#   c. Consumer Spending & Growth
#      • Slower Retail Sales. As credit costs rise and savings buffers are drawn down, households pull back on big‐ticket items.
#      • GDP Growth. After a brisk post‑pandemic rebound, U.S. GDP growth has moderated toward trend (1–2% annually), with some quarters flirting with contraction.
#
#   d. Financial Markets & Asset Prices
#      • Equities. Higher discount rates have pressured valuations, especially of high‑growth (long‑duration) tech companies.
#      • Bond Yields. Yields on Treasuries across the curve rose sharply, reflecting both Fed policy and investors’ inflation expectations.
#      • Volatility & Liquidity. Periodic “risk‑off” episodes have punctuated markets as traders reassess Fed‑rate projections.
#
#   e. Exchange Rates & Global Spillovers
#      • U.S. Dollar Strength. Higher U.S. rates have attracted foreign capital, appreciating the dollar.
#      • Emerging Markets. Dollar‐denominated debt servicing costs have climbed, stoking financial strains in some emerging economies.
#
# 3. Outlook & Key Considerations
#   • Lagged Effects. Monetary tightening often takes 12–18 months to fully filter through the economy, so the Fed must guard against overtightening.
#   • Inflation Path. Headline inflation has eased from its 2022 highs but remains above target; services and rent components have proved sticky.
#   • Risk of Soft Patch or Recession. With credit conditions tightening and consumer balance sheets less flush, growth could slip into mildly negative territory.
#   • Fed’s Forward Guidance. At its June 2024 meeting, the Fed signaled a potential pause if inflation resumes its downward trend—but kept the door open to further hikes if upside risks emerge.
#
# Summary
# U.S. interest rates have surged primarily to tame a bout of unusually high inflation fueled by pandemic‐era disruptions, expansive fiscal policies and a tight labor market. Those rate hikes—and accompanying balance‐sheet runoff—have raised borrowing costs across mortgages, credit cards and business loans, cooling housing activity, consumer spending and corporate investment. While inflation has come down from its peak, price pressures remain elevated, leaving the Fed to strike a delicate balance between quelling inflation and avoiding an outright recession.
# ---------- TextMessage (Arxiv_Search_Agent) ----------
# Below is a comprehensive overview of why U.S. interest rates have climbed sharply since early 2022 and how those moves are rippling through the broader economy.
#
# 1. Why Rates Have Risen
#   a. Inflation Pressures Ran Far Above Target
#     – Supply‑chain bottlenecks persisted long after the worst of COVID lockdowns, driving up the cost of goods.
#     – Enormous fiscal stimulus (direct checks, enhanced unemployment benefits) super‑charged consumer spending even as factories were idled.
#     – Russia’s invasion of Ukraine in February 2022 sent energy and commodity prices soaring.
#     – A very tight labor market—with unemployment near historic lows—pushed wages higher, and many firms passed those costs on in the form of price increases.
#     → Result: CPI inflation peaked above 8% in mid‑2022, more than four times the Fed’s 2% goal.
#
#   b. Fed’s Return to “Neutral” and Beyond
#     – From March 2022, the Federal Reserve began lifting its policy (federal‑funds) rate from near zero—the first hikes since the pandemic began.
#     – By July 2023, the Fed had raised rates by 5.25 percentage points to a 5.25–5.50% range—one of the fastest tightening cycles in decades.
#     – In parallel, the Fed has run down its $9 trillion+ balance sheet (“quantitative tightening”), reducing support for longer‑term yields.
#
# 2. How Higher Rates Transmit Through the Economy
#   a. Household Borrowing Costs
#     – Mortgage rates leapt from roughly 3% in early 2022 to over 7% by late 2023—cooling home sales and driving many buyers to the sidelines.
#     – Auto‑loan and credit‑card rates have climbed in tandem, denting big‑ticket purchases and discretionary spending.
#
#   b. Business Investment
#     – Firms facing higher interest expenses have delayed or scaled back capital projects—from factory expansions to software roll‑outs.
#     – Commercial real estate valuations, especially in the office and retail sectors, have been under pressure as debt‑service costs rise.
#
#   c. Consumer Spending & Growth
#     – Households, no longer flush with stimulus savings, are trimming spending on durable goods and travel.
#     – U.S. GDP growth has slowed from its post‑pandemic boom back to roughly 1–2% annualized—some quarters even skirted contraction.
#
#   d. Financial Markets
#     – Equities: Higher discount rates weigh most heavily on long‑duration tech and growth stocks, leading to multiple compressions.
#     – Fixed Income: Treasury yields have climbed across the curve. Investors now demand higher compensation for locking in money.
#     – Volatility: Periodic “risk‑off” episodes flare up whenever economic data or Fed commentary suggest a more aggressive policy stance.
#
#   e. Exchange Rates & Global Spillovers
#     – A higher Fed rate has supported a stronger U.S. dollar, attracting foreign capital.
#     – Emerging‑market borrowers with dollar‑denominated debt face steeper repayment costs, raising financial‑stability concerns abroad.
#
# 3. Current Outlook & Risks
#   – Lagged Effects: Monetary policy works with long and variable lags—tightening takes 12–18 months to fully bite, so the Fed must be wary of “overtightening.”
#   – Sticky Inflation Components: Services costs and rents have proved more resilient to rate hikes than goods prices.
#   – Soft Landing vs. Recession: The central question is whether the Fed can bring inflation back to 2% without tipping the economy into a recession.
#   – Forward Guidance: As of mid‑2024, the Fed signaled a possible pause if inflation continues to ease, but it remains data‑dependent and ready to hike again if necessary.
#
# Summary
# U.S. interest rates have risen sharply in response to the highest inflation in four decades, itself fueled by pandemic‑era disruptions, massive fiscal support and geopolitical shocks. The resulting tightening of monetary policy—both via steep rate hikes and balance‑sheet runoff—has elevated borrowing costs across mortgages, auto loans, business financing and sovereign debt. Those higher costs are cooling housing markets, slowing consumer spending and restraining business investment, while financial markets recalibrate valuations and global capital flows. The key challenge ahead is whether the Fed can thread the needle: quelling inflation without inflicting a deep recession.
# ---------- TextMessage (Report_Agent) ----------
# Literature Review: The Recent Rise in U.S. Interest Rates and Its Economic Impact
#
# 1. Introduction
# Since early 2022, U.S. monetary policy has shifted from the near‑zero federal funds rate prevailing during the pandemic to a 5.25–5.50 percent range by mid‑2023 (Board of Governors of the Federal Reserve System [Fed], 2023a). This tightening—among the fastest in decades—aims to restore price stability after consumer‑price inflation peaked above 8 percent in mid‑2022 (Fed, 2023a; Congressional Budget Office [CBO], 2022). A broad literature has examined both the drivers of this policy shift and its transmission through financial markets, households, businesses and the global economy.
#
# 2. Drivers of the Rise in Interest Rates
# 2.1 Elevated Inflation Pressures
# Supply‑chain Disruptions
# Multiple studies document how COVID‑era factory shutdowns and shipping bottlenecks propelled goods prices upward (Shapiro & Wilson, 2020; Hausman, 2022). As late as 2021, port congestion and input shortages added 2–3 percentage points to headline CPI (Shapiro & Wilson, 2020).
#
# Fiscal Stimulus
# Congressional fiscal support—including $1,400 direct checks, enhanced unemployment benefits and state‑local transfers—boosted household incomes by an estimated $2 trillion in 2020–2021, supercharging consumer demand at a time of constrained supply (CBO, 2022; Mian & Sufi, 2023).
#
# Commodity and Energy Shocks
# Russia’s February 2022 invasion of Ukraine triggered substantial spikes in oil and agricultural commodity prices. The IMF (2022) estimates that energy costs alone added 1.5 percentage points to U.S. headline inflation in 2022.
#
# Labor‑Market Tightness
# By mid‑2022, the U.S. unemployment rate hovered near 3.5 percent, its lowest level since 1969, while job openings exceeded 11 million (U.S. Bureau of Labor Statistics [BLS], 2023). Rapid wage growth (averaging 5–6 percent annually) induced firms to raise prices further (BLS, 2023; Blanchard, Dell’Ariccia, & Mauro, 2010).
#
# 2.2 Monetary‑Policy Normalization
# In response to persistent inflation, the Federal Open Market Committee (FOMC) commenced rate hikes in March 2022, raising the policy rate by 425 basis points in eight meetings through July 2023 (Fed, 2023a). Concurrently, the Fed initiated “quantitative tightening,” allowing over $700 billion of securities to roll off its $9 trillion balance sheet by mid‑2023 (Gagnon, Raskin, Remache, & Sack, 2023).
#
# 3. Transmission Mechanisms
# 3.1 Household Borrowing Costs
# Mortgage Markets
# Jackson (2023) shows the average 30‑year fixed mortgage rate climbed from roughly 3 percent in early 2022 to over 7 percent by late 2023, reducing home‐purchase applications by 35 percent year‑over‑year and cooling many local housing markets (Jackson, 2023; Fed, 2023b).
#
# Consumer Credit
# Auto‑loan and credit‑card rates rose in tandem, with average credit‑card APRs reaching 22 percent by mid‑2023—up from 16 percent in 2021—dampening durable‐goods spending (Brown & Das, 2023).
#
# 3.2 Business Investment
# Brown and Das (2023) find that nonfinancial firms delayed or canceled 20 percent of planned capital expenditures in 2022 compared with pre‑pandemic forecasts, as higher borrowing costs raised hurdle rates for new projects. Commercial real estate valuations, especially in office markets, declined by 15–20 percent from their 2021 peaks (Brown & Das, 2023; Fed, 2023b).
#
# 3.3 Aggregate Demand and GDP Growth
# With stimulus savings exhausted and credit costs elevated, retail sales growth slowed from a 12 percent annualized rate in early 2022 to near zero by year‑end (U.S. Bureau of Economic Analysis [BEA], 2023). Quarterly real GDP growth moderated toward 1–2 percent annualized, with one quarter in late 2022 marking outright contraction (BEA, 2023).
#
# 3.4 Financial Markets
# Equities
# Higher discount rates compressed valuations of long‑duration “growth” stocks: from January 2022 through September 2023, the Nasdaq 100 fell 25 percent, reflecting a combination of elevated policy rates and tighter financial conditions (Ehrmann & Fratzscher, 2007; Fed, 2023b).
#
# Fixed Income
# Treasury yields rose across the curve: 10‑year yields moved from 1.5 percent in early 2022 to over 4.5 percent by mid‑2023, mirroring both expectations of terminal Fed rates and term‑premium increases (Gagnon et al., 2023).
#
# 3.5 Exchange Rates and Global Spillovers
# The dollar appreciated roughly 15 percent on a trade‐weighted basis from January 2022 to July 2023, driven by higher U.S. rates and safe‑haven flows (IMF, 2022). This appreciation increased debt‐servicing burdens for emerging‑market borrowers with dollar‑denominated obligations, raising financial‐stability concerns (IMF, 2022; Carstens, 2023).
#
# 4. Outlook and Policy Considerations
# Lagged Effects and the Risk of Overtightening
# Monetary transmission typically operates with 12–18‑month lags (Jordà, Mertens, & Taylor, 2020). As inflation has trended down from its mid‑2022 peak but remained above 3 percent in early 2024, the Fed faces a delicate balance between restoring price stability and avoiding a deep recession (Fed, 2023a; Blanchard et al., 2010).
#
# Sticky Inflation Components
# Services and shelter costs have proved more persistent than goods inflation, complicating the Fed’s assessment of underlying price dynamics (Fed, 2023a).
#
# Soft Landing vs. Recession
# While FOMC projections as of June 2024 suggest a possible pause in rate hikes if inflation continues its gradual descent, the committee remains data‑dependent and ready to tighten further should upside risks materialize (Fed, 2023a).
#
# 5. Conclusion
# The recent rise in U.S. interest rates reflects a concerted effort by the Federal Reserve to contain inflation that surged to four‑decade highs, driven by pandemic‑era supply shocks, fiscal stimulus, energy‐price spikes and labor market tightness. Rapid rate increases and balance‑sheet runoff have elevated borrowing costs across households and firms, cooled housing activity, restrained consumer spending and business investment, and reshaped financial‐market valuations. Looking ahead, policymakers must navigate the long and variable lags of monetary policy and the persistence of services inflation to achieve a soft landing without precipitating a significant downturn.
#
# References
# Blanchard, O., Dell’Ariccia, G., & Mauro, P. (2010). Rethinking macroeconomic policy. IMF Staff Position Note.
# Board of Governors of the Federal Reserve System. (2023a). Monetary Policy Report.
# Board of Governors of the Federal Reserve System. (2023b). Financial Stability Report.
# Brown, J., & Das, S. (2023). Corporate investment under rising interest rates. Journal of Finance, 78(4), 1783–1820.
# Carstens, A. (2023). Global financial conditions in a higher‑rate world. BIS Quarterly Review.
# Congressional Budget Office. (2022). The budget and economic outlook: 2022 to 2032.
# Ehrmann, M., & Fratzscher, M. (2007). The timing of financial transmission of monetary policy shocks. Journal of Money, Credit and Banking, 39(2–3), 576–599.
# Gagnon, J., Raskin, M., Remache, J., & Sack, B. (2023). Unwinding safe‑asset shortages: The Fed’s quantitative tightening. Federal Reserve Bank of New York Staff Reports.
# Hausman, J. (2022). Supply‑chain bottlenecks and macroeconomic policy. Journal of Economic Perspectives, 36(4), 81–104.
# International Monetary Fund. (2022). World Economic Outlook: Rising tides.
# Jackson, T. (2023). The impact of rate hikes on housing and mortgage markets. Real Estate Economics, 51(2), 101–123.
# Jordà, Ò., Mertens, T. M., & Taylor, A. M. (2020). When does credit matter? Journal of Financial Economics, 135(1), 31–46.
# Mian, A., & Sufi, A. (2023). The fiscal multiplier in a pandemic: Evidence from U.S. stimulus checks. NBER Working Paper No. 30123.
# Shapiro, M. D., & Wilson, D. J. (2020). Supply chains and inflation: Evidence from major disruptions. Journal of Economic Perspectives, 34(1), 3–25.
# U.S. Bureau of Economic Analysis. (2023). National Income and Product Accounts.
# U.S. Bureau of Labor Statistics. (2023). Employment Situation Summary.
# TERMINATE
