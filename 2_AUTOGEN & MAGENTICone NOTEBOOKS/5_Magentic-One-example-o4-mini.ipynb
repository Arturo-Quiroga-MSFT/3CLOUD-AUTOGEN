# %%
#%pip install "autogen-ext[magentic-one,openai]" 
#%pip install gradio
# If using the MultimodalWebSurfer, you also need to install playwright dependencies:

# %% [markdown]
# ## Magentic One Overview
#
# Magentic-One is a generalist multi-agent system for solving open-ended web and file-based tasks across a variety of domains. It represents a significant step forward for multi-agent systems, achieving competitive performance on a number of agentic benchmarks (see the technical report for full details).
#
# When originally released in November 2024 Magentic-One was implemented directly on the autogen-core library. We have now ported Magentic-One to use autogen-agentchat, providing a more modular and easier to use interface.
#
# Using Magentic-One involves interacting with a digital world designed for humans, which carries inherent risks. To minimize these risks, consider the following precautions:
#
# - Use Containers: Run all tasks in docker containers to isolate the agents and prevent direct system attacks.
#
# - Virtual Environment: Use a virtual environment to run the agents and prevent them from accessing sensitive data.
#
# - Monitor Logs: Closely monitor logs during and after execution to detect and mitigate risky behavior.
#
# - Human Oversight: Run the examples with a human in the loop to supervise the agents and prevent unintended consequences.
#
# - Limit Access: Restrict the agents’ access to the internet and other resources to prevent unauthorized actions.
#
# - Safeguard Data: Ensure that the agents do not have access to sensitive data or resources that could be compromised. Do not share sensitive information with the agents. Be aware that agents may occasionally attempt risky actions, such as recruiting humans for help or accepting cookie agreements without human involvement. Always ensure agents are monitored and operate within a controlled environment to prevent unintended consequences. Moreover, be cautious that Magentic-One may be susceptible to prompt injection attacks from webpages.

# %% [markdown]
# ## Example of using AI Assistant Agents & Magentic One Agents with the MAGENTIC ONE Orchestrator

# %% [markdown]
# ## Import Required Dependencies

# %%
import asyncio
from autogen_ext.models.openai import AzureOpenAIChatCompletionClient
from autogen_agentchat.agents import AssistantAgent
from autogen_agentchat.teams import MagenticOneGroupChat
from autogen_agentchat.ui import Console
from autogen_ext.agents.web_surfer import MultimodalWebSurfer
from autogen_ext.agents.file_surfer import FileSurfer
from autogen_ext.agents.magentic_one import MagenticOneCoderAgent
from autogen_agentchat.agents import CodeExecutorAgent
from autogen_ext.code_executors.local import LocalCommandLineCodeExecutor
from autogen_ext.teams.magentic_one import MagenticOne
import yaml

# %% [markdown]
# ## Create a Model Client with a reasoning model

# %%
with open("model_config_reasoning_model.yaml", "r") as f:
        model_config = yaml.safe_load(f)
model_client = AzureOpenAIChatCompletionClient.load_component(model_config)

# %% [markdown]
# ## Create Basic Team with one Assistant only

# %%
async def main() -> None:
    assistant = AssistantAgent(
        "Assistant",
        model_client=model_client,
    )
    team = MagenticOneGroupChat([assistant], model_client=model_client)
    await Console(team.run_stream(task="Provide proof of the Pythagorean theorem using a diagram."))
    await model_client.close()


await main()

# %% [markdown]
# ## Create a team with a multimodal websurfer
#
# - WebSurfer: A helpful assistant with access to a web browser. Ask them to perform web searches, open pages, and interact with content (e.g., clicking links, scrolling the viewport, filling in form fields, etc.). It can also summarize the entire page, or answer questions based on the content of the page. It can also be asked to sleep and wait for pages to load, in cases where the page seems not yet fully loaded.

# %%
# The example code may download files from the internet, execute code, and interact with web pages. 
# Ensure you are in a safe environment before running the example code.
async def main() -> None:
    surfer = MultimodalWebSurfer(
        "WebSurfer",
        model_client=model_client,
    )

    team = MagenticOneGroupChat([surfer], model_client=model_client)
    await Console(team.run_stream(task="What is the UV index in Toronto today?"))

await main()

# %% [markdown]
# ## Create a multi-agent team with the following capabilities
#
# - WebSurfer: A helpful assistant with access to a web browser. Ask them to perform web searches, open pages, and interact with content (e.g., clicking links, scrolling the viewport, filling in form fields, etc.). It can also summarize the entire page, or answer questions based on the content of the page. It can also be asked to sleep and wait for pages to load, in cases where the page seems not yet fully loaded.
#
# - FileSurfer: An agent that can handle local files.
#
# - Coder: A helpful and general-purpose AI assistant that has strong language skills, Python skills, and Linux command line skills.
#
# - ComputerTerminal: A computer terminal that performs no other action than running Python scripts (provided to it quoted in python code blocks), or sh shell scripts (provided to it quoted in sh code blocks).

# %%
# The example code may download files from the internet, execute code, and interact with web pages. 
# Ensure you are in a safe environment before running the example code.

async def main() -> None:
    surfer = MultimodalWebSurfer(
        "WebSurfer",
        model_client=model_client,
    )

    file_surfer = FileSurfer( "FileSurfer",model_client=model_client)
    coder = MagenticOneCoderAgent("Coder",model_client=model_client)
    terminal = CodeExecutorAgent("ComputerTerminal",code_executor=LocalCommandLineCodeExecutor())
    
    team = MagenticOneGroupChat([surfer, file_surfer, coder, terminal], model_client=model_client)

    await Console(team.run_stream(task="What is the UV index in Melbourne today?"))



await main()

# %% [markdown]
# ## This uses Magentic_one helper class with all the agents bundled together

# %%
async def example_usage():
    client = model_client
    m1 = MagenticOne(client=client)
    task = "Write a Python script to fetch data from the OpenWeatherMap API, and save the file locally."
    result = await Console(m1.run_stream(task=task))
    print(result)


if __name__ == "__main__":
    await example_usage()
# Out:
# /var/folders/dj/qp0fwj152ks28q9cn0_rd3fw0000gn/T/ipykernel_54682/3879225610.py:3: DeprecationWarning: Instantiating MagenticOne without a code_executor is deprecated. Provide a code_executor to clear this warning (e.g., code_executor=LocalCommandLineCodeExecutor() ).
#   m1 = MagenticOne(client=client)
# ---------- TextMessage (user) ----------
# Write a Python script to fetch data from the OpenWeatherMap API, and save the file locally.
# ---------- TextMessage (MagenticOneOrchestrator) ----------
#
# We are working to address the following user request:
#
# Write a Python script to fetch data from the OpenWeatherMap API, and save the file locally.
#
#
# To answer this request we have assembled the following team:
#
# FileSurfer: An agent that can handle local files.
# WebSurfer: A helpful assistant with access to a web browser. Ask them to perform web searches, open pages, and interact with content (e.g., clicking links, scrolling the viewport, filling in form fields, etc.). It can also summarize the entire page, or answer questions based on the content of the page. It can also be asked to sleep and wait for pages to load, in cases where the page seems not yet fully loaded.
# Coder: A helpful and general-purpose AI assistant that has strong language skills, Python skills, and Linux command line skills.
# ComputerTerminal: A computer terminal that performs no other action than running Python scripts (provided to it quoted in ```python code blocks), or sh shell scripts (provided to it quoted in ```sh code blocks).
#
#
# Here is an initial fact sheet to consider:
#
# 1. GIVEN OR VERIFIED FACTS
# - The user wants a Python script.
# - The script must fetch data from the OpenWeatherMap API.
# - The script must save the fetched data to a local file.
#
# 2. FACTS TO LOOK UP
# - The exact OpenWeatherMap API endpoint(s) (e.g., current weather data URL).
# - The required query parameters and their formats (e.g., `appid`, `q` or `lat`/`lon`).
# - The base URL: typically `https://api.openweathermap.org/data/2.5/weather`.
# - Authentication details (how to register for and include an API key).
# - Best practices for local file paths in Python (e.g., using `os` or `pathlib`).
#
# 3. FACTS TO DERIVE
# - How to structure the HTTP request in Python (likely via the `requests` library).
# - How to handle errors or non‑200 HTTP responses.
# - How to serialize the API response (JSON) and write it to disk.
# - Reasonable defaults for filename, encoding, and file format (e.g., `.json`).
#
# 4. EDUCATED GUESSES
# - The user will supply or obtain their own OpenWeatherMap API key.
# - The data will be saved in JSON format.
# - The script will use standard libraries (`requests`, `json`, `os` or `pathlib`).
# - A simple command‑line interface (e.g., passing city name or coordinates) may be desired.
#
#
# Here is the plan to follow as best as possible:
#
# - WebSurfer: look up and summarize the current OpenWeatherMap API endpoint, required query parameters (API key, city name or coordinates), and response format.
# - Coder: draft a Python script that
#   • reads user inputs (city or coords + API key)
#   • uses `requests` to fetch the API data
#   • handles errors (non‑200 responses)
#   • writes the JSON payload to a local file (e.g. `weather.json`, using `pathlib` for paths).
# - ComputerTerminal: install any needed Python dependencies (e.g. `requests`), run the script with sample inputs, and verify it produces the expected file.
# - FileSurfer (optional): inspect the saved file to confirm its contents match the fetched JSON schema.
#
# ---------- TextMessage (MagenticOneOrchestrator) ----------
# Please find and summarize the OpenWeatherMap current weather API documentation: the base URL, required query parameters (e.g., appid, q or lat/lon), response format, and any authentication details.
# ---------- MultiModalMessage (WebSurfer) ----------
# I typed 'OpenWeatherMap current weather API documentation base URL appid q lat lon response format' into the browser search bar.
#
# The web browser is open to the page [OpenWeatherMap current weather API documentation base URL appid q lat lon response format - Search](https://www.bing.com/search?q=OpenWeatherMap+current+weather+API+documentation+base+URL+appid+q+lat+lon+response+format&FORM=QBLH).
# The viewport shows 26% of the webpage, and is positioned at the top of the page
# The following text is visible in the viewport:
#
# By using this site you agree to the use of cookies for analytics, personalized content, and ads.
# Learn more about third party cookies
# |
# Microsoft Privacy Policy
# Skip to content
# OpenWeatherMap current weather API documentation base URL appid q lat lon response formatFrançaisMobileAll
# Search
# Copilot
# Videos
# Images
# Maps
# News
# More
# Tools
# OpenWeatherMap
# https://openweathermap.org › currentCurrent weather data - OpenWeatherMapObtain real-time
# weather data for any location globally with
# OpenWeather'
# s
# Current
# Weather Data
# API. Provides comprehensive weather details in JSON, XML, or HTML formats, includin…
# Home Sign In
# OpenWeather is a team of IT experts and data scientists that has been practising …
# Weather Forecast
# OpenWeather is a team of IT experts and data scientists that has been practising …
# List of All API Parameters With Available Units
# Explore OpenWeather's comprehensive API response parameters list, offering d…
# Maps
# Explore OpenWeather's interactive weather map focused on temperature, …
# Ask a Question
# We will send a response to the email address specified * Email * Subject * Me…
# Example
# Example - Current weather data - OpenWeatherMap
# How to retrieve openweather data through API?
# Once you have created your account, you will receive an API key that you can use to make API requests. To retrieve openWeather data through API, we need node-fetch package which can be installed via NPM. To fetch the current weather data for a specific location, you can use the following code: const apiKey = '<YOUR_API_KEY>';publicapis.io
# 02:44
# [Tutorial] - How to Use Weather API for Beginners | Open Weather Map API
# YouTubeAndy's Tech Tutorials173.2K viewsJun 24, 2022Weather API - OpenWeatherMap
# Ideal for both beginners and professionals, our
# APIs offer
# current weather, minute-by-mi…
# OpenWeatherMapOne Call API: weather data for any geographi…
# To get access to
# current weather, minute forecast for 1 hour, hourly forecast for 48 …
# OpenWeatherMapFeedback
# OpenWeatherMap
# https://openweathermap.org › api
# Weather API - OpenWeatherMapIdeal for both beginners and professionals, our APIs offer current weather, minute-by-minute forecasts, historical data archives, and future predictions. Access weather data starting from …
# Videos of OpenWeatherMap Current Weather API Documentation B…
# bing.com › videos[Tutorial] - How to Use
# Weather
# API for Beginners | Open
# OpenWeatherMapOnline weather serviceOpenWeatherMap is an online service, owned by OpenWeather Ltd, that provides global weather data via API, including current weather data, forecasts, nowcasts, and historical weather data. The company …
#
# The following metadata was extracted from the webpage:
#
# {
#     "meta_tags": {
#         "referrer": "origin-when-cross-origin",
#         "SystemEntropyOriginTrialToken": "A5is4nwJJVnhaJpUr1URgj4vvAXSiHoK0VBbM9fawMskbDUj9WUREpa3JzGAo6xd1Cp2voQEG1h6NQ71AsMznU8AAABxeyJvcmlnaW4iOiJodHRwczovL3d3dy5iaW5nLmNvbTo0NDMiLCJmZWF0dXJlIjoiTXNVc2VyQWdlbnRMYXVuY2hOYXZUeXBlIiwiZXhwaXJ5IjoxNzUzNzQ3MjAwLCJpc1N1YmRvbWFpbiI6dHJ1ZX0=",
#         "ConfidenceOriginTrialToken": "Aqw360MHzRcmtEVv55zzdIWcTk2BBYHcdBAOysNJZP4qkN8M+5vUq36ITHFVst8LiX36KBZJXB8xvyBgdK2z5Q0AAAB6eyJvcmlnaW4iOiJodHRwczovL2JpbmcuY29tOjQ0MyIsImZlYXR1cmUiOiJQZXJmb3JtYW5jZU5hdmlnYXRpb25UaW1pbmdDb25maWRlbmNlIiwiZXhwaXJ5IjoxNzYwNDAwMDAwLCJpc1N1YmRvbWFpbiI6dHJ1ZX0=",
#         "og:description": "Intelligent search from Bing makes it easier to quickly find what you\u2019re looking for and rewards you.",
#         "og:site_name": "Bing",
#         "og:title": "OpenWeatherMap current weather API documentation base URL appid q lat lon response format - Bing",
#         "og:url": "https://www.bing.com/search?q=OpenWeatherMap+current+weather+API+documentation+base+URL+appid+q+lat+lon+response+format&FORM=QBLH",
#         "fb:app_id": "3732605936979161",
#         "og:image": "http://www.bing.com/sa/simg/facebook_sharing_5.png",
#         "og:type": "website",
#         "og:image:width": "600",
#         "og:image:height": "315"
#     }
# }
#
# Here is a screenshot of the page.
#
# ---------- TextMessage (MagenticOneOrchestrator) ----------
# Please click and open the “Current weather data” page (https://openweathermap.org/current) on the OpenWeatherMap site and summarize: the HTTP GET base URL, required query parameters (e.g., appid, q, lat, lon), supported response formats, and how to supply the API key.
# ---------- MultiModalMessage (WebSurfer) ----------
# I clicked 'Current weather data - OpenWeatherMap'.
#
# The web browser is open to the page [Current weather data - OpenWeatherMap](https://openweathermap.org/current).
# The viewport shows 5% of the webpage, and is positioned at the top of the page
# The following text is visible in the viewport:
#
# GuideAPIDashboardMarketplacePricingMapsOur InitiativesPartnersBlogFor BusinessSign inSupport centreCurrent weather data
# HomeAPICurrent weather
# Product conceptCall current weather dataHow to make an API callAPI responseJSON format API response exampleJSON format API response fieldsXML format API response exampleXML format API response fieldsList of weather condition codesMin/max temperature in current weather API and forecast APIBulk downloadingOther featuresGeocoding APIBuilt-in geocodingBuilt-in API request by city nameBuilt-in API request by city IDBuilt-in API request by ZIP codeFormatUnits of measurementMultilingual supportCall back function for JavaScript codeChat with Ulla - OpenWeather AI assistant
# Product concept
#  Access current weather data for any location on Earth! We collect and process weather data from different sources such as global and local weather models, satellites, radars and a vast network of weather stations. Data is available in JSON, XML, or HTML format.
# Call current weather data
# How to make an API call
# API call
# https://api.openweathermap.org/data/2.5/weather?lat=
# {lat}&lon=
# {lon}&appid=
# {API key}Parameters
# latrequiredLatitude. If you need the geocoder to automatic convert city names and zip-codes to geo coordinates and the other way around, please use our
# Geocoding APIlonrequiredLongitude. If you need the geocoder to automatic convert city names and zip-codes to geo coordinates and the other way around, please use our
# Geocoding API We use cookies to personalize content and to analyze our traffic. Please decide if you are willing to accept cookies from our website.
#  Advanced Settings
#  Decline
#  Accept
# ×
# Ulla Weather Assistant
#
# The following metadata was extracted from the webpage:
#
# {
#     "meta_tags": {
#         "apple-itunes-app": "app-id=1535923697",
#         "viewport": "width=device-width, initial-scale=1.0",
#         "keywords": "weather, world, Openstreetmap, forecast, Openweather, current",
#         "description": "Obtain real-time weather data for any location globally with OpenWeather's Current Weather Data API.\nProvides comprehensive weather details in JSON, XML, or HTML formats, including temperature, pressure, humidity, and\nmore. Supports geocoding, language options, and different measurement units.",
#         "author": "OpenWeatherMap.org",
#         "domain": "OpenWeatherMap.org",
#         "p:domain_verify": "34fe229eab8562dca90f4a5962ff80a9",
#         "title": "Current weather data"
#     }
# }
#
# Here is a screenshot of the page.
#
# ---------- TextMessage (MagenticOneOrchestrator) ----------
# Please scroll down on the “Current weather data” page and capture all available query parameters (including city name ‘q’, city ID, ZIP code, lat/lon, units, language, etc.), the exact base URL, supported response formats (JSON, XML, HTML), and instructions on how to include the API key.
# ---------- MultiModalMessage (WebSurfer) ----------
# I scrolled down one page in the browser.
#
# The web browser is open to the page [Current weather data - OpenWeatherMap](https://openweathermap.org/current).
# The viewport shows 5% of the webpage, and is positioned 4% down from the top of the page
# The following text is visible in the viewport:
#
# GuideAPIDashboardMarketplacePricingMapsOur InitiativesPartnersBlogFor BusinessSign inSupport centreProduct conceptCall current weather dataHow to make an API callAPI responseJSON format API response exampleJSON format API response fieldsXML format API response exampleXML format API response fieldsList of weather condition codesMin/max temperature in current weather API and forecast APIBulk downloadingOther featuresGeocoding APIBuilt-in geocodingBuilt-in API request by city nameBuilt-in API request by city IDBuilt-in API request by ZIP codeFormatUnits of measurementMultilingual supportCall back function for JavaScript codeChat with Ulla - OpenWeather AI assistant
# Longitude. If you need the geocoder to automatic convert city names and zip-codes to geo coordinates and the other way around, please use our
# Geocoding APIappidrequiredYour unique API key (you can always find it on your account page under the
# "API key" tab)
# modeoptionalResponse format. Possible values are
# xml and
# html. If you don't use the
# mode parameter format is JSON by default.
# Learn moreunitsoptionalUnits of measurement.
# standard,
# metric and
# imperial units are available. If you do not use the
# units parameter,
# standard units will be applied by default.
# Learn morelangoptionalYou can use this parameter to get the output in your language.
# Learn morePlease use
# Geocoder API if you need automatic convert city names and zip-codes to geo coordinates and the other way around.
# Please note that
# built-in geocoder has been deprecated. Although it is still available for use, bug fixing and updates are no longer available for this functionality.
# Examples of API calls
#  https://api.openweathermap.org/data/2.5/weather?lat=44.34&lon=10.99&appid=
# {API key}API response
#  If you do not see some of the parameters in your API response it means that these weather phenomena are just not happened for the time of measurement for the city or location chosen. Only really measured or calculated data is displayed in API response.
#  We use cookies to personalize content and to analyze our traffic. Please decide if you are willing to accept cookies from our website.
#  Advanced Settings
#  Decline
#  Accept
# ×
# Ulla Weather Assistant
# Here is a screenshot of the page.
#
# ---------- TextMessage (MagenticOneOrchestrator) ----------
# Please write a self‑contained Python script that:
# - Accepts command‑line arguments for location (either city name with `-q` or latitude/longitude with `--lat` and `--lon`), an API key (`--apikey`), and optional `--units` and `--lang` flags.
# - Uses the `requests` library to GET from https://api.openweathermap.org/data/2.5/weather with the proper query parameters (appid, q or lat/lon, units, lang).
# - Handles HTTP errors gracefully (non‑200 responses) and prints an error message.
# - Parses the JSON response and writes it to a local file (e.g. `weather_<location>_<timestamp>.json`) using `pathlib`.
# - Includes a `requirements.txt` comment for installing `requests`.
# Make sure the script is clear, well‑commented, and ready to run on any system with Python 3.
# ---------- TextMessage (Coder) ----------
# Below is a self‑contained Python 3 script that meets your requirements. Save it as, for example, `get_weather.py`, make sure you have Python 3 installed, then install the dependency and run:
#
#
#   pip install requests
#   python get_weather.py --apikey YOUR_KEY -q London --units metric --lang en
#
# ```python
# #!/usr/bin/env python3
# # requirements: requests
#
# """
# Fetch current weather data from OpenWeatherMap and save JSON to a timestamped file.
#
# Usage:
#   python get_weather.py --apikey YOUR_API_KEY (-q CITY | --lat LAT --lon LON)
#                         [--units {standard,metric,imperial}]
#                         [--lang LANGUAGE_CODE]
#
# Examples:
#   python get_weather.py --apikey abc123 -q London
#   python get_weather.py --apikey abc123 --lat 44.34 --lon 10.99 --units metric
# """
#
# import argparse
# import sys
# import json
# from datetime import datetime
# from pathlib import Path
#
# import requests
#
#
# def parse_args():
#     p = argparse.ArgumentParser(
#         description="Fetch current weather from OpenWeatherMap and save to a JSON file."
#     )
#     loc = p.add_mutually_exclusive_group(required=True)
#     loc.add_argument(
#         "-q", "--city", metavar="CITY", help="City name, e.g. 'London,UK' or 'Paris'"
#     )
#     loc.add_argument(
#         "--lat", type=float, help="Latitude, e.g. 44.34"
#     )
#     p.add_argument(
#         "--lon", type=float, help="Longitude, e.g. 10.99 (required if --lat is used)"
#     )
#     p.add_argument(
#         "--apikey", required=True, help="Your OpenWeatherMap API key"
#     )
#     p.add_argument(
#         "--units",
#         choices=["standard", "metric", "imperial"],
#         help="Units of measurement (default is standard)",
#     )
#     p.add_argument(
#         "--lang",
#         help="Language code for response (e.g. en, fr, es)",
#     )
#     args = p.parse_args()
#
#     # If lat is provided, lon must also be provided
#     if args.lat is not None and args.lon is None:
#         p.error("--lon is required when --lat is provided")
#     return args
#
#
# def build_params(args):
#     params = {"appid": args.apikey}
#     if args.city:
#         params["q"] = args.city
#     else:
#         params["lat"] = args.lat
#         params["lon"] = args.lon
#     if args.units:
#         params["units"] = args.units
#     if args.lang:
#         params["lang"] = args.lang
#     return params
#
#
# def main():
#     args = parse_args()
#     base_url = "https://api.openweathermap.org/data/2.5/weather"
#     params = build_params(args)
#
#     try:
#         resp = requests.get(base_url, params=params, timeout=10)
#     except requests.RequestException as e:
#         print(f"Error connecting to OpenWeatherMap: {e}", file=sys.stderr)
#         sys.exit(1)
#
#     if resp.status_code != 200:
#         # Try to extract message from JSON if possible
#         try:
#             err = resp.json().get("message", "")
#         except ValueError:
#             err = resp.text
#         print(f"API error {resp.status_code}: {err}", file=sys.stderr)
#         sys.exit(1)
#
#     # Parse JSON
#     try:
#         data = resp.json()
#     except ValueError:
#         print("Failed to parse JSON response", file=sys.stderr)
#         sys.exit(1)
#
#     # Build filename
#     ts = datetime.utcnow().strftime("%Y%m%dT%H%M%SZ")
#     if args.city:
#         loc_tag = args.city.replace(" ", "_")
#     else:
#         loc_tag = f"{args.lat}_{args.lon}"
#     filename = f"weather_{loc_tag}_{ts}.json"
#     outfile = Path.cwd() / filename
#
#     # Write to file
#     try:
#         outfile.write_text(json.dumps(data, indent=2), encoding="utf-8")
#     except OSError as e:
#         print(f"Failed to write file {outfile}: {e}", file=sys.stderr)
#         sys.exit(1)
#
#     print(f"Weather data saved to {outfile}")
#
#
# if __name__ == "__main__":
#     main()
# ```
#
# Copy that into `get_weather.py`.
# Install `requests` via
# ```
# pip install requests
# ```
# Then run as shown above.
# It will exit non‑zero on connection/API errors, and on success write a timestamped JSON file in your current directory.
# ---------- TextMessage (MagenticOneOrchestrator) ----------
# Below is a ready‑to‑run Python 3 script that fetches current weather data from OpenWeatherMap and saves it as a timestamped JSON file.
#
# 1. Save this as get_weather.py
# 2. Install the only dependency:
#    ```bash
#    pip install requests
#    ```
# 3. Run it, for example:
#    ```bash
#    python get_weather.py --apikey YOUR_API_KEY -q London --units metric --lang en
#    ```
#
# ```python
# #!/usr/bin/env python3
# # requirements: requests
#
# """
# Fetch current weather data from OpenWeatherMap and save JSON to a timestamped file.
#
# Usage:
#   python get_weather.py --apikey YOUR_API_KEY (-q CITY | --lat LAT --lon LON)
#                         [--units {standard,metric,imperial}]
#                         [--lang LANGUAGE_CODE]
#
# Examples:
#   python get_weather.py --apikey abc123 -q "New York,US"
#   python get_weather.py --apikey abc123 --lat 44.34 --lon 10.99 --units metric
# """
#
# import argparse
# import sys
# import json
# from datetime import datetime
# from pathlib import Path
#
# import requests
#
# def parse_args():
#     p = argparse.ArgumentParser(
#         description="Fetch current weather from OpenWeatherMap and save to a JSON file."
#     )
#     loc = p.add_mutually_exclusive_group(required=True)
#     loc.add_argument(
#         "-q", "--city", metavar="CITY",
#         help="City name, e.g. 'London' or 'London,UK'"
#     )
#     loc.add_argument(
#         "--lat", type=float,
#         help="Latitude, e.g. 44.34"
#     )
#     p.add_argument(
#         "--lon", type=float,
#         help="Longitude, e.g. 10.99 (required if --lat is used)"
#     )
#     p.add_argument(
#         "--apikey", required=True,
#         help="Your OpenWeatherMap API key"
#     )
#     p.add_argument(
#         "--units",
#         choices=["standard", "metric", "imperial"],
#         help="Units of measurement (default: standard)"
#     )
#     p.add_argument(
#         "--lang",
#         help="Language code for response (e.g. en, fr, es)"
#     )
#     args = p.parse_args()
#
#     if args.lat is not None and args.lon is None:
#         p.error("--lon is required when --lat is provided")
#     return args
#
# def build_params(args):
#     params = {"appid": args.apikey}
#     if args.city:
#         params["q"] = args.city
#     else:
#         params["lat"] = args.lat
#         params["lon"] = args.lon
#     if args.units:
#         params["units"] = args.units
#     if args.lang:
#         params["lang"] = args.lang
#     return params
#
# def main():
#     args = parse_args()
#     base_url = "https://api.openweathermap.org/data/2.5/weather"
#     params = build_params(args)
#
#     try:
#         resp = requests.get(base_url, params=params, timeout=10)
#         resp.raise_for_status()
#     except requests.RequestException as e:
#         print(f"Error fetching data: {e}", file=sys.stderr)
#         sys.exit(1)
#
#     try:
#         data = resp.json()
#     except ValueError:
#         print("Failed to parse JSON response", file=sys.stderr)
#         sys.exit(1)
#
#     # Generate filename: weather_<location>_<UTC-timestamp>.json
#     ts = datetime.utcnow().strftime("%Y%m%dT%H%M%SZ")
#     if args.city:
#         loc_tag = args.city.replace(" ", "_").replace(",", "")
#     else:
#         loc_tag = f"{args.lat}_{args.lon}"
#     filename = f"weather_{loc_tag}_{ts}.json"
#     outpath = Path.cwd() / filename
#
#     try:
#         outpath.write_text(json.dumps(data, indent=2), encoding="utf-8")
#     except OSError as e:
#         print(f"Could not write file {outpath}: {e}", file=sys.stderr)
#         sys.exit(1)
#
#     print(f"Weather data saved to {outpath}")
#
# if __name__ == "__main__":
#     main()
# ```
#
# What this does:
# - Builds a GET request to `https://api.openweathermap.org/data/2.5/weather`
# - Accepts either `-q/--city` or `--lat`+`--lon`, plus `--apikey`, optional `--units` and `--lang`
# - Exits with an error message on network/API failure
# - Writes the pretty‑printed JSON response to a file named
#   `weather_<location>_<YYYYMMDDThhmmssZ>.json`
#
# You’re all set—just plug in your API key and location!
# messages=[TextMessage(source='user', models_usage=None, metadata={}, content='Write a Python script to fetch data from the OpenWeatherMap API, and save the file locally.', type='TextMessage'), TextMessage(source='MagenticOneOrchestrator', models_usage=None, metadata={}, content='\nWe are working to address the following user request:\n\nWrite a Python script to fetch data from the OpenWeatherMap API, and save the file locally.\n\n\nTo answer this request we have assembled the following team:\n\nFileSurfer: An agent that can handle local files.\nWebSurfer: A helpful assistant with access to a web browser. Ask them to perform web searches, open pages, and interact with content (e.g., clicking links, scrolling the viewport, filling in form fields, etc.). It can also summarize the entire page, or answer questions based on the content of the page. It can also be asked to sleep and wait for pages to load, in cases where the page seems not yet fully loaded.\nCoder: A helpful and general-purpose AI assistant that has strong language skills, Python skills, and Linux command line skills.\nComputerTerminal: A computer terminal that performs no other action than running Python scripts (provided to it quoted in ```python code blocks), or sh shell scripts (provided to it quoted in ```sh code blocks).\n\n\nHere is an initial fact sheet to consider:\n\n1. GIVEN OR VERIFIED FACTS  \n- The user wants a Python script.  \n- The script must fetch data from the OpenWeatherMap API.  \n- The script must save the fetched data to a local file.\n\n2. FACTS TO LOOK UP  \n- The exact OpenWeatherMap API endpoint(s) (e.g., current weather data URL).  \n- The required query parameters and their formats (e.g., `appid`, `q` or `lat`/`lon`).  \n- The base URL: typically `https://api.openweathermap.org/data/2.5/weather`.  \n- Authentication details (how to register for and include an API key).  \n- Best practices for local file paths in Python (e.g., using `os` or `pathlib`).\n\n3. FACTS TO DERIVE  \n- How to structure the HTTP request in Python (likely via the `requests` library).  \n- How to handle errors or non‑200 HTTP responses.  \n- How to serialize the API response (JSON) and write it to disk.  \n- Reasonable defaults for filename, encoding, and file format (e.g., `.json`).\n\n4. EDUCATED GUESSES  \n- The user will supply or obtain their own OpenWeatherMap API key.  \n- The data will be saved in JSON format.  \n- The script will use standard libraries (`requests`, `json`, `os` or `pathlib`).  \n- A simple command‑line interface (e.g., passing city name or coordinates) may be desired.\n\n\nHere is the plan to follow as best as possible:\n\n- WebSurfer: look up and summarize the current OpenWeatherMap API endpoint, required query parameters (API key, city name or coordinates), and response format.  \n- Coder: draft a Python script that  \n  • reads user inputs (city or coords + API key)  \n  • uses `requests` to fetch the API data  \n  • handles errors (non‑200 responses)  \n  • writes the JSON payload to a local file (e.g. `weather.json`, using `pathlib` for paths).  \n- ComputerTerminal: install any needed Python dependencies (e.g. `requests`), run the script with sample inputs, and verify it produces the expected file.  \n- FileSurfer (optional): inspect the saved file to confirm its contents match the fetched JSON schema.\n', type='TextMessage'), TextMessage(source='MagenticOneOrchestrator', models_usage=None, metadata={}, content='Please find and summarize the OpenWeatherMap current weather API documentation: the base URL, required query parameters (e.g., appid, q or lat/lon), response format, and any authentication details.', type='TextMessage'), MultiModalMessage(source='WebSurfer', models_usage=RequestUsage(prompt_tokens=2027, completion_tokens=241), metadata={}, content=['I typed \'OpenWeatherMap current weather API documentation base URL appid q lat lon response format\' into the browser search bar.\n\nThe web browser is open to the page [OpenWeat ...
