# %%
#%pip install -U "autogen-agentchat"
#%pip install -U "autogen-agentchat[azure]"
#%pip install -U autogenstudio
# %pip install python-dotenv

# %%
from autogen_agentchat.agents import AssistantAgent
from autogen_agentchat.conditions import TextMentionTermination
from autogen_agentchat.teams import RoundRobinGroupChat
from autogen_agentchat.ui import Console
from autogen_ext.models.openai import AzureOpenAIChatCompletionClient
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
model_client = AzureOpenAIChatCompletionClient(
    azure_deployment="gpt-4o",
    azure_endpoint="https://aq-aoai-swedencentral.openai.azure.com/",
    model="gpt-4o",
    api_version="2025-03-01-preview",
    api_key="3ShjYyRHd6t0VthIuoOUe1GEnwlj1tkNSHkOs6IrO1CxKQ3gHmsIJQQJ99BAACfhMk5XJ3w3AAABACOG3ddZ",
    temperature=0.7,
)

# %%
planner_agent = AssistantAgent(
    "planner_agent",
    model_client=model_client,
    description="A helpful assistant that can plan trips.",
    system_message="You are a helpful assistant that can suggest a travel plan for a user based on their request.",
)

local_agent = AssistantAgent(
    "local_agent",
    model_client=model_client,
    description="A local assistant that can suggest local activities or places to visit.",
    system_message="You are a helpful assistant that can suggest authentic and interesting local activities or places to visit for a user and can utilize any context information provided.",
)

language_agent = AssistantAgent(
    "language_agent",
    model_client=model_client,
    description="A helpful assistant that can provide language tips for a given destination.",
    system_message="You are a helpful assistant that can review travel plans, providing feedback on important/critical tips about how best to address language or communication challenges for the given destination. If the plan already includes language tips, you can mention that the plan is satisfactory, with rationale.",
)

travel_summary_agent = AssistantAgent(
    "travel_summary_agent",
    model_client=model_client,
    description="A helpful assistant that can summarize the travel plan.",
    system_message="You are a helpful assistant that can take in all of the suggestions and advice from the other agents and provide a detailed final travel plan. You must ensure that the final plan is integrated and complete. YOUR FINAL RESPONSE MUST BE THE COMPLETE PLAN. When the plan is complete and all perspectives are integrated, you can respond with TERMINATE.",
)

# %%
termination = TextMentionTermination("TERMINATE")
group_chat = RoundRobinGroupChat(
    [planner_agent, local_agent, language_agent, travel_summary_agent], termination_condition=termination
)
await Console(group_chat.run_stream(task="Plan a 3 day trip to Nepal."))

await model_client.close()
# Out:
# ---------- user ----------
# Plan a 3 day trip to Nepal.
# ---------- planner_agent ----------
# **3-Day Nepal Trip Itinerary**
# Nepal is a magical destination known for its breathtaking mountains, rich culture, and warm hospitality. Here's a plan for a 3-day trip that balances sightseeing, culture, and soft adventures.
#
# ---
#
# ### **Day 1: Arrival in Kathmandu and Exploring the Cultural Heritage**
# **Morning:**
# - **Arrival in Kathmandu:** Land at Tribhuvan International Airport. After clearing customs, check into your hotel or guesthouse.
# - **Breakfast:** Savor a Nepali breakfast, which might include dishes like "chiura" (beaten rice) and "dahi" (yogurt).
#
# **Mid-Morning:**
# - **Kathmandu Durbar Square:** Visit this UNESCO World Heritage Site, a historic plaza filled with ancient temples, palaces, and courtyards.
# - **Swayambhunath (Monkey Temple):** A short drive away, this iconic stupa offers panoramic views of Kathmandu Valley and is an important Buddhist pilgrimage site.
#
# **Lunch:**
# - Enjoy a local meal at a restaurant in Thamel, Kathmandu’s vibrant tourist hub. Try dishes like dal bhat (lentil soup and rice) or momos (dumplings).
#
# **Afternoon:**
# - **Pashupatinath Temple:** One of the holiest Hindu temples in the world, located on the banks of the Bagmati River. Witness evening rituals and cremation ceremonies.
# - **Boudhanath Stupa:** Another UNESCO site, this massive Buddhist stupa is a serene spot to experience Tibetan Buddhist culture.
#
# **Evening:**
# - **Dinner in Thamel:** Explore its bustling streets and dine at a rooftop restaurant. Try Newari cuisine or international options.
# - **Overnight Stay:** Check into a comfortable hotel or guesthouse in Kathmandu.
#
# ---
#
# ### **Day 2: Scenic Adventure in Pokhara**
# **Morning:**
# - **Travel to Pokhara:** Take an early morning flight (25 minutes) or drive (6-7 hours) to Pokhara, Nepal’s adventure capital. Check into your lakeside hotel.
# - **Breakfast:** Have breakfast with views of the Annapurna mountain range.
#
# **Mid-Morning:**
# - **Boating on Phewa Lake:** Rent a boat and enjoy the tranquil waters of Phewa Lake. Visit the Tal Barahi Temple, located on a small island in the lake.
# - **Davis Falls and Gupteshwor Cave:** Explore these natural wonders located nearby.
#
# **Lunch:**
# - Relish your meal at a lakeside restaurant with stunning views.
#
# **Afternoon:**
# - **Peace Pagoda:** A short hike or drive takes you to the World Peace Pagoda, which offers panoramic views of Pokhara, Phewa Lake, and the Himalayas.
# - **Bindhyabasini Temple:** Visit this sacred Hindu temple dedicated to Goddess Durga.
#
# **Evening:**
# - **Relax at Lakeside:** Stroll along the Lakeside area, known for its vibrant cafes, shops, and live music.
# - **Dinner:** Try a fusion of Nepali and continental cuisine at a local restaurant.
# - **Overnight Stay:** Stay at a lakeside hotel or resort.
#
# ---
#
# ### **Day 3: Sunrise and Return to Kathmandu**
# **Early Morning:**
# - **Sarangkot Sunrise View:** Drive to Sarangkot, a hill station near Pokhara, to witness the sunrise over the Annapurna and Dhaulagiri ranges. This is a photographer’s dream!
#
# **Breakfast:**
# - Return to Pokhara and enjoy breakfast with mountain views.
#
# **Mid-Morning:**
# - **Adventure Activity (Optional):** If you're adventurous, try paragliding or zip-lining in Pokhara for a thrilling experience.
#
# **Lunch:**
# - Enjoy a hearty meal in Pokhara before heading back.
#
# **Afternoon:**
# - **Travel Back to Kathmandu:** Take an afternoon flight or drive back to Kathmandu.
#
# **Evening:**
# - **Shopping in Thamel:** Pick up souvenirs like pashmina shawls, prayer flags, or handicrafts.
# - **Relaxing Dinner:** End your trip with a farewell dinner at a traditional Nepali restaurant, accompanied by cultural dance performances.
# - **Overnight Stay:** Stay at a hotel in Kathmandu or prepare for your departure.
#
# ---
#
# ### **Tips for Your Trip:**
# - **Visa:** Ensure you have a Nepal visa (available on arrival for many nationalities).
# - **Currency:** The local currency is the Nepalese Rupee (NPR). Carry cash for smaller transactions.
# - **Packing:** Bring layers, as temperatures can vary, especially in the mountains.
# - **Local Transport:** Use taxis or hire a private vehicle for convenience.
#
# This 3-day itinerary offers a mix of cultural immersion, scenic beauty, and soft adventure, ensuring you experience the best of Nepal in a short time!
# /Users/arturoquiroga/3CLOUD-AUTOGEN/.venv/lib/python3.13/site-packages/autogen_agentchat/agents/_assistant_agent.py:870: UserWarning: Resolved model mismatch: gpt-4o-2024-08-06 != gpt-4o-2024-11-20. Model mapping in autogen_ext.models.openai may be incorrect. Set the model to gpt-4o-2024-11-20 to enhance token/cost estimation and suppress this warning.
#   model_result = await model_client.create(
# ---------- local_agent ----------
# If you have additional interests—like trekking, meditation, or unique culinary experiences—let me know, and I can adjust the itinerary to fit your preferences!
# If you have additional interests—like trekking, meditation, or unique culinary experiences—let me know, and I can adjust the itinerary to fit your preferences!
# ---------- language_agent ----------
# This is a well-organized itinerary, but it lacks specific language or communication tips for travelers visiting Nepal. Here's some feedback and additional guidance:
#
# ### **Language Tips for Nepal**
# 1. **Official Language:**
#    - The official language is Nepali. While many locals in tourist areas (like Kathmandu and Pokhara) speak English, communication can sometimes be a challenge in less touristy spots.
#
# 2. **Basic Nepali Phrases:**
#    - Learning a few key Nepali phrases can enhance your experience and help you connect with locals:
#      - **Namaste** (नमस्ते) – Hello
#      - **Dhanyabad** (धन्यवाद) – Thank you
#      - **Maaf garnus** (माफ गर्नुहोस्) – Sorry
#      - **Kati ho?** (कति हो?) – How much?
#      - **Pani cha?** (पानी छ?) – Do you have water?
#
# 3. **Non-Verbal Communication:**
#    - A friendly smile and the traditional greeting "Namaste" go a long way in fostering goodwill.
#
# 4. **Transportation Communication:**
#    - When hiring taxis or private vehicles, confirm the fare in advance. Write down or show the destination name to avoid miscommunication.
#
# 5. **Restaurant Etiquette:**
#    - While menus in major tourist hubs are usually in English, smaller eateries might have Nepali-only menus. Knowing food-related words like "momo" (dumplings) or "dal bhat" (lentils and rice) can be helpful.
#
# 6. **Emergency Communication:**
#    - Save important contact numbers, such as your hotel, embassy, and emergency services (dial 100 for police assistance).
#
# ### **Assessment of Current Plan**
# The trip itinerary is excellent in terms of activities and logistics, but integrating language tips would make it more comprehensive for travelers unfamiliar with Nepali culture and communication norms. Adding these small yet impactful adjustments ensures smoother interactions and a richer cultural experience.
#
# Let me know if you'd like these language tips incorporated into the itinerary or if you need further assistance!
# ---------- travel_summary_agent ----------
# ### Final Integrated Travel Plan: 3-Day Nepal Trip
#
# Nepal is a land of breathtaking landscapes, rich culture, and warm hospitality. This itinerary combines cultural exploration, scenic beauty, soft adventure, and practical communication tips to make your trip seamless and enjoyable.
#
# ---
#
# ### **Day 1: Arrival in Kathmandu and Exploring the Cultural Heritage**
# **Morning:**
# - **Arrival in Kathmandu:** Land at Tribhuvan International Airport. After clearing customs, meet your pre-arranged transportation or taxi and head to your hotel or guesthouse.
# - **Breakfast:** Enjoy a Nepali breakfast, such as "chiura" (beaten rice), "dahi" (yogurt), or chapati with tea.
#
# **Mid-Morning:**
# - **Kathmandu Durbar Square:** Visit this UNESCO World Heritage Site, a historic plaza with ancient temples and palaces.
#   - **Language Tip:** Use "Dhanyabad" (Thank you) when interacting with locals—politeness is appreciated.
# - **Swayambhunath (Monkey Temple):** Drive to this iconic stupa with panoramic views of Kathmandu Valley.
#
# **Lunch:**
# - Savor dal bhat (lentil soup and rice) or momos (dumplings) at a local restaurant in Thamel.
#
# **Afternoon:**
# - **Pashupatinath Temple:** Visit this sacred Hindu temple and witness evening rituals along the Bagmati River.
#   - **Tip:** "Maaf garnus" (Sorry) is helpful if you accidentally interrupt ceremonies or rituals.
# - **Boudhanath Stupa:** Explore this massive Buddhist stupa, a serene site with Tibetan culture influences.
#
# **Evening:**
# - **Dinner in Thamel:** Dine at a rooftop restaurant and try Newari cuisine or international options.
#   - **Tip:** "Kati ho?" (How much?) is useful when shopping or paying for services.
# - **Overnight Stay:** Stay at a comfortable hotel or guesthouse in Kathmandu.
#
# ---
#
# ### **Day 2: Scenic Adventure in Pokhara**
# **Morning:**
# - **Travel to Pokhara:** Take an early morning flight (25 minutes) or drive (6-7 hours) to Pokhara. Check into your lakeside hotel.
# - **Breakfast:** Have breakfast with views of the Annapurna mountain range.
#
# **Mid-Morning:**
# - **Boating on Phewa Lake:** Rent a boat to enjoy the tranquil waters of Phewa Lake. Visit Tal Barahi Temple on the lake's island.
#   - **Tip:** "Pani cha?" (Do you have water?) can be handy during outings.
# - **Davis Falls and Gupteshwor Cave:** Explore these natural wonders nearby.
#
# **Lunch:**
# - Enjoy a lakeside meal with stunning views of the mountains and lake.
#
# **Afternoon:**
# - **Peace Pagoda:** Hike or drive to the World Peace Pagoda for panoramic views of Pokhara and the Himalayas.
# - **Bindhyabasini Temple:** Visit this sacred Hindu temple dedicated to Goddess Durga.
#
# **Evening:**
# - **Relax at Lakeside:** Walk along the vibrant Lakeside area, known for its cafes and shops.
# - **Dinner:** Try Nepali and continental cuisine at a local restaurant.
# - **Overnight Stay:** Stay at a lakeside hotel or resort.
#
# ---
#
# ### **Day 3: Sunrise and Return to Kathmandu**
# **Early Morning:**
# - **Sarangkot Sunrise View:** Drive to Sarangkot to witness the sunrise over the Annapurna and Dhaulagiri ranges—a must-see for photographers.
#
# **Breakfast:**
# - Return to Pokhara for breakfast with mountain views.
#
# **Mid-Morning:**
# - **Adventure Activity (Optional):** Try paragliding or zip-lining for a thrilling experience.
#
# **Lunch:**
# - Enjoy a hearty meal in Pokhara before heading back.
#
# **Afternoon:**
# - **Travel Back to Kathmandu:** Take an afternoon flight or drive back to Kathmandu to conclude your trip.
#
# **Evening:**
# - **Shopping in Thamel:** Pick up souvenirs like pashmina shawls, prayer flags, or handicrafts.
#   - **Tip:** Bargaining is common in Nepal. Be polite and use "Kati ho?" (How much?) to ask prices.
# - **Relaxing Dinner:** End your trip with a farewell dinner at a traditional Nepali restaurant, accompanied by cultural dance performances.
# - **Overnight Stay:** Stay at a hotel in Kathmandu or prepare for your departure.
#
# ---
#
# ### **Additional Tips**
# 1. **Visa and Entry:** Ensure your Nepal visa is ready (available on arrival for many nationalities).
# 2. **Currency:** Use Nepalese Rupees (NPR) for transactions; cash is preferred in local markets.
# 3. **Packing:** Bring layers for varying temperatures and comfortable shoes for walking and light hiking.
# 4. **Emergency Contacts:** Save hotel numbers, embassy details, and emergency services (dial 100 for police).
# 5. **Basic Nepali Phrases:**
#    - **Namaste** (Hello)
#    - **Dhanyabad** (Thank you)
#    - **Kati ho?** (How much?)
#    - **Pani cha?** (Do you have water?)
#
# This integrated itinerary combines cultural exploration, scenic beauty, adventure, and practical communication tips to ensure a memorable and hassle-free experience in Nepal.
#
# ---
#
# **Ready to pack your bags for Nepal? Let me know if there's anything else you'd like to add or modify!**
#
# TERMINATE
