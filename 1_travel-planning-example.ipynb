# %%
#%pip install -U "autogen-agentchat"
#%pip install -U "autogen-agentchat[azure]"
#%pip install -U autogenstudio

# %%
from autogen_agentchat.agents import AssistantAgent
from autogen_agentchat.conditions import TextMentionTermination
from autogen_agentchat.teams import RoundRobinGroupChat
from autogen_agentchat.ui import Console
from autogen_ext.models.openai import AzureOpenAIChatCompletionClient

# %%
model_client = AzureOpenAIChatCompletionClient(
    azure_deployment="gpt-4o",
    azure_endpoint="https://aq-aoai-swedencentral.openai.azure.com/",
    model="gpt-4o",
    api_version="2025-03-01-preview",
    api_key="3ShjYyRHd6t0VthIuoOUe1GEnwlj1tkNSHkOs6IrO1CxKQ3gHmsIJQQJ99BAACfhMk5XJ3w3AAABACOG3ddZ",
    temperature=0.7,
)

# %%
planner_agent = AssistantAgent(
    "planner_agent",
    model_client=model_client,
    description="A helpful assistant that can plan trips.",
    system_message="You are a helpful assistant that can suggest a travel plan for a user based on their request.",
)

local_agent = AssistantAgent(
    "local_agent",
    model_client=model_client,
    description="A local assistant that can suggest local activities or places to visit.",
    system_message="You are a helpful assistant that can suggest authentic and interesting local activities or places to visit for a user and can utilize any context information provided.",
)

language_agent = AssistantAgent(
    "language_agent",
    model_client=model_client,
    description="A helpful assistant that can provide language tips for a given destination.",
    system_message="You are a helpful assistant that can review travel plans, providing feedback on important/critical tips about how best to address language or communication challenges for the given destination. If the plan already includes language tips, you can mention that the plan is satisfactory, with rationale.",
)

travel_summary_agent = AssistantAgent(
    "travel_summary_agent",
    model_client=model_client,
    description="A helpful assistant that can summarize the travel plan.",
    system_message="You are a helpful assistant that can take in all of the suggestions and advice from the other agents and provide a detailed final travel plan. You must ensure that the final plan is integrated and complete. YOUR FINAL RESPONSE MUST BE THE COMPLETE PLAN. When the plan is complete and all perspectives are integrated, you can respond with TERMINATE.",
)

# %%
termination = TextMentionTermination("TERMINATE")
group_chat = RoundRobinGroupChat(
    [planner_agent, local_agent, language_agent, travel_summary_agent], termination_condition=termination
)
await Console(group_chat.run_stream(task="Plan a 3 day trip to Nepal."))

await model_client.close()
# Out:
# ---------- user ----------
# Plan a 3 day trip to Nepal.
# ---------- planner_agent ----------
# Nepal is a stunning destination packed with natural beauty, cultural richness, and adventurous activities. Here’s a 3-day trip plan to help you experience the best of Nepal, focusing on Kathmandu Valley and its surroundings. This itinerary balances cultural exploration, scenic views, and light adventure:
#
# ---
#
# ### **Day 1: Arrival in Kathmandu & Exploring Kathmandu Valley**
# - **Morning: Arrival**
#   - Arrive at Tribhuvan International Airport in Kathmandu.
#   - Check into your hotel (recommendations: Thamel area for budget options or boutique stays).
#   - Freshen up and prepare for the day.
#
# - **Late Morning: Explore Kathmandu Durbar Square**
#   - Visit Kathmandu Durbar Square, a UNESCO World Heritage Site.
#   - Explore the ancient royal palace, temples, courtyards, and bustling markets.
#   - Learn about Nepalese architecture and history.
#
# - **Afternoon: Swayambhunath Stupa (Monkey Temple)**
#   - Head to Swayambhunath Stupa, a hilltop Buddhist temple offering panoramic views of Kathmandu Valley.
#   - Observe beautiful prayer flags, spinning prayer wheels, and the resident monkeys.
#
# - **Evening: Thamel District**
#   - Stroll around the vibrant streets of Thamel, Kathmandu's tourist hub.
#   - Shop for souvenirs like pashminas, handicrafts, and traditional jewelry.
#   - Enjoy a traditional Nepalese dinner at a local restaurant (try dal bhat, momo dumplings, or Newari cuisine).
#
# ---
#
# ### **Day 2: Day Trip to Bhaktapur & Patan**
# - **Morning: Bhaktapur**
#   - Take a short drive to Bhaktapur, another UNESCO World Heritage Site.
#   - Explore Bhaktapur Durbar Square, famous for its medieval architecture, pottery square, and Nyatapola Temple.
#   - Try the local delicacy, "Juju Dhau" (king curd), a creamy yogurt made in Bhaktapur.
#
# - **Afternoon: Patan**
#   - Drive to Patan (Lalitpur), known for its rich arts and crafts heritage.
#   - Visit Patan Durbar Square and the Patan Museum to see ancient artwork and sculptures.
#   - Admire the Golden Temple (Hiranya Varna Mahavihar), a stunning Buddhist site.
#
# - **Evening: Relax & Dinner**
#   - Return to Kathmandu.
#   - Enjoy dinner at a rooftop restaurant with views of the city lights.
#
# ---
#
# ### **Day 3: Sunrise & Himalayan Adventure**
# - **Early Morning: Nagarkot Sunrise**
#   - Take a pre-dawn drive to Nagarkot, a hill station near Kathmandu, known for its spectacular sunrise views over the Himalayas (including Mt. Everest on clear days).
#   - Enjoy the serene atmosphere and snap breathtaking photos.
#
# - **Morning: Short Nature Walk**
#   - Take a light hike or nature walk around Nagarkot to enjoy the landscapes and greenery.
#
# - **Afternoon: Return to Kathmandu**
#   - Drive back to Kathmandu and visit Pashupatinath Temple, a sacred Hindu site located along the Bagmati River.
#   - If time permits, visit Boudhanath Stupa, one of the largest Buddhist stupas in the world.
#
# - **Evening: Departure or Relaxation**
#   - Depending on your flight schedule, relax and enjoy your final moments in Nepal.
#   - If you have extra time, indulge in a traditional Nepali spa or massage before departing for the airport.
#
# ---
#
# ### **Additional Tips:**
# - **Transportation:** Hire a private car or taxi for easy travel between destinations, or ask your hotel for assistance.
# - **Packing:** Bring comfortable walking shoes, layers for cool mornings, and sunscreen.
# - **Currency:** Carry Nepalese Rupees for local purchases.
# - **Time of Visit:** October to March is ideal for pleasant weather and clear mountain views.
#
# This 3-day itinerary provides a mix of cultural immersion, scenic beauty, and light adventure. Let me know if you'd like adjustments or alternative suggestions!
# /Users/arturoquiroga/AUTOGEN for 3CLOUD/.venv/lib/python3.13/site-packages/autogen_agentchat/agents/_assistant_agent.py:870: UserWarning: Resolved model mismatch: gpt-4o-2024-08-06 != gpt-4o-2024-11-20. Model mapping in autogen_ext.models.openai may be incorrect. Set the model to gpt-4o-2024-11-20 to enhance token/cost estimation and suppress this warning.
#   model_result = await model_client.create(
# ---------- local_agent ----------
# Would you like recommendations for specific accommodations, restaurants, or activities tailored to your interests (e.g., trekking, spirituality, or food)? Let me know if you have preferences or travel goals!
# Would you like recommendations for specific accommodations, restaurants, or activities tailored to your interests (e.g., trekking, spirituality, or food)? Let me know if you have preferences or travel goals!
# ---------- language_agent ----------
# This is a well-rounded itinerary for a short trip to Nepal. However, I'd like to address potential language or communication challenges you may encounter during your visit and provide tips to enhance your experience.
#
# ### **Language and Communication Tips for Nepal:**
# 1. **Official Language:** Nepali is the official language of Nepal. English is widely spoken in tourist areas like Kathmandu, Pokhara, and Thamel, but it may be less common in rural areas.
#
# 2. **Key Phrases in Nepali:**
#    - **Namaste** (नमस्ते): Hello/Greetings.
#    - **Dhanyabad** (धन्यवाद): Thank you.
#    - **Maaf garnu hos** (माफ गर्नुहोस्): Excuse me/Sorry.
#    - **Kati ho?** (कति हो?): How much?
#    - **Ho** (हो): Yes and **Hoina** (होइन): No.
#    - **Pani cha?** (पानी छ?): Do you have water?
#
# 3. **Translation Apps:** Consider downloading a language translation app like Google Translate for quick assistance. You can also download the Nepali language pack for offline use.
#
# 4. **Body Language:** Nepalis are known for their warm hospitality. A polite tone, a smile, and the traditional "Namaste" gesture (hands pressed together) go a long way in fostering positive interactions.
#
# 5. **Menus and Signs:** In tourist hubs, menus and signs are often bilingual (Nepali and English). However, in more remote areas, you may encounter only Nepali text. Asking locals politely for assistance usually works well.
#
# 6. **Hiring Guides:** For places like Bhaktapur or Nagarkot, consider hiring a local guide who speaks English. This will enhance your understanding of the culture, history, and significance of the sites.
#
# ### **Conclusion:**
# If you incorporate these language tips, your plan will be satisfactory for Nepal. The itinerary already includes engaging cultural and scenic experiences, and with a bit of preparation for communication, you'll be well-equipped to enjoy your trip smoothly! Let me know if you need more tailored advice. Safe travels!
# ---------- travel_summary_agent ----------
# ### **Final Integrated 3-Day Nepal Travel Plan**
#
# This plan combines cultural exploration, scenic beauty, and practical tips to ensure a seamless and enriching travel experience in Nepal.
#
# ---
#
# ### **Day 1: Arrival in Kathmandu & Exploring Kathmandu Valley**
# - **Morning: Arrival**
#   - Arrive at Tribhuvan International Airport in Kathmandu.
#   - Check into your hotel (recommendations: **Thamel** for convenience, with options like Kathmandu Guest House for budget travelers or Hotel Yak & Yeti for luxury).
#   - Freshen up and prepare for the day.
#
# - **Late Morning: Explore Kathmandu Durbar Square**
#   - Visit **Kathmandu Durbar Square**, a UNESCO World Heritage Site.
#   - Explore the ancient royal palace, temples, and courtyards.
#   - Visit the Kumari Ghar to learn about the living goddess tradition.
#   - Enjoy street snacks like samosas or sel roti (traditional Nepali rice donuts).
#
# - **Afternoon: Swayambhunath Stupa (Monkey Temple)**
#   - Head to **Swayambhunath Stupa**, a hilltop Buddhist temple offering panoramic views of Kathmandu Valley.
#   - Observe colorful prayer flags, spinning prayer wheels, and monkeys.
#   - Capture stunning sunset photographs if you stay until evening.
#
# - **Evening: Thamel District**
#   - Stroll through the vibrant streets of **Thamel**, Kathmandu’s cultural and tourist hub.
#   - Shop for souvenirs like pashminas, handicrafts, and singing bowls.
#   - Enjoy a traditional Nepali dinner at a recommended restaurant like **OR2K** for vegetarian options or **Nepali Chulo** for authentic Newari cuisine.
#
# ---
#
# ### **Day 2: Day Trip to Bhaktapur & Patan**
# - **Morning: Bhaktapur**
#   - Take a short drive to **Bhaktapur**, another UNESCO World Heritage Site.
#   - Explore **Bhaktapur Durbar Square**, famous for its medieval architecture, pottery square, and Nyatapola Temple.
#   - Sample local delicacies like **Juju Dhau** (king curd) and observe artisans creating pottery.
#   - Use key Nepali phrases ("Namaste," "Dhanyabad") to connect with locals and enrich your experience.
#
# - **Afternoon: Patan**
#   - Drive to **Patan (Lalitpur)**, known for its arts and crafts heritage.
#   - Visit **Patan Durbar Square** and the **Patan Museum** to see ancient artwork and sculptures.
#   - Admire the **Golden Temple (Hiranya Varna Mahavihar)**, a beautiful Buddhist monastery.
#   - Shop for handmade jewelry or wooden carvings at local markets.
#
# - **Evening: Relaxation & Dinner**
#   - Return to Kathmandu and relax at your hotel or a rooftop restaurant.
#   - For dinner, try **Roadhouse Café** for a mix of Nepali and international cuisine or **Himalayan Java** for great coffee and pastries.
#
# ---
#
# ### **Day 3: Sunrise & Himalayan Adventure**
# - **Early Morning: Nagarkot Sunrise**
#   - Drive pre-dawn to **Nagarkot**, a hill station near Kathmandu, to witness a spectacular sunrise over the Himalayas (with potential views of Mt. Everest on clear days).
#   - Enjoy the serene atmosphere and take unforgettable photos.
#   - Comfortable layers are essential for the cool morning temperatures.
#
# - **Morning: Nature Walk**
#   - Take a light hike or nature walk around Nagarkot. Trails like **Nagarkot View Tower** offer panoramic views of the surrounding landscapes.
#   - Interact with locals using simple Nepali phrases ("Pani cha?" for water or "Dhanyabad" for gratitude).
#
# - **Afternoon: Return to Kathmandu**
#   - Drive back to Kathmandu and visit **Pashupatinath Temple**, a sacred Hindu site along the Bagmati River.
#   - Observe cremation rituals at the ghats respectfully and learn about Hindu spiritual practices.
#   - If time permits, visit **Boudhanath Stupa**, one of the largest Buddhist stupas in the world, and walk around its prayer wheel.
#
# - **Evening: Departure or Relaxation**
#   - Depending on your flight schedule, relax and enjoy your final moments in Nepal.
#   - Indulge in a traditional **Nepali spa or massage** (recommended: Tranquility Spa in Thamel) to unwind.
#   - Head to Tribhuvan International Airport for departure.
#
# ---
#
# ### **Additional Tips:**
# 1. **Transportation:** Arrange private car hire or taxis for easier navigation, especially for day trips like Nagarkot or Bhaktapur.
# 2. **Packing Essentials:** Comfortable walking shoes, layers for varying temperatures, sunscreen, and a reusable water bottle.
# 3. **Currency:** Bring Nepalese Rupees for local purchases; ATMs are available in Kathmandu and tourist areas.
# 4. **Language Assistance:** Use basic Nepali phrases or a translation app like Google Translate for smoother communication.
# 5. **Best Time to Visit:** October to March offers ideal weather and clear mountain views.
# 6. **Local Guides:** Hiring licensed guides at sites like Bhaktapur or Nagarkot can enhance your understanding of the culture and history.
#
# ---
#
# ### **Summary**
# This 3-day trip plan offers you a balanced mix of cultural immersion, scenic beauty, and light adventure. With visits to UNESCO World Heritage Sites, stunning Himalayan views, and delicious local food, you’ll experience the richness of Nepal. Language tips and practical advice ensure smooth communication and navigation throughout your journey.
#
# Enjoy your trip to Nepal, and let me know if you need further adjustments or details!
#
# **TERMINATE**
