# %%
#%pip install -U "autogen-agentchat"
#%pip install -U "autogen-agentchat[azure]"
#%pip install -U autogenstudio
# %pip install python-dotenv

# %% [markdown]
# ## Example team of AI Assistant agents in a ROUND ROBIN CHATGROUP team

# %%
from autogen_agentchat.agents import AssistantAgent
from autogen_agentchat.conditions import TextMentionTermination
from autogen_agentchat.teams import RoundRobinGroupChat
from autogen_agentchat.ui import Console
from autogen_ext.models.openai import AzureOpenAIChatCompletionClient
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
model_client = AzureOpenAIChatCompletionClient(
    azure_deployment="gpt-4o",
    azure_endpoint="https://aq-aoai-swedencentral.openai.azure.com/",
    model="gpt-4o",
    api_version="2025-03-01-preview",
    api_key="3ShjYyRHd6t0VthIuoOUe1GEnwlj1tkNSHkOs6IrO1CxKQ3gHmsIJQQJ99BAACfhMk5XJ3w3AAABACOG3ddZ",
    temperature=0.7,
)

# %%
planner_agent = AssistantAgent(
    "planner_agent",
    model_client=model_client,
    description="A helpful assistant that can plan trips.",
    system_message="You are a helpful assistant that can suggest a travel plan for a user based on their request.",
)

local_agent = AssistantAgent(
    "local_agent",
    model_client=model_client,
    description="A local assistant that can suggest local activities or places to visit.",
    system_message="You are a helpful assistant that can suggest authentic and interesting local activities or places to visit for a user and can utilize any context information provided.",
)

language_agent = AssistantAgent(
    "language_agent",
    model_client=model_client,
    description="A helpful assistant that can provide language tips for a given destination.",
    system_message="You are a helpful assistant that can review travel plans, providing feedback on important/critical tips about how best to address language or communication challenges for the given destination. If the plan already includes language tips, you can mention that the plan is satisfactory, with rationale.",
)

travel_summary_agent = AssistantAgent(
    "travel_summary_agent",
    model_client=model_client,
    description="A helpful assistant that can summarize the travel plan.",
    system_message="You are a helpful assistant that can take in all of the suggestions and advice from the other agents and provide a detailed final travel plan. You must ensure that the final plan is integrated and complete. YOUR FINAL RESPONSE MUST BE THE COMPLETE PLAN. When the plan is complete and all perspectives are integrated, you can respond with TERMINATE.",
)

# %%
termination = TextMentionTermination("TERMINATE")
group_chat = RoundRobinGroupChat(
    [planner_agent, local_agent, language_agent, travel_summary_agent], termination_condition=termination
)
await Console(group_chat.run_stream(task="Plan a 3 day trip to Nepal."))

await model_client.close()
# Out:
# ---------- user ----------
# Plan a 3 day trip to Nepal.
# ---------- planner_agent ----------
# Nepal is a land of stunning natural beauty, rich culture, and incredible experiences. A 3-day trip is short but can still be packed with amazing highlights. Here's a suggested itinerary for your trip:
#
# ---
#
# ### **Day 1: Arrival in Kathmandu**
# **Morning:**
# - **Arrival at Tribhuvan International Airport:** Land in Kathmandu, Nepal's capital city. You'll be greeted by stunning views of the Himalayas as you land.
# - **Check-in to your hotel:** Choose a hotel in Thamel, a lively tourist hub with cozy accommodation, restaurants, and shops.
# - **Breakfast or lunch:** Enjoy Nepali cuisine, such as momo (dumplings) or dal bhat (lentil soup with rice).
#
# **Afternoon:**
# - **Explore Kathmandu Durbar Square:** A UNESCO World Heritage Site, this ancient palace square is home to stunning architecture, historical monuments, and the Living Goddess (Kumari).
# - **Swayambhunath (Monkey Temple):** Visit this iconic Buddhist stupa perched on a hill with panoramic views of Kathmandu Valley.
#
# **Evening:**
# - **Stroll around the Thamel area:** Shop for souvenirs like pashmina shawls, handicrafts, or trekking gear.
# - **Dinner:** Try authentic Nepali or Tibetan dishes at a local restaurant.
#
# ---
#
# ### **Day 2: Bhaktapur and Patan**
# **Morning:**
# - **Drive to Bhaktapur (30–40 mins):** Explore this ancient city, another UNESCO World Heritage Site, known for its well-preserved medieval architecture. Visit the Nyatapola Temple, pottery square, and enjoy juju dhau (a local sweet yogurt).
# - **Breakfast in Bhaktapur:** Try the local cuisine here.
#
# **Afternoon:**
# - **Drive to Patan (30–40 mins):** Visit Patan Durbar Square, a UNESCO World Heritage Site showcasing stunning Newari architecture. Explore the Patan Museum and admire the intricate carvings on temples.
#
# **Evening:**
# - **Dinner in Patan:** Dine at a rooftop restaurant overlooking the square or head back to Kathmandu for dinner.
# - **Optional: Night walk in Thamel or Garden of Dreams:** Relax in this serene neo-classical garden.
#
# ---
#
# ### **Day 3: Sunrise at Nagarkot & Departure**
# **Early Morning:**
# - **Drive to Nagarkot (1.5 hours):** Wake up early to catch the sunrise over the Himalayas, including views of Mt. Everest on clear days.
# - **Breakfast in Nagarkot:** Enjoy breakfast with a view before heading back to Kathmandu.
#
# **Late Morning:**
# - **Visit Pashupatinath Temple:** A sacred Hindu temple dedicated to Lord Shiva, located on the banks of the Bagmati River.
# - **Boudhanath Stupa:** One of the largest spherical stupas in the world, a UNESCO World Heritage Site and a peaceful place to explore Tibetan Buddhist culture.
#
# **Afternoon:**
# - **Lunch in Boudhanath:** Try Tibetan food such as thukpa (noodle soup) or yak cheese dishes.
#
# **Departure:**
# - Head to the airport for your flight home. Depending on your flight time, you can squeeze in some last-minute shopping or relaxation at your hotel.
#
# ---
#
# ### **Additional Tips:**
# - **Transportation:** Hire a private car or taxi for convenience, or join a guided tour. Public transport is available but can be time-consuming.
# - **Currency:** The local currency is Nepalese Rupee (NPR), so ensure you have some cash for small expenses.
# - **Packing:** Bring comfortable walking shoes, layers for varying temperatures, and sunscreen.
# - **Altitude:** Kathmandu and nearby areas are at manageable altitudes, so no acclimatization is needed.
#
# This 3-day itinerary focuses on culture, heritage, and scenic beauty, giving you a taste of Nepal’s magic! Let me know if you'd like to modify or add anything. Safe travels!
# /Users/arturoquiroga/3CLOUD-AUTOGEN/.venv/lib/python3.13/site-packages/autogen_agentchat/agents/_assistant_agent.py:870: UserWarning: Resolved model mismatch: gpt-4o-2024-08-06 != gpt-4o-2024-11-20. Model mapping in autogen_ext.models.openai may be incorrect. Set the model to gpt-4o-2024-11-20 to enhance token/cost estimation and suppress this warning.
#   model_result = await model_client.create(
# ---------- local_agent ----------
# Would you like recommendations for specific hotels or restaurants in these areas? Or perhaps tips for navigating cultural norms in Nepal? Let me know if you’d like to customize your trip further!
# Would you like recommendations for specific hotels or restaurants in these areas? Or perhaps tips for navigating cultural norms in Nepal? Let me know if you’d like to customize your trip further!
# ---------- language_agent ----------
# This plan seems well-thought-out and covers many key highlights of Nepal within a short timeframe. However, I’ll provide feedback and tips regarding language and communication challenges that travelers may face in Nepal:
#
# ### **Language and Communication Tips:**
# 1. **Official Language:** The official language in Nepal is Nepali. While many people in tourist areas speak English, learning a few basic phrases in Nepali can help you connect better with locals:
#    - **Namaste**: Hello/Greetings
#    - **Dhanyabad**: Thank you
#    - **Maaf garnu hos**: Sorry/Excuse me
#    - **Kati ho?**: How much is this?
#
# 2. **Politeness and Tone:** Nepali culture values politeness. Using a warm and respectful tone when communicating, even if there’s a language barrier, will be appreciated.
#
# 3. **Body Language:** Non-verbal communication can go a long way. A friendly smile or a nod can help build rapport in situations where language differences exist.
#
# 4. **Written Communication:** Carrying a notebook or using a translation app can help if you need to write down specific instructions, especially if hiring a taxi or negotiating prices.
#
# 5. **Signs and Menus:** In tourist areas like Kathmandu, many signs and restaurant menus are available in English. However, in less touristy spots like Bhaktapur or Nagarkot, you may encounter only Nepali text. Translation apps like Google Translate can be helpful here.
#
# 6. **Avoid Miscommunication:** When making arrangements (e.g., for transportation or tours), confirm details like cost, time, and destinations to avoid misunderstandings.
#
# ### **Feedback on Your Plan:**
# This itinerary already focuses on tourist-friendly areas where English is widely spoken, such as Thamel, Durbar Squares, and Nagarkot. If you follow these language tips, the plan should be satisfactory for a smooth trip.
#
# Would you like advice on specific Nepali phrases or details on how to use translation apps effectively during your trip? Let me know!
# ---------- travel_summary_agent ----------
# Here’s the finalized and integrated 3-day trip plan to Nepal, incorporating all perspectives and suggestions:
#
# ---
#
# ### **Day 1: Arrival in Kathmandu**
# **Morning:**
# - **Arrival at Tribhuvan International Airport:** Land in Kathmandu and enjoy Himalayan views from the plane. After immigration, arrange transport to Thamel (20–30 minutes drive).
# - **Check-in to your hotel:** Recommended options in Thamel include Kathmandu Guest House or Hotel Mulberry for comfort and convenience.
# - **Breakfast or lunch:** Savor Nepali cuisine at Rosemary Kitchen or OR2K, known for their diverse menus and friendly ambiance.
#
# **Afternoon:**
# - **Explore Kathmandu Durbar Square:** A UNESCO World Heritage Site with ancient temples and the Living Goddess (Kumari). Entry fees are applicable for foreigners, so carry cash in Nepalese Rupees.
# - **Swayambhunath (Monkey Temple):** Marvel at the stupa, prayer flags, and panoramic views of Kathmandu Valley. Prepare for a short hike up the stairs.
#
# **Evening:**
# - **Stroll around Thamel:** Shop for souvenirs like pashmina shawls, handmade crafts, and trekking gear.
# - **Dinner:** Try Nepali or Tibetan dishes at Thamel House Restaurant. Don’t miss momos (dumplings) and dal bhat (lentil soup with rice).
#
# **Language Tip:** Greet locals with “Namaste” for a warm connection, and use polite phrases like “Dhanyabad” (thank you) to show appreciation.
#
# ---
#
# ### **Day 2: Bhaktapur and Patan**
# **Morning:**
# - **Drive to Bhaktapur:** Arrange a private car or taxi (30–40 minutes). Explore Nyatapola Temple, 55-Window Palace, and pottery square. Try juju dhau, the famous local yogurt, at a street vendor or café.
# - **Breakfast in Bhaktapur:** Café Nyatapola offers a great breakfast with views of the square.
#
# **Afternoon:**
# - **Drive to Patan:** Visit Patan Durbar Square, another UNESCO World Heritage Site. Explore the Patan Museum to learn about Newari art and culture. Admire the Krishna Mandir and other intricately carved temples.
# - **Lunch:** Dine at Café Swotha or the Patan Museum Café for local and international dishes.
#
# **Evening:**
# - **Return to Kathmandu:** Relax at the Garden of Dreams, a peaceful neo-classical garden near Thamel. Alternatively, explore Thamel at night for vibrant shops and music.
# - **Dinner:** Head back to Thamel for a rooftop dinner at The Ship Restaurant or The Black Olive.
#
# **Local Tip:** Respect temple customs; remove shoes before entering and avoid pointing your feet at religious sites.
#
# ---
#
# ### **Day 3: Sunrise at Nagarkot & Departure**
# **Early Morning:**
# - **Drive to Nagarkot:** Leave early (around 4:00 AM) to catch the spectacular sunrise over the Himalayas, including Mt. Everest on clear days. Arrange transportation in advance (1.5-hour drive).
# - **Breakfast in Nagarkot:** Enjoy a simple breakfast at Club Himalaya or other scenic hotels with mountain views.
#
# **Late Morning:**
# - **Visit Pashupatinath Temple:** A sacred Hindu site dedicated to Lord Shiva, located along the Bagmati River. Witness rituals and observe the spiritual ambiance.
# - **Explore Boudhanath Stupa:** This enormous Buddhist stupa is peaceful and rich in Tibetan culture. Circumambulate the stupa clockwise, spinning prayer wheels, as a sign of respect.
#
# **Afternoon:**
# - **Lunch in Boudhanath:** Try Tibetan dishes like thukpa (noodle soup) or yak cheese at the Stupa View Restaurant.
#
# **Departure:**
# - Return to your hotel to pack or freshen up. Depending on your flight time, visit local shops for last-minute souvenirs. Head to Tribhuvan International Airport for your departure.
#
# **Language Note:** Carry a translation app for local areas where English signage may be limited. Use polite gestures and confirm arrangements in advance to avoid miscommunication.
#
# ---
#
# ### **Additional Tips:**
# 1. **Transportation:** Renting a private car ensures efficiency. Alternatively, hire taxis but confirm costs beforehand.
# 2. **Packing Essentials:** Comfortable walking shoes, sunscreen, a hat, and layers for Kathmandu’s varying temperatures. Bring a small daypack for excursions.
# 3. **Cultural Etiquette:** Always ask permission before taking photos of people. Avoid touching items at religious sites unless invited.
# 4. **Currency:** Nepalese Rupee (NPR) is the local currency. Carry cash for entry fees, small shops, and tips. Larger establishments accept credit cards.
# 5. **Health Precautions:** Drink bottled or filtered water to avoid stomach issues. Carry basic medication for emergencies.
#
# By following this plan, you’ll experience Nepal’s rich culture, breathtaking scenery, and warm hospitality, all within three days.
#
# TERMINATE
