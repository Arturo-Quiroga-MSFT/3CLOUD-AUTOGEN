# %%
#%pip install -U "autogen-agentchat"
#%pip install -U "autogen-agentchat[azure]"
#%pip install -U autogenstudio
# %pip install python-dotenv

# %% [markdown]
# ## Example team of AI Assistant agents in a ROUND ROBIN CHATGROUP team

# %%
from autogen_agentchat.agents import AssistantAgent
from autogen_agentchat.conditions import TextMentionTermination
from autogen_agentchat.teams import RoundRobinGroupChat
from autogen_agentchat.ui import Console
from autogen_ext.models.openai import AzureOpenAIChatCompletionClient
from dotenv import load_dotenv
load_dotenv()
import yaml

# %%
with open("model_config.yaml", "r") as f:
        model_config = yaml.safe_load(f)
model_client = AzureOpenAIChatCompletionClient.load_component(model_config)

# %%
planner_agent = AssistantAgent(
    "planner_agent",
    model_client=model_client,
    description="A helpful assistant that can plan trips.",
    system_message="You are a helpful assistant that can suggest a travel plan for a user based on their request.",
)

local_agent = AssistantAgent(
    "local_agent",
    model_client=model_client,
    description="A local assistant that can suggest local activities or places to visit.",
    system_message="You are a helpful assistant that can suggest authentic and interesting local activities or places to visit for a user and can utilize any context information provided.",
)

language_agent = AssistantAgent(
    "language_agent",
    model_client=model_client,
    description="A helpful assistant that can provide language tips for a given destination.",
    system_message="You are a helpful assistant that can review travel plans, providing feedback on important/critical tips about how best to address language or communication challenges for the given destination. If the plan already includes language tips, you can mention that the plan is satisfactory, with rationale.",
)

travel_summary_agent = AssistantAgent(
    "travel_summary_agent",
    model_client=model_client,
    description="A helpful assistant that can summarize the travel plan.",
    system_message="You are a helpful assistant that can take in all of the suggestions and advice from the other agents and provide a detailed final travel plan. You must ensure that the final plan is integrated and complete. YOUR FINAL RESPONSE MUST BE THE COMPLETE PLAN. When the plan is complete and all perspectives are integrated, you can respond with TERMINATE.",
)

# %%
termination = TextMentionTermination("TERMINATE")
group_chat = RoundRobinGroupChat(
    [planner_agent, local_agent, language_agent, travel_summary_agent], termination_condition=termination
)
await Console(group_chat.run_stream(task="Plan a 3 day trip to Nepal."))

await model_client.close()
# Out:
# ---------- TextMessage (user) ----------
# Plan a 3 day trip to Nepal.
# ---------- TextMessage (planner_agent) ----------
# Nepal, often called the "Land of the Himalayas," offers stunning landscapes, cultural richness, and adventure for travelers. Whether you're seeking nature, history, or relaxation, a three-day trip can provide a memorable experience. Here's a well-rounded itinerary tailored for your short trip:
#
# ### **3-Day Nepal Itinerary**
# #### **Day 1: Kathmandu – History, Culture, and Heritage**
# Kathmandu, the capital city, is a vibrant destination filled with ancient temples, UNESCO World Heritage sites, and bustling bazaars.
#
# **Morning: Exploration of UNESCO World Heritage Sites**
# - **Pashupatinath Temple**: Start your day at this iconic Hindu temple complex dedicated to Lord Shiva, located by the Bagmati River.
# - **Boudhanath Stupa**: Visit one of the largest and most beautiful Buddhist stupas in the world, a serene and spiritual experience.
#
# **Afternoon: Kathmandu Durbar Square**
# - Explore the historic Kathmandu Durbar Square, famous for its ancient palaces, courtyards, and temples. Don't miss the Kumari Ghar, the residence of the living goddess.
# - Stop by the nearby Freak Street, known for its historical significance as a hippie hub in the 1960s.
#
# **Evening: Thamel for Shopping and Local Dining**
# - Head to Thamel, Kathmandu's vibrant tourist hub, for souvenirs such as prayer flags, pashmina shawls, and handicrafts.
# - Enjoy a traditional Nepali dinner at a restaurant such as **Rosemary Kitchen** or **Thakali Bhanchha**, sampling dishes like dal bhat (lentil soup with rice), momos (dumplings), or Newari cuisine.
#
# #### **Day 2: Nagarkot – Himalayan Views**
# Nagarkot, located a short drive from Kathmandu, is known for its panoramic views of the Himalayas, including Mount Everest on clear days.
#
# **Morning: Sunrise at Nagarkot**
# - Wake early and drive to Nagarkot (approx. 2-hour ride from Kathmandu). Catch the breathtaking sunrise over the snow-capped peaks.
#
# **Day: Easy Trekking and Views**
# - Take a short hike exploring Nagarkot’s surrounding hills and villages. Popular trails include hiking to **Changunarayan Temple**, a UNESCO World Heritage site known for its ancient architecture.
# - Enjoy the tranquility and fresh mountain air in Nagarkot’s peaceful ambiance.
#
# **Evening: Relax and Stargaze**
# - Stay overnight at a scenic resort or hotel such as **Club Himalaya Nagarkot Resort** or **Hotel Mystic Mountain**. Many accommodations feature terraces for stargazing and uninterrupted Himalayan views.
#
# #### **Day 3: Bhaktapur – The Cultural City**
# Bhaktapur is a medieval city known for its well-preserved architecture, arts, and culture.
#
# **Morning: Bhaktapur Durbar Square**
# - Explore **Bhaktapur Durbar Square**, a stunning heritage site with intricately carved temples, historical courtyards, and palaces.
# - Visit highlights such as the **Nyatapola Temple** (the tallest temple in Nepal), the **55-Window Palace**, and the **Pottery Square** where artisans create traditional pottery.
#
# **Afternoon: Try Local Newari Cuisine**
# - Savor authentic Newari dishes such as bara (lentil pancakes), yomari (sweet stuffed dumplings), and chatamari (Nepali-style pizza) at local eateries like **Cafe Nyatapola**.
#
# **Evening: Depart**
# - Depending on your flight schedule, head back to Kathmandu in the late afternoon (approx. 1-hour drive). Consider stopping at Patan Durbar Square if you have extra time.
#
# ---
#
# ### **Additional Notes**
# - **Travel logistics**: Book a private car or hire reliable transportation to make the most of the short trip, as public transit can be slow. Domestic flights are also available to expedite travel between locations.
# - **Accommodations**: Choose hotels that offer local charm while fitting your budget (e.g., heritage hotels or mountain resorts).
# - **Packing tip**: Bring warm clothing, especially for Nagarkot mornings, as it can be chilly even in warmer months.
#
# This itinerary offers a mix of culture, history, and natural beauty, making for an unforgettable adventure in Nepal! Let me know if you'd like additional suggestions or modifications.
# /Users/arturoquiroga/3CLOUD-AUTOGEN/.venv/lib/python3.13/site-packages/autogen_agentchat/agents/_assistant_agent.py:955: UserWarning: Resolved model mismatch: gpt-4o-2024-08-06 != gpt-4o-2024-11-20. Model mapping in autogen_ext.models.openai may be incorrect. Set the model to gpt-4o-2024-11-20 to enhance token/cost estimation and suppress this warning.
#   model_result = await model_client.create(
# ---------- TextMessage (local_agent) ----------
# Your trip to Nepal sounds exciting! If you'd like to add more adventure or relaxation, here are some optional activities for each day:
#
# ### **Day 1: Kathmandu**
# - **Add-on Adventure**: Visit the Garden of Dreams, a lovely neo-classical garden in the heart of Kathmandu, perfect for relaxing amidst lush greenery.
# - **Spiritual Experience**: Attend a meditation session or learn about Tibetan Buddhism at the Kopan Monastery.
#
# ### **Day 2: Nagarkot**
# - **Extended Trekking**: If you're up for a longer hike, consider trekking to Dhulikhel, another beautiful spot for panoramic mountain views.
# - **Cultural Immersion**: Stroll through local villages near Nagarkot to interact with locals and observe their traditional Himalayan lifestyle.
#
# ### **Day 3: Bhaktapur**
# - **Art Exploration**: Take a workshop on pottery or traditional thangka painting in Bhaktapur and bring home a handmade souvenir.
# - **Nature Experience**: Visit Siddha Pokhari, a serene pond near Bhaktapur Durbar Square, ideal for unwinding before departure.
#
# Let me know if you’d like recommendations for specific hotels, restaurants, or transportation options! 🌏
# Your trip to Nepal sounds exciting! If you'd like to add more adventure or relaxation, here are some optional activities for each day:
#
# ### **Day 1: Kathmandu**
# - **Add-on Adventure**: Visit the Garden of Dreams, a lovely neo-classical garden in the heart of Kathmandu, perfect for relaxing amidst lush greenery.
# - **Spiritual Experience**: Attend a meditation session or learn about Tibetan Buddhism at the Kopan Monastery.
#
# ### **Day 2: Nagarkot**
# - **Extended Trekking**: If you're up for a longer hike, consider trekking to Dhulikhel, another beautiful spot for panoramic mountain views.
# - **Cultural Immersion**: Stroll through local villages near Nagarkot to interact with locals and observe their traditional Himalayan lifestyle.
#
# ### **Day 3: Bhaktapur**
# - **Art Exploration**: Take a workshop on pottery or traditional thangka painting in Bhaktapur and bring home a handmade souvenir.
# - **Nature Experience**: Visit Siddha Pokhari, a serene pond near Bhaktapur Durbar Square, ideal for unwinding before departure.
#
# Let me know if you’d like recommendations for specific hotels, restaurants, or transportation options! 🌏
# ---------- TextMessage (language_agent) ----------
# This itinerary offers a wonderful balance of culture, nature, and adventure. However, given that you're planning to spend time in Nepal, understanding some communication tips would greatly enhance your experience, especially since English is not the first language for most locals.
#
# ### **Language and Communication Tips for Nepal**
# 1. **Key Phrases**:
#    - While English is widely understood in tourist areas, learning a few Nepali words can show respect and build rapport. Here's a quick guide for essential phrases:
#      - **Namaste** – Hello/Greetings
#      - **Dhan'yavād** – Thank you
#      - **Kati ho?** – How much? (Useful for shopping)
#      - **Chhaina** or **Maaf garnuhos** – Sorry
#      - **Maile bujhina** – I didn’t understand
#      - **Shauchalaya kahaa cha?** – Where is the toilet?
#
# 2. **Avoiding Miscommunication**:
#    - Be patient and speak slowly when communicating with locals whose English may still be basic.
#    - Use gestures or pointing if language barriers arise during menu orders, shopping, or directions.
#
# 3. **Translation Apps**:
#    - Download a translation app like Google Translate and ensure it supports offline use in case of limited internet access.
#
# 4. **Professional Guides**:
#    - Consider hiring a local guide who speaks both Nepali and English in areas like Bhaktapur or Nagarkot. Guides can bridge any communication gaps while sharing rich cultural insights.
#
# 5. **Caution in Rural Areas**:
#    - In remote locations or villages, English fluency might be limited. Showing friendliness and patience can go a long way in building understanding.
#
# Your itinerary already includes high-value cultural experiences, and being mindful of these communication tips will make your journey smoother and more rewarding. If you'd like assistance with any specific communication challenges, let me know! 😊
# ---------- TextMessage (travel_summary_agent) ----------
# Here is the complete, integrated itinerary for your 3-day trip to Nepal, reflecting travel insights, local recommendations, and communication tips for an unforgettable experience:
#
# ---
#
# ### **Day 1: Kathmandu – History, Culture, and Heritage**
#
# **Morning: Explore UNESCO World Heritage Sites**
# - **Pashupatinath Temple**: Begin your trip at Nepal’s most sacred Hindu temple. Witness rituals and soak in the spiritual atmosphere near the Bagmati River.
# - **Boudhanath Stupa**: Visit this massive Buddhist stupa renowned for its serene aura and prayer wheels surrounding it.
#
# **Lunch Recommendation**:
# - Opt for a cozy eatery near Boudhanath, such as **Roadhouse Cafe**, for continental and local dishes.
#
# **Afternoon: Kathmandu Durbar Square**
# - Spend time exploring the historical square, home to palaces, shrines, and alleyways. Visit Kumari Ghar (abode of the living goddess) and stroll along Freak Street to understand its hippie history.
#
# **Evening: Thamel**
# - Experience the lively buzz of Thamel. Shop for souvenirs such as Tibetan jewelry, handicrafts, and pashmina scarves. Enjoy a traditional Nepali dinner at **Rosemary Kitchen** or **Thakali Bhanchha**, trying dishes like dal bhat, momos, or Newari cuisine.
#
# **Language Tip**: Use "Kati ho?" (How much?) when bargaining at shops in Thamel.
#
# ---
#
# ### **Day 2: Nagarkot – Himalayan Views and Serenity**
#
# **Early Morning: Sunrise at Nagarkot**
# - Depart early (approx. 2-hour drive) to reach Nagarkot for one of the most spectacular Himalayan sunrises. Carry warm clothes as mornings here can be chilly.
#
# **Breakfast Recommendation**:
# - Enjoy breakfast at your hotel or at **Cafe du Mont**, offering panoramic views with hearty meals.
#
# **Day: Easy Trekking and Cultural Immersion**
# - Embark on a light trek to **Changunarayan Temple** (UNESCO-listed), passing through scenic trails, traditional villages, and terraced fields. Immerse yourself in local culture by engaging with villagers and observing Himalayan living.
#
# **Lunch Recommendation**:
# - Relish local meals like momos or Tibetan thenthuk at a small mountain-side eatery.
#
# **Afternoon: Relaxation and Stargazing**
# - Spend the afternoon unwinding at **Club Himalaya Nagarkot Resort** or **Hotel Mystic Mountain**. These accommodations offer direct mountain views and terraces ideal for stargazing in the evening.
#
# **Optional Add-on**:
# - For adventure enthusiasts, extend your trek toward Dhulikhel for another refreshing Himalayan view.
#
# **Language Tip**: Greet locals with "Namaste" (Hello) and use minimal Nepali phrases to show respect while interacting.
#
# ---
#
# ### **Day 3: Bhaktapur – Architectural Heritage and Art**
#
# **Morning: Bhaktapur Durbar Square**
# - Drive to Bhaktapur (approx. 1-hour from Nagarkot), a medieval town known for its beautifully preserved heritage.
# - Explore **Bhaktapur Durbar Square**, spotlighting architectural wonders like Nyatapola Temple (Nepal’s tallest temple) and the 55-Window Palace.
# - Walk to **Pottery Square**, where you can observe artisans molding clay and try your hand at pottery during a quick workshop.
#
# **Lunch Recommendation**:
# - Dine at **Cafe Nyatapola**, known for its rooftop views and delicious Newari dishes (try yomari, bara, or chatamari).
#
# **Afternoon: Art and Nature**
# - Visit Siddha Pokhari, a serene pond perfect for relaxation.
# - Optional: Attend a Thangka painting session to learn how intricate Buddhist art is created.
#
# **Return to Kathmandu**:
# - In the late afternoon, drive back to Kathmandu depending on your flight schedule (optional stop at **Patan Durbar Square** if time permits).
#
# **Dinner Recommendation**:
# - Enjoy a farewell dinner at **The Ship Restaurant**, offering modern interpretations of Nepali cuisine.
#
# **Language Tip**: Use Google Translate or a local guide for deeper engagement, especially in areas with fewer English speakers.
#
# ---
#
# ### **Additional Notes**
# - **Transportation**: Book a private vehicle or coordinate a guided service (e.g., car hire with driver) for time efficiency. Domestic airlines are also available if you plan to extend your trip further.
# - **Accommodation**:
#   - Kathmandu: **Hotel Mulberry** or **Traditional Comfort Hotel**
#   - Nagarkot: **Club Himalaya Nagarkot Resort** or **Hotel Mystic Mountain**
#   - Bhaktapur: **Peacock Guest House**
# - **Packing**: Don’t forget warm layers for Nagarkot mornings, comfortable trekking shoes, sunscreen, and power banks for electronics.
#
# This itinerary balances cultural exploration, natural beauty, and personal connection to Nepal’s traditions, all while smoothly navigating communication challenges. Have an amazing journey!
#
# **TERMINATE**
