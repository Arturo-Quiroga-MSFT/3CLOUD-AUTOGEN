# %%
#%pip install -U "autogen-agentchat"
#%pip install -U "autogen-agentchat[azure]"
#%pip install -U autogenstudio
# %pip install python-dotenv
# Out:
# Requirement already satisfied: python-dotenv in /Users/arturoquiroga/3CLOUD-AUTOGEN/.venv/lib/python3.13/site-packages (1.1.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Example team of AI Assistant agents in a ROUND ROBIN CHATGROUP team

# %%
from autogen_agentchat.agents import AssistantAgent
from autogen_agentchat.conditions import TextMentionTermination
from autogen_agentchat.teams import RoundRobinGroupChat
from autogen_agentchat.ui import Console
from autogen_ext.models.openai import AzureOpenAIChatCompletionClient
from dotenv import load_dotenv
load_dotenv()
import yaml

# %% [markdown]
# ## load the modelconfig

# %%
with open("model_config.yaml", "r") as f:
        model_config = yaml.safe_load(f)
model_client = AzureOpenAIChatCompletionClient.load_component(model_config)

# %% [markdown]
# ## Define 4 agents  == Planner-agent - Local-agent - Language-agent - Trip-summary-agent

# %%
planner_agent = AssistantAgent(
    "planner_agent",
    model_client=model_client,
    description="A helpful assistant that can plan trips.",
    system_message="You are a helpful assistant that can suggest a travel plan for a user based on their request.",
)

local_agent = AssistantAgent(
    "local_agent",
    model_client=model_client,
    description="A local assistant that can suggest local activities or places to visit.",
    system_message="You are a helpful assistant that can suggest authentic and interesting local activities or places to visit for a user and can utilize any context information provided.",
)

language_agent = AssistantAgent(
    "language_agent",
    model_client=model_client,
    description="A helpful assistant that can provide language tips for a given destination.",
    system_message="You are a helpful assistant that can review travel plans, providing feedback on important/critical tips about how best to address language or communication challenges for the given destination. If the plan already includes language tips, you can mention that the plan is satisfactory, with rationale.",
)

travel_summary_agent = AssistantAgent(
    "travel_summary_agent",
    model_client=model_client,
    description="A helpful assistant that can summarize the travel plan.",
    system_message="You are a helpful assistant that can take in all of the suggestions and advice from the other agents and provide a detailed final travel plan. You must ensure that the final plan is integrated and complete. YOUR FINAL RESPONSE MUST BE THE COMPLETE PLAN. When the plan is complete and all perspectives are integrated, you can respond with TERMINATE.",
)

# %% [markdown]
# ## user question

# %%
termination = TextMentionTermination("TERMINATE")
group_chat = RoundRobinGroupChat(
    [planner_agent, local_agent, language_agent, travel_summary_agent], termination_condition=termination
)
await Console(group_chat.run_stream(task="Plan a 3 day trip to Nepal."))

await model_client.close()
# Out:
# ---------- TextMessage (user) ----------
# Plan a 3 day trip to Nepal.
# ---------- TextMessage (planner_agent) ----------
# Here’s a 3-day travel plan for Nepal, covering a mix of cultural, natural, and adventurous experiences. This plan assumes arrival in Kathmandu (the capital city) and offers a balance of must-see attractions without being overly rushed.
#
# ---
#
# ### **Day 1: Explore Kathmandu – Cultural Wonders**
#
# **Morning:**
# - **Arrival in Kathmandu**: After landing at Tribhuvan International Airport, check into your hotel.
# - **Visit Swayambhunath Stupa (Monkey Temple)**: Start your trip with this iconic hilltop stupa, offering panoramic views of Kathmandu. The site is an ancient religious complex with Buddhist and Hindu significance.
# - **Breakfast**: Enjoy traditional Nepali food, such as yomari or sel roti, at a nearby café.
#
# **Midday:**
# - **Kathmandu Durbar Square**: Explore the historic heart of Kathmandu, with its palace courtyards, ancient temples, and bustling local markets. Look out for the Kumari Ghar, home to Nepal’s Living Goddess.
# - **Lunch**: Relish momo (dumplings) or dal bhat (lentil soup with rice and veggies) at a typical Nepali restaurant.
#
# **Afternoon:**
# - **Pashupatinath Temple**: Visit the most sacred Hindu temple in Nepal on the banks of the Bagmati River. Witness traditional Hindu rituals and cremation ceremonies (respectfully).
# - **Boudhanath Stupa**: Conclude the day at one of the largest Buddhist stupas in the world. Stroll along the circular prayer path and soak in the peaceful atmosphere.
#
# **Evening:**
# - **Dinner**: Try Nepali thali at a local restaurant. If you’re feeling adventurous, sample some rakshi (local rice liquor).
# - **Relax in Thamel**: Walk through the vibrant streets of Thamel, a popular area filled with shops, cafes, and live music bars.
#
# ---
#
# ### **Day 2: Escape into Nature – Day Trip to Nagarkot**
#
# **Early Morning:**
# - **Drive to Nagarkot (1.5-hour drive)**: Leave early to catch the sunrise over the Himalayas. Nagarkot is famous for its stunning views of Mount Everest and other Himalayan peaks.
#
# **Breakfast:**
# - Enjoy breakfast at a resort overlooking the mountains.
#
# **Midday:**
# - **Hiking from Nagarkot to Changu Narayan Temple**: Embark on a 3–4 hour scenic hike through local villages, fields, and forests to reach Changu Narayan, a UNESCO World Heritage Site. Explore the ancient Hindu temple dedicated to Lord Vishnu.
#
# **Lunch:**
# - Have lunch at a cozy café near Changu Narayan or Nagarkot before driving back.
#
# **Afternoon:**
# - **Return to Kathmandu**: Relax during the drive back or wander through more of Nagarkot’s viewpoints before returning.
#
# **Evening:**
# - **Shopping in Thamel**: Pick up souvenirs such as pashmina shawls, handcrafted jewelry, or traditional Nepali art.
# - **Dinner**: Choose from an international or Asian fusion menu at a rooftop restaurant in Thamel.
#
# ---
#
# ### **Day 3: Adventure + Farewell to Nepal**
#
# **Morning:**
# - **Patan Durbar Square**: Drive 30 minutes south to Patan, a city known for its artisanal crafts and the golden Krishna Mandir. Explore this ancient square and its museums.
# - **Breakfast in Patan**: Try a traditional Newari breakfast, such as bara (lentil patties) or chatamari (Nepali-style pizza).
#
# **Midday:**
# - **Optional Activity**:
#   - **River Rafting**: If you're feeling adventurous, head to the Trishuli River for white water rafting (requires a half-day tour).
#   - **Bhaktapur Visit**: Explore Bhaktapur Durbar Square, famed for its preserved medieval architecture, pottery square, and delicious “king curd” (juju dhau).
#
# **Lunch:**
# - Enjoy Nepali cuisine in Bhaktapur or return to Kathmandu for a rooftop meal.
#
# **Afternoon:**
# - **Relax at the Garden of Dreams**: Unwind at this beautiful neo-classical garden in central Kathmandu.
#
# **Evening:**
# - **Farewell Dinner**: End your trip with a special Nepali cultural dinner and dance show at a local restaurant.
#
# **Night:**
# - Transfer to Tribhuvan International Airport for your flight departure.
#
# ---
#
# ### **Tips for Your Trip:**
# - **Transport:** Use taxis, private cars, or hire a guide for ease of travel.
# - **Weather:** Pack layers to accommodate varying temperatures.
# - **Local Etiquette:** Dress modestly, especially when visiting religious sites.
#
# This plan allows you to experience Nepal’s best highlights in a short time without being rushed. Let me know if you want to tailor the plan further or add specific activities!
# /Users/arturoquiroga/3CLOUD-AUTOGEN/.venv/lib/python3.13/site-packages/autogen_agentchat/agents/_assistant_agent.py:955: UserWarning: Resolved model mismatch: gpt-4o-2024-08-06 != gpt-4o-2024-11-20. Model mapping in autogen_ext.models.openai may be incorrect. Set the model to gpt-4o-2024-11-20 to enhance token/cost estimation and suppress this warning.
#   model_result = await model_client.create(
# ---------- TextMessage (local_agent) ----------
# This is a well-balanced itinerary! If you're open to some tweaks or have specific interests such as trekking, wildlife, or wellness, we can customize it even more. For example:
#
# - **If you're into trekking**: A short, scenic trek like the Dhulikhel-Namo Buddha trail could replace the Day 2 Nagarkot visit.
# - **For wildlife enthusiasts**: Swap Day 2 for a day trip to Chitwan National Park for a jungle safari experience.
# - **For meditation or wellness**: Incorporate a yoga or meditation retreat session, especially in places like Boudhanath or Nagarkot.
#
# Let me know how you'd like it tailored further! Safe travels! 🌄
# This is a well-balanced itinerary! If you're open to some tweaks or have specific interests such as trekking, wildlife, or wellness, we can customize it even more. For example:
#
# - **If you're into trekking**: A short, scenic trek like the Dhulikhel-Namo Buddha trail could replace the Day 2 Nagarkot visit.
# - **For wildlife enthusiasts**: Swap Day 2 for a day trip to Chitwan National Park for a jungle safari experience.
# - **For meditation or wellness**: Incorporate a yoga or meditation retreat session, especially in places like Boudhanath or Nagarkot.
#
# Let me know how you'd like it tailored further! Safe travels! 🌄
# ---------- TextMessage (language_agent) ----------
# This itinerary provides a great blend of cultural immersion, natural beauty, and mild adventure. However, it's important to address language and communication challenges for a smoother experience during your three days in Nepal.
#
# ### **Language Tips**
# 1. **Nepali Phrases**: While many locals in tourism areas understand English, learning basic Nepali phrases like “Namaste” (Hello) or “Dhanyabad” (Thank you) will make interactions more friendly. Carry a phrasebook or use a translation app.
#
# 2. **Tour Guides**: Hiring a guide for places like Durbar Squares or hiking trails ensures clear communication about historical and cultural significance. Guides often speak fluent English and some other languages.
#
# 3. **Written Addresses**: If using taxis or asking for directions, write down the name of places in Nepali script beforehand. It helps avoid miscommunication with drivers or locals who may not read Romanized Nepali.
#
# 4. **Hotel and Restaurant Staff**: Hospitality staff often speak English, but patience and clear communication are key when ordering food or addressing concerns.
#
# Since the plan overlooks specific solutions to potential language barriers, these tips will enhance your experience in Nepal. If you'd like detailed guidance on communication-related apps or tools, feel free to ask!
# ---------- TextMessage (travel_summary_agent) ----------
# Here is the complete and integrated 3-day travel plan to Nepal, factoring in cultural, natural, and adventurous experiences, as well as useful local and language recommendations for a smooth trip.
#
# ---
#
# ### **Day 1: Explore Kathmandu – Dive into Culture**
#
# **Morning:**
# - **Arrival in Kathmandu**: Upon landing at Tribhuvan International Airport, clear immigration and check into a hotel in the centrally-located Thamel district.
# - **Visit Swayambhunath Stupa (Monkey Temple)**: Start your adventure with this ancient temple, perched atop a hill, to get sweeping views of the Kathmandu Valley. Enjoy the serene ambiance and encounter playful monkeys that inhabit the area.
# - **Learn Nepali Phrases**: Greet locals with a “Namaste” and practice saying “Dhanyabad” to express gratitude.
#
# **Breakfast:**
# - Enjoy classic Nepali breakfast treats like yomari or sel roti at a nearby café.
#
# **Midday:**
# - **Kathmandu Durbar Square**: Immerse yourself in the royal history of Nepal by visiting this UNESCO World Heritage Site. Explore the temples, palaces, and the Kumari Ghar, the residence of Nepal’s living goddess.
# - Hire a local guide (who speaks English) for better insights into the rich cultural history.
#
# **Lunch:**
# - Dine at a local restaurant. Try dishes like momo (dumplings) or dal bhat tarkari (a classic Nepali meal of lentils, rice, and vegetables).
#
# **Afternoon:**
# - **Pashupatinath Temple**: Visit this sacred Hindu site to observe rituals and cremation ceremonies along the Bagmati River. Respect the sanctity of the place by dressing modestly and not taking intrusive photographs.
# - **Boudhanath Stupa**: Conclude your sightseeing with an evening stroll around one of the largest Buddhist stupas in the world. Absorb the peaceful aura as monks chant and devotees spin prayer wheels.
#
# **Evening:**
# - **Dinner**: Head back to Thamel and enjoy a traditional Nepali thali meal at a local restaurant. For a cultural twist, try some rakshi (traditional rice liquor).
# - **Shopping and Strolling in Thamel**: Explore this vibrant neighborhood, famous for its bohemian vibe, handmade crafts, trekking gear, and boutique shops.
#
# ---
#
# ### **Day 2: Escape into Nature – Nagarkot and Beyond**
#
# **Early Morning:**
# - **Drive to Nagarkot**: Embark on an early morning journey to Nagarkot (1.5 hours from Kathmandu). Experience sunrise views of the Himalayan range, including glimpses of Mount Everest on clear days.
#
# **Breakfast:**
# - Enjoy breakfast at a mountain-facing resort or restaurant with picturesque views.
#
# **Midday:**
# - **Nagarkot to Changu Narayan Hike**: Begin a 3–4 hour hike through terraced fields, quaint villages, and serene forests. The trek concludes at Changu Narayan Temple, an ancient Hindu heritage site dedicated to Lord Vishnu. Both the route and the destination offer stunning cultural and natural insights.
#
# **Lunch:**
# - Have lunch in a cozy café or restaurant near Changu Narayan or Nagarkot.
#
# **Afternoon:**
# - **Return to Kathmandu**: Relax during the scenic drive back to the city. If you have extra time, you can take a detour to Bhaktapur (an ancient city). Bhaktapur Durbar Square offers well-preserved medieval architecture, pottery markets, and the famous juju dhau (king of yogurts).
#
# **Evening:**
# - **Shopping in Thamel**: Continue souvenir shopping and pick up items such as pashmina shawls, singing bowls, or traditional Thangka paintings.
# - **Dinner**: Have an intimate dinner on a rooftop restaurant in Thamel, with a mix of Nepali and fusion cuisines.
#
# ---
#
# ### **Day 3: Adventure and Farewell to Nepal**
#
# **Morning:**
# - **Patan Durbar Square**: Travel 30 minutes south to visit the culturally-rich city of Patan (also known as Lalitpur). Discover intricately-carved temples and the beautiful Krishna Mandir at the Durbar Square.
# - Consider an optional visit to its museum featuring local crafts, which is perfect for art enthusiasts.
# - **Breakfast in Patan**: Enjoy a traditional Newari breakfast (bara or chatamari) at a local eatery.
#
# **Midday:**
# - **Optional Experiences**:
#   - If seeking adventure: Head to the Trishuli River (requires pre-booking) for white-water rafting, a thrilling experience surrounded by sublime hills.
#   - If preferring heritage: Spend time exploring Bhaktapur Durbar Square’s treasures, famous for its 55-window palace and Pottery Square.
#
# **Lunch:**
# - Fine dine in Bhaktapur or return to Kathmandu for a rooftop lunch overlooking the city.
#
# **Afternoon:**
# - **Relax at the Garden of Dreams**: Wind down your trip at this beautiful neo-classical garden in downtown Kathmandu—perfect for introspection and relaxation.
#
# **Evening:**
# - **Farewell Dinner**: Treat yourself to a cultural dinner show in Kathmandu featuring traditional music, dances, and a wide array of Nepali dishes.
#
# **Night:**
# - Transfer to Tribhuvan International Airport for your departure. Cherish the memories and bid goodbye to Nepal.
#
# ---
#
# ### **Additional Tips:**
# 1. **Local Transport**: Hire private cars for ease or use well-regarded taxi companies to move between destinations. Apps like Pathao or Tootle can also be helpful.
# 2. **Weather & Packing**: Kathmandu and surrounding areas might see varying temperatures; bring layers, comfortable hiking gear, and sunscreen.
# 3. **Language Assistance**: While most Nepalis in tourist hubs speak English, download apps like Google Translate with Nepali script, or carry a phrasebook for seamless communication.
# 4. **Ethical Tourism**: Be respectful at religious sites, ask permission before taking photos of locals, and support fair-trade shops to ensure your purchases benefit local craftsmen.
#
# This plan ensures you experience Nepal’s cultural depths, natural beauty, and mild adventure within a short span, with practical suggestions to simplify your journey.
#
# ### TERMINATE
