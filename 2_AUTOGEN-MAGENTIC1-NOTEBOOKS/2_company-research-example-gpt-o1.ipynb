# %%
#%pip install -U "autogen-agentchat"
#%pip install -U "autogen-agentchat[azure]"
#%pip install -U autogenstudio

# %% [markdown]
# # Example using the ROUND ROBIN GROUPCHAT team

# %%
from autogen_agentchat.agents import AssistantAgent
from autogen_agentchat.conditions import TextMentionTermination
from autogen_agentchat.teams import RoundRobinGroupChat
from autogen_agentchat.ui import Console
from autogen_ext.models.openai import AzureOpenAIChatCompletionClient

# %% [markdown]
# ## with o1 reasoning model

# %%
model_client = AzureOpenAIChatCompletionClient(
    azure_deployment="o1",
    azure_endpoint="https://aq-aoai-swedencentral.openai.azure.com/",
    model="o1",
    api_version="2025-03-01-preview",
    api_key="3ShjYyRHd6t0VthIuoOUe1GEnwlj1tkNSHkOs6IrO1CxKQ3gHmsIJQQJ99BAACfhMk5XJ3w3AAABACOG3ddZ",
 #   temperature=0.7,
)

# %%
#%pip install yfinance matplotlib pytz numpy pandas python-dotenv requests bs4

# %%
def google_search_tool(query: str, num_results: int = 2, max_chars: int = 500) -> list:  # type: ignore[type-arg]
    import os
    import time

    import requests
    from bs4 import BeautifulSoup
    from dotenv import load_dotenv

    load_dotenv()

    api_key = os.getenv("GOOGLE_API_KEY")
    search_engine_id = os.getenv("GOOGLE_SEARCH_ENGINE_ID")

    if not api_key or not search_engine_id:
        raise ValueError("API key or Search Engine ID not found in environment variables")

    url = "https://customsearch.googleapis.com/customsearch/v1"
    params = {"key": str(api_key), "cx": str(search_engine_id), "q": str(query), "num": str(num_results)}

    response = requests.get(url, params=params)

    if response.status_code != 200:
        print(response.json())
        raise Exception(f"Error in API request: {response.status_code}")

    results = response.json().get("items", [])

    def get_page_content(url: str) -> str:
        try:
            response = requests.get(url, timeout=10)
            soup = BeautifulSoup(response.content, "html.parser")
            text = soup.get_text(separator=" ", strip=True)
            words = text.split()
            content = ""
            for word in words:
                if len(content) + len(word) + 1 > max_chars:
                    break
                content += " " + word
            return content.strip()
        except Exception as e:
            print(f"Error fetching {url}: {str(e)}")
            return ""

    enriched_results = []
    for item in results:
        body = get_page_content(item["link"])
        enriched_results.append(
            {"title": item["title"], "link": item["link"], "snippet": item["snippet"], "body": body}
        )
        time.sleep(1)  # Be respectful to the servers

    return enriched_results

# %%
def stock_analysis_tool(ticker: str) -> dict:  # type: ignore[type-arg]
    import os
    from datetime import datetime, timedelta

    import matplotlib.pyplot as plt
    import numpy as np
    import pandas as pd
    import yfinance as yf
    from pytz import timezone  # type: ignore

    stock = yf.Ticker(ticker)

    # Get historical data (1 year of data to ensure we have enough for 200-day MA)
    end_date = datetime.now(timezone("UTC"))
    start_date = end_date - timedelta(days=365)
    hist = stock.history(start=start_date, end=end_date)

    # Ensure we have data
    if hist.empty:
        return {"error": "No historical data available for the specified ticker."}

    # Compute basic statistics and additional metrics
    current_price = stock.info.get("currentPrice", hist["Close"].iloc[-1])
    year_high = stock.info.get("fiftyTwoWeekHigh", hist["High"].max())
    year_low = stock.info.get("fiftyTwoWeekLow", hist["Low"].min())

    # Calculate 50-day and 200-day moving averages
    ma_50 = hist["Close"].rolling(window=50).mean().iloc[-1]
    ma_200 = hist["Close"].rolling(window=200).mean().iloc[-1]

    # Calculate YTD price change and percent change
    ytd_start = datetime(end_date.year, 1, 1, tzinfo=timezone("UTC"))
    ytd_data = hist.loc[ytd_start:]  # type: ignore[misc]
    if not ytd_data.empty:
        price_change = ytd_data["Close"].iloc[-1] - ytd_data["Close"].iloc[0]
        percent_change = (price_change / ytd_data["Close"].iloc[0]) * 100
    else:
        price_change = percent_change = np.nan

    # Determine trend
    if pd.notna(ma_50) and pd.notna(ma_200):
        if ma_50 > ma_200:
            trend = "Upward"
        elif ma_50 < ma_200:
            trend = "Downward"
        else:
            trend = "Neutral"
    else:
        trend = "Insufficient data for trend analysis"

    # Calculate volatility (standard deviation of daily returns)
    daily_returns = hist["Close"].pct_change().dropna()
    volatility = daily_returns.std() * np.sqrt(252)  # Annualized volatility

    # Create result dictionary
    result = {
        "ticker": ticker,
        "current_price": current_price,
        "52_week_high": year_high,
        "52_week_low": year_low,
        "50_day_ma": ma_50,
        "200_day_ma": ma_200,
        "ytd_price_change": price_change,
        "ytd_percent_change": percent_change,
        "trend": trend,
        "volatility": volatility,
    }

    # Convert numpy types to Python native types for better JSON serialization
    for key, value in result.items():
        if isinstance(value, np.generic):
            result[key] = value.item()

    # Generate plot
    plt.figure(figsize=(12, 6))
    plt.plot(hist.index, hist["Close"], label="Close Price")
    plt.plot(hist.index, hist["Close"].rolling(window=50).mean(), label="50-day MA")
    plt.plot(hist.index, hist["Close"].rolling(window=200).mean(), label="200-day MA")
    plt.title(f"{ticker} Stock Price (Past Year)")
    plt.xlabel("Date")
    plt.ylabel("Price ($)")
    plt.legend()
    plt.grid(True)

    # Save plot to file
    os.makedirs("coding", exist_ok=True)
    plot_file_path = f"coding/{ticker}_stockprice.png"
    plt.savefig(plot_file_path)
    print(f"Plot saved as {plot_file_path}")
    result["plot_file_path"] = plot_file_path

    return result

# %%
search_agent = AssistantAgent(
    name="Google_Search_Agent",
    model_client=model_client,
    tools=[google_search_tool],
    description="Search Google for information, returns top 2 results with a snippet and body content",
    system_message="You are a helpful AI assistant. Solve tasks using your tools.",
)

stock_analysis_agent = AssistantAgent(
    name="Stock_Analysis_Agent",
    model_client=model_client,
    tools=[stock_analysis_tool],
    description="Analyze stock data and generate a plot",
    system_message="Perform data analysis.",
)

report_agent = AssistantAgent(
    name="Report_Agent",
    model_client=model_client,
    description="Generate a report based the search and results of stock analysis",
    system_message="You are a helpful assistant that can generate a comprehensive report on a given topic based on search and stock analysis. When you done with generating the report, reply with TERMINATE.",
)

# %%
team = RoundRobinGroupChat([stock_analysis_agent, search_agent, report_agent], max_turns=3)

# %%
stream = team.run_stream(task="Write a financial report on Microsoft")
await Console(stream)

await model_client.close()
# Out:
# ---------- user ----------
# Write a financial report on Microsoft
# ---------- Stock_Analysis_Agent ----------
# [FunctionCall(id='call_wccNv9QOVUwFi9U9StWfANlo', arguments='{"ticker":"MSFT"}', name='stock_analysis_tool')]
# Plot saved as coding/MSFT_stockprice.png
# ---------- Stock_Analysis_Agent ----------
# [FunctionExecutionResult(content="{'ticker': 'MSFT', 'current_price': 366.82, '52_week_high': 468.35, '52_week_low': 344.79, '50_day_ma': 388.7064923095703, '200_day_ma': 415.37143646240236, 'ytd_price_change': -50.92236328125, 'ytd_percent_change': -12.18989665985856, 'trend': 'Downward', 'volatility': 0.24704505197475887, 'plot_file_path': 'coding/MSFT_stockprice.png'}", name='stock_analysis_tool', call_id='call_wccNv9QOVUwFi9U9StWfANlo', is_error=False)]
# ---------- Stock_Analysis_Agent ----------
# {'ticker': 'MSFT', 'current_price': 366.82, '52_week_high': 468.35, '52_week_low': 344.79, '50_day_ma': 388.7064923095703, '200_day_ma': 415.37143646240236, 'ytd_price_change': -50.92236328125, 'ytd_percent_change': -12.18989665985856, 'trend': 'Downward', 'volatility': 0.24704505197475887, 'plot_file_path': 'coding/MSFT_stockprice.png'}
# ---------- Google_Search_Agent ----------
# Below is a concise financial report on Microsoft (MSFT), incorporating the stock data you provided:
#
# 1. Company Overview
#    • Microsoft is a global technology leader, primarily known for its software products (Windows operating system, Microsoft 365 suite), cloud services (Azure), hardware (Surface devices, Xbox gaming consoles), and a wide range of enterprise solutions.
#    • With a diverse product offering and a long history of innovation, Microsoft has consistently been one of the highest market-capitalization companies worldwide.
#
# 2. Recent Stock Performance
#    • Current Share Price: US$366.82
#    • 52-Week High: US$468.35
#    • 52-Week Low: US$344.79
#    • 50-Day Moving Average: US$388.71
#    • 200-Day Moving Average: US$415.37
#    • Year-to-Date (YTD) Price Change: –US$50.92
#    • YTD Percent Change: –12.19%
#
#    While Microsoft’s share price remains historically strong, it is currently below its 50-day and 200-day moving averages, suggesting a challenging environment in the near term. The data you provided indicates a downward trend this year (-12.19%). It is worth noting that specific fluctuations can be influenced by broader market sentiments around technology stocks and macroeconomic conditions.
#
# 3. Volatility and Trend
#    • Volatility: 0.247 (on a scale where higher values imply greater price swings)
#    • Trend: Downward
#
#    At roughly 0.247, the volatility suggests moderate swings in stock prices, meaning investors might see somewhat larger daily or weekly movements than in more stable times. The downward trend points to a pullback in investor sentiment, which could be due to a combination of profit-taking, broader tech rotation, or caution regarding sector outlook.
#
# 4. Recent Financial Highlights (General Context)
#    • Revenues: Microsoft’s revenue has been steadily growing in part due to its cloud segment (Azure) and continued success of Office 365 subscriptions.
#    • Profitability: Historically high profit margins, supported by the large proportion of recurring subscription-based revenues and a strong enterprise client base.
#    • Cash Position: Microsoft typically maintains a robust balance sheet, enabling strategic acquisitions and significant R&D investments.
#
# 5. Outlook and Considerations
#    • Growth Catalysts: Azure cloud services, AI-integrated solutions (e.g., GitHub Copilot, Bing Chat), and ongoing innovations in productivity software continue to be major growth drivers.
#    • Challenges: Heightened competition in the cloud marketplace, macroeconomic uncertainties, and pressure on enterprise spending can inhibit near-term growth.
#    • Investor Sentiment: Despite recent share-price softness, Microsoft’s diversification and historical resilience appeal to many long-term investors. The downward momentum may create buying opportunities, but investors will watch macro factors (inflation, interest rates) and company guidance closely.
#
# 6. Conclusion
#    Microsoft remains a technology powerhouse with strong fundamentals. The recent pullback and downward trend underscore that even well-established market leaders can experience periods of lower investor confidence and price volatility. Long-term prospects hinge on strategic investments in cloud computing, AI, and new platform innovations. As always, investors should review personal risk tolerance and stay informed about market conditions and Microsoft’s corporate developments.
#
# Disclaimer: This report is based on the data you provided and publicly available information. It does not represent financial advice or real-time market analysis. Always consult a qualified financial advisor and conduct thorough research before making investment decisions.
# ---------- Report_Agent ----------
# Below is a comprehensive financial report on Microsoft Corporation (ticker: MSFT), incorporating recent stock data and an overview of key business aspects:
#
# 1. Company Overview
#    • Microsoft is one of the world’s largest technology companies, recognized for its extensive range of software (Windows, Microsoft 365), cloud services (Azure), hardware (Surface devices), and gaming (Xbox).
#    • Its diverse product portfolio and large user base reflect a mix of consumer, enterprise, and government customers, positioning Microsoft for steady cash flow and potential for ongoing innovation.
#
# 2. Recent Stock Performance
#    • Current Share Price: US$366.82
#    • 52-Week High: US$468.35
#    • 52-Week Low: US$344.79
#    • 50-Day Moving Average (MA): US$388.71
#    • 200-Day Moving Average (MA): US$415.37
#    • Year-to-Date (YTD) Price Change: –US$50.92
#    • YTD Percent Change: –12.19%
#    • Trend: Downward
#    • Volatility: 0.247 (moderate)
#
#    Despite Microsoft’s historically strong performance, the shares are currently trading below both the 50-day and 200-day moving averages, indicating that sentiment has shifted downward in the near term. The YTD price decrease may be partly influenced by broader market volatility, shifts in tech-sector investments, and macroeconomic headwinds.
#
# 3. Key Fundamentals
#    • Revenue Growth: Microsoft’s revenues have been boosted by increasing cloud adoption (Azure) and subscription-based services (e.g., Microsoft 365). Its enterprise software business remains a substantial contributor to profits.
#    • Profitability: Known for robust margins, Microsoft benefits from diversified revenue streams and reliable cash flow generated from recurring software subscriptions.
#    • Balance Sheet Strength: The company’s strong cash position underpins ongoing research and development investments, dividend payments, and share buybacks.
#    • Recent Initiatives: Microsoft continues to focus on AI-driven services (e.g., integrated Bing Chat, GitHub Copilot), expanding cloud capabilities, and product integrations across Windows, Office, and Teams.
#
# 4. Outlook and Considerations
#    • Growth Drivers: Azure cloud services, productivity tools, and renewed interest in AI and machine learning could power long-term expansion.
#    • Potential Challenges: Increased competition in cloud and AI markets, evolving data privacy regulations, and changes in enterprise spending patterns during economic uncertainty.
#    • Investor Outlook: While the current downward trend may unsettle some investors, Microsoft’s track record of adapting to market shifts and ongoing innovations can appeal to those with a long-term horizon. A pullback in stock price could represent an opportunity for value-focused investors, but short-term volatility remains possible.
#
# 5. Conclusion
#    Microsoft has built a solid foundation for future growth, leveraging a broad portfolio that spans operating systems, productivity tools, gaming, and cloud services. Current market conditions have driven the stock below key moving averages, reflected in a modest year-to-date decline. Nonetheless, the company’s financial strength, innovation pipeline, and cloud leadership suggest a positive long-term outlook. As with any equity, potential investors should evaluate Microsoft’s performance alongside macroeconomic conditions, competitive landscape, and individual risk tolerance.
#
# Disclaimer: This report is for informational purposes only and does not constitute financial advice. Always consult a qualified financial advisor and conduct detailed research before making investment decisions.
#
# TERMINATE
