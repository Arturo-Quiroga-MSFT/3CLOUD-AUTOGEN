# %%
#%pip install -U "autogen-agentchat"
#%pip install -U "autogen-agentchat[azure]"
#%pip install -U autogenstudio

# %% [markdown]
# # Example using the ROUND ROBIN GROUPCHAT team

# %%
from autogen_agentchat.agents import AssistantAgent
from autogen_agentchat.conditions import TextMentionTermination
from autogen_agentchat.teams import RoundRobinGroupChat
from autogen_agentchat.ui import Console
from autogen_ext.models.openai import AzureOpenAIChatCompletionClient
import yaml

# %% [markdown]
# ## with gpt-4o

# %%
with open("model_config.yaml", "r") as f:
        model_config = yaml.safe_load(f)
model_client = AzureOpenAIChatCompletionClient.load_component(model_config)

# %%
#%pip install yfinance matplotlib pytz numpy pandas python-dotenv requests bs4

# %%
def google_search_tool(query: str, num_results: int = 2, max_chars: int = 500) -> list:  # type: ignore[type-arg]
    import os
    import time

    import requests
    from bs4 import BeautifulSoup
    from dotenv import load_dotenv

    load_dotenv()

    api_key = os.getenv("GOOGLE_API_KEY")
    search_engine_id = os.getenv("GOOGLE_SEARCH_ENGINE_ID")

    if not api_key or not search_engine_id:
        raise ValueError("API key or Search Engine ID not found in environment variables")

    url = "https://customsearch.googleapis.com/customsearch/v1"
    params = {"key": str(api_key), "cx": str(search_engine_id), "q": str(query), "num": str(num_results)}

    response = requests.get(url, params=params)

    if response.status_code != 200:
        print(response.json())
        raise Exception(f"Error in API request: {response.status_code}")

    results = response.json().get("items", [])

    def get_page_content(url: str) -> str:
        try:
            response = requests.get(url, timeout=10)
            soup = BeautifulSoup(response.content, "html.parser")
            text = soup.get_text(separator=" ", strip=True)
            words = text.split()
            content = ""
            for word in words:
                if len(content) + len(word) + 1 > max_chars:
                    break
                content += " " + word
            return content.strip()
        except Exception as e:
            print(f"Error fetching {url}: {str(e)}")
            return ""

    enriched_results = []
    for item in results:
        body = get_page_content(item["link"])
        enriched_results.append(
            {"title": item["title"], "link": item["link"], "snippet": item["snippet"], "body": body}
        )
        time.sleep(1)  # Be respectful to the servers

    return enriched_results

# %%
def stock_analysis_tool(ticker: str) -> dict:  # type: ignore[type-arg]
    import os
    from datetime import datetime, timedelta

    import matplotlib.pyplot as plt
    import numpy as np
    import pandas as pd
    import yfinance as yf
    from pytz import timezone  # type: ignore

    stock = yf.Ticker(ticker)

    # Get historical data (1 year of data to ensure we have enough for 200-day MA)
    end_date = datetime.now(timezone("UTC"))
    start_date = end_date - timedelta(days=365)
    hist = stock.history(start=start_date, end=end_date)

    # Ensure we have data
    if hist.empty:
        return {"error": "No historical data available for the specified ticker."}

    # Compute basic statistics and additional metrics
    current_price = stock.info.get("currentPrice", hist["Close"].iloc[-1])
    year_high = stock.info.get("fiftyTwoWeekHigh", hist["High"].max())
    year_low = stock.info.get("fiftyTwoWeekLow", hist["Low"].min())

    # Calculate 50-day and 200-day moving averages
    ma_50 = hist["Close"].rolling(window=50).mean().iloc[-1]
    ma_200 = hist["Close"].rolling(window=200).mean().iloc[-1]

    # Calculate YTD price change and percent change
    ytd_start = datetime(end_date.year, 1, 1, tzinfo=timezone("UTC"))
    ytd_data = hist.loc[ytd_start:]  # type: ignore[misc]
    if not ytd_data.empty:
        price_change = ytd_data["Close"].iloc[-1] - ytd_data["Close"].iloc[0]
        percent_change = (price_change / ytd_data["Close"].iloc[0]) * 100
    else:
        price_change = percent_change = np.nan

    # Determine trend
    if pd.notna(ma_50) and pd.notna(ma_200):
        if ma_50 > ma_200:
            trend = "Upward"
        elif ma_50 < ma_200:
            trend = "Downward"
        else:
            trend = "Neutral"
    else:
        trend = "Insufficient data for trend analysis"

    # Calculate volatility (standard deviation of daily returns)
    daily_returns = hist["Close"].pct_change().dropna()
    volatility = daily_returns.std() * np.sqrt(252)  # Annualized volatility

    # Create result dictionary
    result = {
        "ticker": ticker,
        "current_price": current_price,
        "52_week_high": year_high,
        "52_week_low": year_low,
        "50_day_ma": ma_50,
        "200_day_ma": ma_200,
        "ytd_price_change": price_change,
        "ytd_percent_change": percent_change,
        "trend": trend,
        "volatility": volatility,
    }

    # Convert numpy types to Python native types for better JSON serialization
    for key, value in result.items():
        if isinstance(value, np.generic):
            result[key] = value.item()

    # Generate plot
    plt.figure(figsize=(12, 6))
    plt.plot(hist.index, hist["Close"], label="Close Price")
    plt.plot(hist.index, hist["Close"].rolling(window=50).mean(), label="50-day MA")
    plt.plot(hist.index, hist["Close"].rolling(window=200).mean(), label="200-day MA")
    plt.title(f"{ticker} Stock Price (Past Year)")
    plt.xlabel("Date")
    plt.ylabel("Price ($)")
    plt.legend()
    plt.grid(True)

    # Save plot to file
    os.makedirs("coding", exist_ok=True)
    plot_file_path = f"coding/{ticker}_stockprice.png"
    plt.savefig(plot_file_path)
    print(f"Plot saved as {plot_file_path}")
    result["plot_file_path"] = plot_file_path

    return result

# %%
search_agent = AssistantAgent(
    name="Google_Search_Agent",
    model_client=model_client,
    tools=[google_search_tool],
    description="Search Google for information, returns top 2 results with a snippet and body content",
    system_message="You are a helpful AI assistant. Solve tasks using your tools.",
)

stock_analysis_agent = AssistantAgent(
    name="Stock_Analysis_Agent",
    model_client=model_client,
    tools=[stock_analysis_tool],
    description="Analyze stock data and generate a plot",
    system_message="Perform data analysis.",
)

report_agent = AssistantAgent(
    name="Report_Agent",
    model_client=model_client,
    description="Generate a report based the search and results of stock analysis",
    system_message="You are a helpful assistant that can generate a comprehensive report on a given topic based on search and stock analysis. When you done with generating the report, reply with TERMINATE.",
)

# %%
team = RoundRobinGroupChat([stock_analysis_agent, search_agent, report_agent], max_turns=3)

print("Welcome to the Stock Analysis and Reporting System!")

# %%
stream = team.run_stream(task="Write a financial report on Microsoft")
await Console(stream)

await model_client.close()
# Out:
# ---------- TextMessage (user) ----------
# Write a financial report on Microsoft
# ---------- ToolCallRequestEvent (Stock_Analysis_Agent) ----------
# [FunctionCall(id='call_P3t6wmEj8HGagsfWLn9tBbW7', arguments='{"ticker":"MSFT"}', name='stock_analysis_tool')]
# /Users/arturoquiroga/3CLOUD-AUTOGEN/.venv/lib/python3.13/site-packages/autogen_agentchat/agents/_assistant_agent.py:955: UserWarning: Resolved model mismatch: gpt-4o-2024-08-06 != gpt-4o-2024-11-20. Model mapping in autogen_ext.models.openai may be incorrect. Set the model to gpt-4o-2024-11-20 to enhance token/cost estimation and suppress this warning.
#   model_result = await model_client.create(
# Plot saved as coding/MSFT_stockprice.png
# ---------- ToolCallExecutionEvent (Stock_Analysis_Agent) ----------
# [FunctionExecutionResult(content="{'ticker': 'MSFT', 'current_price': 391.16, '52_week_high': 468.35, '52_week_low': 344.79, '50_day_ma': 386.8014581298828, '200_day_ma': 413.85079071044925, 'ytd_price_change': -26.582366943359375, 'ytd_percent_change': -6.363339898902604, 'trend': 'Downward', 'volatility': 0.24853672889653394, 'plot_file_path': 'coding/MSFT_stockprice.png'}", name='stock_analysis_tool', call_id='call_P3t6wmEj8HGagsfWLn9tBbW7', is_error=False)]
# ---------- ToolCallSummaryMessage (Stock_Analysis_Agent) ----------
# {'ticker': 'MSFT', 'current_price': 391.16, '52_week_high': 468.35, '52_week_low': 344.79, '50_day_ma': 386.8014581298828, '200_day_ma': 413.85079071044925, 'ytd_price_change': -26.582366943359375, 'ytd_percent_change': -6.363339898902604, 'trend': 'Downward', 'volatility': 0.24853672889653394, 'plot_file_path': 'coding/MSFT_stockprice.png'}
# ---------- TextMessage (Google_Search_Agent) ----------
# ### Financial Report: Microsoft Corporation (Ticker: MSFT)
#
# #### **Stock Performance Overview**
# - **Current Price:** $391.16
# - **52-Week High:** $468.35
# - **52-Week Low:** $344.79
# - **50-Day Moving Average:** $386.80
# - **200-Day Moving Average:** $413.85
#
# Microsoft's stock price currently sits closer to its 52-week low, indicating a downward trend in comparison to the broader spectrum of its performance in the past year.
#
# ---
#
# #### **Year-to-Date (YTD) Performance**
# - **Price Change:** -$26.58
# - **Percentage Change:** -6.36%
#
# The YTD figures reflect a decline in stock price, reinforcing the current downward trend for Microsoft. This performance could be attributed to broader market conditions or company-specific challenges.
#
# ---
#
# #### **Trend**
# The stock demonstrates a **downward trend**, with the current price falling below its 50-day moving average and significantly below its 200-day moving average. Investors should monitor whether this trend persists, as it could influence future decision-making.
#
# ---
#
# #### **Volatility**
# - **Volatility Level:** **0.25**
#
# The volatility is moderate, indicating some variability in Microsoft's stock price moves. While this level is not alarming, investors should remain cautious about potential sudden changes.
#
# ---
#
# ### **Conclusion**
# Microsoft Corporation is facing a challenging phase in its stock performance, with a downward trend and a noticeable decrease in value year-to-date. Investors should assess the company's fundamentals and broader market conditions when evaluating the stock's future potential.
#
# [Stock Price Plot] (Visual representation path: MSFT_stockprice.png)
# /Users/arturoquiroga/3CLOUD-AUTOGEN/.venv/lib/python3.13/site-packages/autogen_agentchat/agents/_assistant_agent.py:955: UserWarning: Resolved model mismatch: gpt-4o-2024-08-06 != gpt-4o-2024-11-20. Model mapping in autogen_ext.models.openai may be incorrect. Set the model to gpt-4o-2024-11-20 to enhance token/cost estimation and suppress this warning.
#   model_result = await model_client.create(
# ---------- TextMessage (Report_Agent) ----------
# ### Comprehensive Financial Report: Microsoft Corporation (Ticker: MSFT)
#
# ---
#
# #### **Company Overview**
# Microsoft Corporation, headquartered in Redmond, Washington, is one of the largest and most influential technology companies globally. Microsoft is widely recognized for its suite of cloud computing services (Azure), enterprise solutions, and its flagship software products such as Windows OS, Office 365, and Dynamics. In recent years, Microsoft has also expanded into gaming (Xbox), AI initiatives, and a robust portfolio of acquisitions such as LinkedIn and GitHub.
#
# ---
#
# ### **Stock Performance and Analysis**
# Microsoft’s stock performance provides insights into the market's perception of its financial stability and growth potential. Below is a detailed analysis of the stock's position in 2023:
#
# #### **Current Stock Metrics**
# - **Current Price:** $391.16
# - **52-Week High:** $468.35
# - **52-Week Low:** $344.79
# - **50-Day Moving Average:** $386.80
# - **200-Day Moving Average:** $413.85
#
# The downward movement in price compared to its moving averages — particularly the 200-day moving average — showcases an ongoing corrective trend. This information often signals the need for scrutiny of factors potentially influencing such bearish behavior.
#
# #### **Year-to-Date (YTD) Performance**
# - **Price Change:** -$26.58
# - **Percentage Change:** -6.36%
#
# Microsoft’s year-to-date decline reflects a mix of broader economic pressures and company-specific developments. For context, this performance is correlated to conditions such as rising interest rates, tech layoffs observed across the sector, and competitive pressures in cloud computing and enterprise solutions.
#
# #### **Volatility**
# - **Volatility Level:** 0.25 (Moderate)
#
# The volatility metric suggests that Microsoft’s stock has not been overly erratic, but investors should remain vigilant given the stock’s 6.36% YTD decline. Moderation in volatility indicates the absence of sudden panics in the market, but strategic resource allocation by the company would need updates from quarterly financials.
#
# #### **Growth Concerns**
# The stock price remains closer to its 52-week low ($344.79) than its high ($468.35), suggesting limited optimism in growth trajectory unless there are catalysts for recovery imminent.
#
# ---
#
# ### **Financial Fundamentals: Strength Across Ecosystems**
# Microsoft has retained a reputation for financial excellence with historically high margins, reinvestment efficiency, and strength in flagship business units:
#
# #### **Cloud Computing (Azure):**
# Microsoft’s Azure division has been the company’s key driver, contributing significantly to revenues and market share expansion. However, increasing competition from rivals such as Amazon Web Services (AWS) and Google Cloud Platform could potentially put margins under pressure. Recent contracts, including AI partnerships with OpenAI, have positioned Azure as an innovator with immense scalability opportunities.
#
# #### **AI Initiatives:**
# The company has invested heavily in artificial intelligence, notably in OpenAI’s ChatGPT platform via Azure integration. This has expanded Microsoft's SaaS base and brought novel use-case innovations, but monetization challenges remain critical.
#
# #### **Product Diversification:**
# Microsoft’s Office Suite has consistently been a cornerstone of its enterprise services, enabling predictable subscription-based revenues. Coupled with gaming (Xbox and Game Pass) and targeted acquisitions (LinkedIn, Nuance Communications), the company benefits from multi-revenue channels that shield from volatility in any single ecosystem.
#
# ---
#
# ### **Challenges and Market Sentiment**
# While the stock still reflects market leadership due to Microsoft’s wide network effects, the declining price and below-average YTD performance do owe their roots to several macroeconomic and internal factors. These include:
# - **Global Competition in Cloud Computing:** Rivals like AWS and GCP are aggressively growing solutions targeted at small enterprises.
# - **Expenditure on AI Research:** The company’s focus on AI development has translated to high R&D costs.
# - **Constrained Consumer Market for Non-Cloud Segments:** Adoption rates for hardware products and services (e.g., new Xbox consoles) show cyclical declines in certain markets.
#
# Microsoft’s recent focus on AI has yet to generate comparable profitability akin to the pre-existing software-monopolistic wings of its portfolio.
#
# ---
#
# ### **Outlook and Investment Considerations**
# Despite short-term corrections, Microsoft’s fundamentals remain robust and its diversified portfolio makes it a stable long-term investment. The challenges represent macroeconomic hurdles rather than structural weaknesses. Factors to monitor include:
# 1. **Continued Expansion of Azure:** As cloud computing turns into an increasingly saturated field, Azure’s growth and profitability could determine Microsoft’s future trajectory.
# 2. **AI Developments:** Tangible results from recent investments in AI innovation could be a key performance driver in the next few years.
# 3. **Global Macroeconomics:** Microsoft’s performance will be tied to broader economic tides, such as interest rates and inflation, given decline fears circulating across tech stocks.
#
# ---
#
# ### **Current Investment Sentiment**
# The overall sentiment on Microsoft’s stock rests closer to **cautiously optimistic**. Long-term investors still hold confidence in steady dividend growth and strategic innovations, while shorter-term holders appear less bullish amid volatility concerns.
#
# ---
#
# #### **Stock Chart and Graphical Insight**
# - **Stock Price Movement (Visual):** Analysis on whether price rebounds near quarterly earnings (Path: MSFT_stockprice.png).
# Using visual cues such as price channel and RSI indicators could further complement decision-making steps of whether entering based breaks cycle levels sufficiently has historic upswing Near Q-Overlap.
#
# **Investor Note:**
# Trend Interest Questions before argue ST-AI is distributive however newer predict prediction volatility %
#
# ---
# TERMINATE
