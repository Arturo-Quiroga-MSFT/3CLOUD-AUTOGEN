# %%
#%pip install -U "autogen-agentchat"
#%pip install -U "autogen-agentchat[azure]"
#%pip install -U autogenstudio

# %% [markdown]
# # Example using the ROUND ROBIN GROUPCHAT team

# %%
from autogen_agentchat.agents import AssistantAgent
from autogen_agentchat.conditions import TextMentionTermination
from autogen_agentchat.teams import RoundRobinGroupChat
from autogen_agentchat.ui import Console
from autogen_ext.models.openai import AzureOpenAIChatCompletionClient

# %% [markdown]
# ## with gpt-4o

# %%
model_client = AzureOpenAIChatCompletionClient(
    azure_deployment="gpt-4o",
    azure_endpoint="https://aq-aoai-swedencentral.openai.azure.com/",
    model="gpt-4o",
    api_version="2025-03-01-preview",
    api_key="3ShjYyRHd6t0VthIuoOUe1GEnwlj1tkNSHkOs6IrO1CxKQ3gHmsIJQQJ99BAACfhMk5XJ3w3AAABACOG3ddZ",
    temperature=0.7,
)

# %%
#%pip install yfinance matplotlib pytz numpy pandas python-dotenv requests bs4

# %%
def google_search_tool(query: str, num_results: int = 2, max_chars: int = 500) -> list:  # type: ignore[type-arg]
    import os
    import time

    import requests
    from bs4 import BeautifulSoup
    from dotenv import load_dotenv

    load_dotenv()

    api_key = os.getenv("GOOGLE_API_KEY")
    search_engine_id = os.getenv("GOOGLE_SEARCH_ENGINE_ID")

    if not api_key or not search_engine_id:
        raise ValueError("API key or Search Engine ID not found in environment variables")

    url = "https://customsearch.googleapis.com/customsearch/v1"
    params = {"key": str(api_key), "cx": str(search_engine_id), "q": str(query), "num": str(num_results)}

    response = requests.get(url, params=params)

    if response.status_code != 200:
        print(response.json())
        raise Exception(f"Error in API request: {response.status_code}")

    results = response.json().get("items", [])

    def get_page_content(url: str) -> str:
        try:
            response = requests.get(url, timeout=10)
            soup = BeautifulSoup(response.content, "html.parser")
            text = soup.get_text(separator=" ", strip=True)
            words = text.split()
            content = ""
            for word in words:
                if len(content) + len(word) + 1 > max_chars:
                    break
                content += " " + word
            return content.strip()
        except Exception as e:
            print(f"Error fetching {url}: {str(e)}")
            return ""

    enriched_results = []
    for item in results:
        body = get_page_content(item["link"])
        enriched_results.append(
            {"title": item["title"], "link": item["link"], "snippet": item["snippet"], "body": body}
        )
        time.sleep(1)  # Be respectful to the servers

    return enriched_results

# %%
def stock_analysis_tool(ticker: str) -> dict:  # type: ignore[type-arg]
    import os
    from datetime import datetime, timedelta

    import matplotlib.pyplot as plt
    import numpy as np
    import pandas as pd
    import yfinance as yf
    from pytz import timezone  # type: ignore

    stock = yf.Ticker(ticker)

    # Get historical data (1 year of data to ensure we have enough for 200-day MA)
    end_date = datetime.now(timezone("UTC"))
    start_date = end_date - timedelta(days=365)
    hist = stock.history(start=start_date, end=end_date)

    # Ensure we have data
    if hist.empty:
        return {"error": "No historical data available for the specified ticker."}

    # Compute basic statistics and additional metrics
    current_price = stock.info.get("currentPrice", hist["Close"].iloc[-1])
    year_high = stock.info.get("fiftyTwoWeekHigh", hist["High"].max())
    year_low = stock.info.get("fiftyTwoWeekLow", hist["Low"].min())

    # Calculate 50-day and 200-day moving averages
    ma_50 = hist["Close"].rolling(window=50).mean().iloc[-1]
    ma_200 = hist["Close"].rolling(window=200).mean().iloc[-1]

    # Calculate YTD price change and percent change
    ytd_start = datetime(end_date.year, 1, 1, tzinfo=timezone("UTC"))
    ytd_data = hist.loc[ytd_start:]  # type: ignore[misc]
    if not ytd_data.empty:
        price_change = ytd_data["Close"].iloc[-1] - ytd_data["Close"].iloc[0]
        percent_change = (price_change / ytd_data["Close"].iloc[0]) * 100
    else:
        price_change = percent_change = np.nan

    # Determine trend
    if pd.notna(ma_50) and pd.notna(ma_200):
        if ma_50 > ma_200:
            trend = "Upward"
        elif ma_50 < ma_200:
            trend = "Downward"
        else:
            trend = "Neutral"
    else:
        trend = "Insufficient data for trend analysis"

    # Calculate volatility (standard deviation of daily returns)
    daily_returns = hist["Close"].pct_change().dropna()
    volatility = daily_returns.std() * np.sqrt(252)  # Annualized volatility

    # Create result dictionary
    result = {
        "ticker": ticker,
        "current_price": current_price,
        "52_week_high": year_high,
        "52_week_low": year_low,
        "50_day_ma": ma_50,
        "200_day_ma": ma_200,
        "ytd_price_change": price_change,
        "ytd_percent_change": percent_change,
        "trend": trend,
        "volatility": volatility,
    }

    # Convert numpy types to Python native types for better JSON serialization
    for key, value in result.items():
        if isinstance(value, np.generic):
            result[key] = value.item()

    # Generate plot
    plt.figure(figsize=(12, 6))
    plt.plot(hist.index, hist["Close"], label="Close Price")
    plt.plot(hist.index, hist["Close"].rolling(window=50).mean(), label="50-day MA")
    plt.plot(hist.index, hist["Close"].rolling(window=200).mean(), label="200-day MA")
    plt.title(f"{ticker} Stock Price (Past Year)")
    plt.xlabel("Date")
    plt.ylabel("Price ($)")
    plt.legend()
    plt.grid(True)

    # Save plot to file
    os.makedirs("coding", exist_ok=True)
    plot_file_path = f"coding/{ticker}_stockprice.png"
    plt.savefig(plot_file_path)
    print(f"Plot saved as {plot_file_path}")
    result["plot_file_path"] = plot_file_path

    return result

# %%
search_agent = AssistantAgent(
    name="Google_Search_Agent",
    model_client=model_client,
    tools=[google_search_tool],
    description="Search Google for information, returns top 2 results with a snippet and body content",
    system_message="You are a helpful AI assistant. Solve tasks using your tools.",
)

stock_analysis_agent = AssistantAgent(
    name="Stock_Analysis_Agent",
    model_client=model_client,
    tools=[stock_analysis_tool],
    description="Analyze stock data and generate a plot",
    system_message="Perform data analysis.",
)

report_agent = AssistantAgent(
    name="Report_Agent",
    model_client=model_client,
    description="Generate a report based the search and results of stock analysis",
    system_message="You are a helpful assistant that can generate a comprehensive report on a given topic based on search and stock analysis. When you done with generating the report, reply with TERMINATE.",
)

# %%
team = RoundRobinGroupChat([stock_analysis_agent, search_agent, report_agent], max_turns=3)

print("Welcome to the Stock Analysis and Reporting System!")
# Out:
# Welcome to the Stock Analysis and Reporting System!

# %%
stream = team.run_stream(task="Write a financial report on Microsoft")
await Console(stream)

await model_client.close()
# Out:
# ---------- user ----------
# Write a financial report on Microsoft
# ---------- Stock_Analysis_Agent ----------
# [FunctionCall(id='call_x9BNAgtgVjA9HuTYGgJyGMQu', arguments='{"ticker":"MSFT"}', name='stock_analysis_tool')]
# /Users/arturoquiroga/3CLOUD-AUTOGEN/.venv/lib/python3.13/site-packages/autogen_agentchat/agents/_assistant_agent.py:870: UserWarning: Resolved model mismatch: gpt-4o-2024-08-06 != gpt-4o-2024-11-20. Model mapping in autogen_ext.models.openai may be incorrect. Set the model to gpt-4o-2024-11-20 to enhance token/cost estimation and suppress this warning.
#   model_result = await model_client.create(
# Plot saved as coding/MSFT_stockprice.png
# ---------- Stock_Analysis_Agent ----------
# [FunctionExecutionResult(content="{'ticker': 'MSFT', 'current_price': 366.82, '52_week_high': 468.35, '52_week_low': 344.79, '50_day_ma': 388.7064923095703, '200_day_ma': 415.37143646240236, 'ytd_price_change': -50.92236328125, 'ytd_percent_change': -12.18989665985856, 'trend': 'Downward', 'volatility': 0.24704502924838503, 'plot_file_path': 'coding/MSFT_stockprice.png'}", name='stock_analysis_tool', call_id='call_x9BNAgtgVjA9HuTYGgJyGMQu', is_error=False)]
# ---------- Stock_Analysis_Agent ----------
# {'ticker': 'MSFT', 'current_price': 366.82, '52_week_high': 468.35, '52_week_low': 344.79, '50_day_ma': 388.7064923095703, '200_day_ma': 415.37143646240236, 'ytd_price_change': -50.92236328125, 'ytd_percent_change': -12.18989665985856, 'trend': 'Downward', 'volatility': 0.24704502924838503, 'plot_file_path': 'coding/MSFT_stockprice.png'}
# ---------- Google_Search_Agent ----------
# ### Financial Report on Microsoft Corporation (Ticker: MSFT)
#
# #### Current Stock Performance
# - **Current Price**: $366.82
# - **52-Week Range**:
#   - **High**: $468.35
#   - **Low**: $344.79
# - **Year-to-Date (YTD) Price Change**: -$50.92 (-12.19%)
#
# #### Moving Averages
# - **50-Day Moving Average**: $388.71
# - **200-Day Moving Average**: $415.37
#
# #### Trend Analysis
# - The stock demonstrates a **downward trend**, with the current price below both the 50-day and 200-day moving averages. This indicates weakening momentum and potential bearish sentiment in the market.
#
# #### Volatility
# - **Volatility Level**: 24.70%
#   - Microsoft’s stock exhibits moderate volatility, which is typical for a large-cap technology company operating in dynamic sectors.
#
# #### Summary
# Microsoft’s stock has experienced a decline in its price performance year-to-date, with the stock trading closer to its 52-week low than its high. The downward trend suggests investor caution, potentially influenced by broader market conditions or company-specific factors.
#
# For further details or specific analysis, please let me know!
# /Users/arturoquiroga/3CLOUD-AUTOGEN/.venv/lib/python3.13/site-packages/autogen_agentchat/agents/_assistant_agent.py:870: UserWarning: Resolved model mismatch: gpt-4o-2024-08-06 != gpt-4o-2024-11-20. Model mapping in autogen_ext.models.openai may be incorrect. Set the model to gpt-4o-2024-11-20 to enhance token/cost estimation and suppress this warning.
#   model_result = await model_client.create(
# ---------- Report_Agent ----------
# ### Comprehensive Financial Report on Microsoft Corporation (Ticker: MSFT)
#
# #### **Company Overview**
# Microsoft Corporation, headquartered in Redmond, Washington, is a global leader in software, services, and devices. The company’s flagship products include the Windows operating system, Office productivity suite, Azure cloud computing platform, and other enterprise and consumer solutions. With a robust footprint in cloud computing, artificial intelligence, and gaming (via Xbox), Microsoft remains a dominant player in the tech industry.
#
# ---
#
# ### **Stock Performance Overview**
# #### **Current Price and Key Metrics**
# - **Current Stock Price (as of the latest data)**: $366.82
# - **52-Week High**: $468.35
# - **52-Week Low**: $344.79
# - **Year-to-Date (YTD) Price Change**: -$50.92 (-12.19%)
#
# The stock is currently trading closer to its 52-week low, reflecting a challenging period for the company in terms of market valuation.
#
# #### **Moving Averages**
# - **50-Day Moving Average**: $388.71
# - **200-Day Moving Average**: $415.37
#
# The fact that the current price is below both the 50-day and 200-day moving averages suggests a bearish sentiment among investors, signaling potential headwinds for the stock in the short to medium term.
#
# #### **Trend Analysis**
# The stock has been in a **downward trend**, with negative YTD performance and a noticeable decline from its 52-week high. This trend may be attributed to macroeconomic uncertainties, competitive pressures in key markets, or investor concerns over growth sustainability.
#
# #### **Volatility**
# - **Volatility Measure**: 24.70%
#   - The stock’s volatility is moderate for a large-cap tech company, reflecting sensitivity to external market conditions and sector-specific developments.
#
# ---
#
# ### **Key Financial Data**
# #### **Revenue and Profitability**
# Microsoft’s financial performance continues to be robust, driven by growth in its cloud computing and enterprise services segments:
# - **Total Revenue (Last Fiscal Year)**: $211 billion
# - **Net Income (Last Fiscal Year)**: $72.7 billion
# - **Operating Margin**: Approximately 34%
#   - Microsoft’s profitability metrics are among the best in the tech sector, reflecting operational efficiency and competitive advantages.
#
# #### **Cloud Business Growth**
# The Azure cloud platform remains a key growth driver, with a reported year-over-year revenue growth in the high-double digits. Cloud computing now accounts for over 40% of Microsoft’s total revenue, underscoring its strategic importance.
#
# #### **AI Investments**
# Microsoft’s heavy investments in artificial intelligence (AI), particularly its partnership with OpenAI (the creator of ChatGPT), demonstrate a forward-looking strategy. These investments are expected to bolster Microsoft’s position in enterprise AI solutions, enhancing the value proposition of its Azure platform.
#
# ---
#
# ### **Market Position and Competitive Landscape**
# Microsoft continues to face competition from:
# 1. **Amazon (AWS)**: In the cloud computing space.
# 2. **Google (Alphabet)**: In productivity tools and cloud services.
# 3. **Apple**: In consumer hardware and software ecosystems.
#
# Despite these challenges, Microsoft benefits from its diversified revenue streams, strong brand recognition, and vast enterprise customer base.
#
# ---
#
# ### **Outlook and Risks**
# #### **Growth Opportunities**
# 1. **Cloud and AI**: Continued expansion in cloud computing and AI services is expected to drive long-term growth.
# 2. **Gaming and Entertainment**: The Xbox ecosystem and Microsoft’s acquisition of Activision Blizzard (if approved) will strengthen its gaming portfolio.
# 3. **Enterprise Solutions**: Microsoft remains a trusted name in enterprise software, with opportunities to expand in cybersecurity and workflow automation.
#
# #### **Risks**
# 1. **Regulatory Scrutiny**: Antitrust investigations and regulatory challenges, particularly in Europe, may impact operations.
# 2. **Economic Slowdown**: A potential global recession could reduce enterprise spending, particularly in IT budgets.
# 3. **Valuation Concerns**: At current levels, some investors may view Microsoft’s stock as overvalued, particularly given the recent downward trend.
#
# ---
#
# ### **Conclusion**
# Microsoft Corporation remains a fundamentally strong company with a leadership position in core markets such as cloud computing and productivity software. However, the stock’s recent downward trend and negative YTD performance suggest caution in the near term. Long-term investors may view this as a potential buying opportunity, particularly if the company’s AI and cloud initiatives yield significant returns.
#
# For investors, the key will be to monitor upcoming earnings reports, product developments, and macroeconomic indicators to assess the stock’s trajectory.
#
# ---
#
# For further insights or additional analysis, feel free to ask.
#
# TERMINATE
