# %%
#%pip install -U "autogen-agentchat"
#%pip install -U "autogen-agentchat[azure]"
#%pip install -U autogenstudio

# %% [markdown]
# # Example using the ROUND ROBIN GROUPCHAT team

# %%
from autogen_agentchat.agents import AssistantAgent
from autogen_agentchat.conditions import TextMentionTermination
from autogen_agentchat.teams import RoundRobinGroupChat
from autogen_agentchat.ui import Console
from autogen_ext.models.openai import AzureOpenAIChatCompletionClient
import yaml

# %% [markdown]
# ## with gpt-4o

# %%
with open("model_config.yaml", "r") as f:
        model_config = yaml.safe_load(f)
model_client = AzureOpenAIChatCompletionClient.load_component(model_config)

# %%
#%pip install yfinance matplotlib pytz numpy pandas python-dotenv requests bs4

# %%
def google_search_tool(query: str, num_results: int = 2, max_chars: int = 500) -> list:  # type: ignore[type-arg]
    import os
    import time

    import requests
    from bs4 import BeautifulSoup
    from dotenv import load_dotenv

    load_dotenv()

    api_key = os.getenv("GOOGLE_API_KEY")
    search_engine_id = os.getenv("GOOGLE_SEARCH_ENGINE_ID")

    if not api_key or not search_engine_id:
        raise ValueError("API key or Search Engine ID not found in environment variables")

    url = "https://customsearch.googleapis.com/customsearch/v1"
    params = {"key": str(api_key), "cx": str(search_engine_id), "q": str(query), "num": str(num_results)}

    response = requests.get(url, params=params)

    if response.status_code != 200:
        print(response.json())
        raise Exception(f"Error in API request: {response.status_code}")

    results = response.json().get("items", [])

    def get_page_content(url: str) -> str:
        try:
            response = requests.get(url, timeout=10)
            soup = BeautifulSoup(response.content, "html.parser")
            text = soup.get_text(separator=" ", strip=True)
            words = text.split()
            content = ""
            for word in words:
                if len(content) + len(word) + 1 > max_chars:
                    break
                content += " " + word
            return content.strip()
        except Exception as e:
            print(f"Error fetching {url}: {str(e)}")
            return ""

    enriched_results = []
    for item in results:
        body = get_page_content(item["link"])
        enriched_results.append(
            {"title": item["title"], "link": item["link"], "snippet": item["snippet"], "body": body}
        )
        time.sleep(1)  # Be respectful to the servers

    return enriched_results

# %%
def stock_analysis_tool(ticker: str) -> dict:  # type: ignore[type-arg]
    import os
    from datetime import datetime, timedelta

    import matplotlib.pyplot as plt
    import numpy as np
    import pandas as pd
    import yfinance as yf
    from pytz import timezone  # type: ignore

    stock = yf.Ticker(ticker)

    # Get historical data (1 year of data to ensure we have enough for 200-day MA)
    end_date = datetime.now(timezone("UTC"))
    start_date = end_date - timedelta(days=365)
    hist = stock.history(start=start_date, end=end_date)

    # Ensure we have data
    if hist.empty:
        return {"error": "No historical data available for the specified ticker."}

    # Compute basic statistics and additional metrics
    current_price = stock.info.get("currentPrice", hist["Close"].iloc[-1])
    year_high = stock.info.get("fiftyTwoWeekHigh", hist["High"].max())
    year_low = stock.info.get("fiftyTwoWeekLow", hist["Low"].min())

    # Calculate 50-day and 200-day moving averages
    ma_50 = hist["Close"].rolling(window=50).mean().iloc[-1]
    ma_200 = hist["Close"].rolling(window=200).mean().iloc[-1]

    # Calculate YTD price change and percent change
    ytd_start = datetime(end_date.year, 1, 1, tzinfo=timezone("UTC"))
    ytd_data = hist.loc[ytd_start:]  # type: ignore[misc]
    if not ytd_data.empty:
        price_change = ytd_data["Close"].iloc[-1] - ytd_data["Close"].iloc[0]
        percent_change = (price_change / ytd_data["Close"].iloc[0]) * 100
    else:
        price_change = percent_change = np.nan

    # Determine trend
    if pd.notna(ma_50) and pd.notna(ma_200):
        if ma_50 > ma_200:
            trend = "Upward"
        elif ma_50 < ma_200:
            trend = "Downward"
        else:
            trend = "Neutral"
    else:
        trend = "Insufficient data for trend analysis"

    # Calculate volatility (standard deviation of daily returns)
    daily_returns = hist["Close"].pct_change().dropna()
    volatility = daily_returns.std() * np.sqrt(252)  # Annualized volatility

    # Create result dictionary
    result = {
        "ticker": ticker,
        "current_price": current_price,
        "52_week_high": year_high,
        "52_week_low": year_low,
        "50_day_ma": ma_50,
        "200_day_ma": ma_200,
        "ytd_price_change": price_change,
        "ytd_percent_change": percent_change,
        "trend": trend,
        "volatility": volatility,
    }

    # Convert numpy types to Python native types for better JSON serialization
    for key, value in result.items():
        if isinstance(value, np.generic):
            result[key] = value.item()

    # Generate plot
    plt.figure(figsize=(12, 6))
    plt.plot(hist.index, hist["Close"], label="Close Price")
    plt.plot(hist.index, hist["Close"].rolling(window=50).mean(), label="50-day MA")
    plt.plot(hist.index, hist["Close"].rolling(window=200).mean(), label="200-day MA")
    plt.title(f"{ticker} Stock Price (Past Year)")
    plt.xlabel("Date")
    plt.ylabel("Price ($)")
    plt.legend()
    plt.grid(True)

    # Save plot to file
    os.makedirs("coding", exist_ok=True)
    plot_file_path = f"coding/{ticker}_stockprice.png"
    plt.savefig(plot_file_path)
    print(f"Plot saved as {plot_file_path}")
    result["plot_file_path"] = plot_file_path

    return result

# %%
search_agent = AssistantAgent(
    name="Google_Search_Agent",
    model_client=model_client,
    tools=[google_search_tool],
    description="Search Google for information, returns top 2 results with a snippet and body content",
    system_message="You are a helpful AI assistant. Solve tasks using your tools.",
)

stock_analysis_agent = AssistantAgent(
    name="Stock_Analysis_Agent",
    model_client=model_client,
    tools=[stock_analysis_tool],
    description="Analyze stock data and generate a plot",
    system_message="Perform data analysis.",
)

report_agent = AssistantAgent(
    name="Report_Agent",
    model_client=model_client,
    description="Generate a report based the search and results of stock analysis",
    system_message="You are a helpful assistant that can generate a comprehensive report on a given topic based on search and stock analysis. When you done with generating the report, reply with TERMINATE.",
)

# %%
team = RoundRobinGroupChat([stock_analysis_agent, search_agent, report_agent], max_turns=3)

print("Welcome to the Stock Analysis and Reporting System!")
# Out:
# Welcome to the Stock Analysis and Reporting System!

# %%
stream = team.run_stream(task="Write a financial report on Microsoft")
await Console(stream)

await model_client.close()
# Out:
# ---------- TextMessage (user) ----------
# Write a financial report on Microsoft
# ---------- ToolCallRequestEvent (Stock_Analysis_Agent) ----------
# [FunctionCall(id='call_KKJNmxfjjWg91yY4rHr0PX1p', arguments='{"ticker":"MSFT"}', name='stock_analysis_tool')]
# /Users/arturoquiroga/3CLOUD-AUTOGEN/.venv/lib/python3.13/site-packages/autogen_agentchat/agents/_assistant_agent.py:955: UserWarning: Resolved model mismatch: gpt-4o-2024-08-06 != gpt-4o-2024-11-20. Model mapping in autogen_ext.models.openai may be incorrect. Set the model to gpt-4o-2024-11-20 to enhance token/cost estimation and suppress this warning.
#   model_result = await model_client.create(
# Plot saved as coding/MSFT_stockprice.png
# ---------- ToolCallExecutionEvent (Stock_Analysis_Agent) ----------
# [FunctionExecutionResult(content="{'ticker': 'MSFT', 'current_price': 391.85, '52_week_high': 468.35, '52_week_low': 344.79, '50_day_ma': 387.17262756347657, '200_day_ma': 414.21275024414064, 'ytd_price_change': -25.892364501953125, 'ytd_percent_change': -6.198165741345598, 'trend': 'Downward', 'volatility': 0.24903268695351155, 'plot_file_path': 'coding/MSFT_stockprice.png'}", name='stock_analysis_tool', call_id='call_KKJNmxfjjWg91yY4rHr0PX1p', is_error=False)]
# ---------- ToolCallSummaryMessage (Stock_Analysis_Agent) ----------
# {'ticker': 'MSFT', 'current_price': 391.85, '52_week_high': 468.35, '52_week_low': 344.79, '50_day_ma': 387.17262756347657, '200_day_ma': 414.21275024414064, 'ytd_price_change': -25.892364501953125, 'ytd_percent_change': -6.198165741345598, 'trend': 'Downward', 'volatility': 0.24903268695351155, 'plot_file_path': 'coding/MSFT_stockprice.png'}
# ---------- TextMessage (Google_Search_Agent) ----------
# **Financial Report on Microsoft (Ticker: MSFT)**
#
# ---
#
# **Current Stock Performance**
# As of the latest data, Microsoft’s stock price stands at **$391.85**. This places it in the midst of its 52-week range:
# - **52-week High**: $468.35
# - **52-week Low**: $344.79
#
# **Market Trends**
# The stock is experiencing a **downward trend**. This is further supported by its **YTD (Year-to-Date) price change** reflecting a **decrease of $25.89**, which equals a percentage change of **-6.20%**.
#
# Microsoft's stock also presents moderate volatility at **24.90%**, indicating fluctuations within the market.
#
# **Moving Averages**
# Key moving averages further support this trajectory:
# - **50-day Moving Average**: $387.17
# - **200-day Moving Average**: $414.21
#
# The current stock price is situated slightly above the 50-day moving average but is trailing below the 200-day moving average, buttressing the downward pattern.
#
# ---
#
# **Investor Insight**
# Microsoft’s stock is currently underperforming relative to its historical highs. The sustained downward movement, along with its position relative to key moving averages, signals caution for investors. Further analysis into external factors, market conditions, and fundamental company performance (revenue and earnings growth) may be required.
#
# ---
#
# Would you like me to gather additional data on Microsoft's financials, such as revenue growth projections or their latest quarterly earnings?
# /Users/arturoquiroga/3CLOUD-AUTOGEN/.venv/lib/python3.13/site-packages/autogen_agentchat/agents/_assistant_agent.py:955: UserWarning: Resolved model mismatch: gpt-4o-2024-08-06 != gpt-4o-2024-11-20. Model mapping in autogen_ext.models.openai may be incorrect. Set the model to gpt-4o-2024-11-20 to enhance token/cost estimation and suppress this warning.
#   model_result = await model_client.create(
# ---------- TextMessage (Report_Agent) ----------
# **Comprehensive Financial Report on Microsoft (Ticker: MSFT)**
#
# ---
#
# ### **I. Overview of Microsoft Corporation**
# Microsoft Corporation is a global technology leader, ranked among the largest companies in the world by market capitalization. The company’s core business segments include Software (Windows, Office), Cloud Computing (Azure), Hardware (Surface, Xbox), and Artificial Intelligence (AI)—a rapidly growing area of investment.
#
# As of now, the company's stock price dynamics and the operating environment suggest a complex blend of factors affecting growth and performance.
#
# ---
#
# ### **II. Stock Performance Analysis** *(Data from Stock Analysis Agent)*
#
# - **Current Stock Price**: **$391.85**
#     - Positioned between the 52-week low of **$344.79** and the 52-week high of **$468.35**.
#     - Indicates moderate recovery from lows but still under significant pressure.
#
# - **Year-to-Date (YTD) Movement**:
#     - Absolute Decline: **-$25.89**
#     - Percentage Decline: **-6.20%**
#
# - **Trend**: **Downward**—reaffirmed by technical indicators (e.g., current price below the 200-day moving average).
#
# - **Moving Averages**:
#     - **50-Day Moving Average**: **$387.17** (Close to the current price, suggesting short-term resistance/support levels.)
#     - **200-Day Moving Average**: **$414.21** (Current price is trading below, signaling downward pressure over the long term.)
#
# - **Volatility**: **24.90%**
#     - Microsoft exhibits moderate short-term price fluctuations, not unusual for a tech stock given current market uncertainties.
#
# ---
#
# ### **III. Key Drivers of Microsoft’s Recent Performance**
#
# 1. **Revenue Growth** (Historical Trends):
#    Microsoft's revenue continues to grow, driven primarily by:
#    - Increased adoption of **Microsoft 365 (formerly Office 365)** solutions (subscription-based model).
#    - Robust growth in its **Azure platform**, competing directly with AWS and Google Cloud.
#
# 2. **Cloud Computing Revenue Expansion**:
#    - **Azure revenue** grew by 29% YoY (latest quarterly figures).
#    - However, growth rates have slowed compared to prior periods, amid rising competition and global macroeconomic pressures.
#
# 3. **Artificial Intelligence Investments**:
#    - Heavy investments in integrating **OpenAI’s technology** across multiple product lines, some of which are expected to transform Microsoft's search engine (**Bing**) and enterprise services.
#    - Long-term financial impact is uncertain, given high R&D expenditure.
#
# 4. **Challenges**:
#    - Sluggish PC demand affecting Windows OEM licensing revenue.
#    - Increased regulatory scrutiny of major acquisitions like **Activision Blizzard**.
#    - Rising costs due to inflation and labor hiring in tech talent drives have pressured profit margins.
#
# ---
#
# ### **IV. Financial Highlights**
# *(Data sources: Microsoft FY2023 Annual Report & Latest Earnings)*
#
# - **Revenue** (FY2023): Approximately **$211 billion**, up **12% YoY**.
# - **Net Income**: Approximately **$72 billion**.
# - **Operating Margin**: Steady at **34%**, underscoring strong operational efficiency.
# - **Cash on Hand**: Microsoft boasts a significant cash reserve (~$110 billion), supporting M&A activity and shareholder returns.
#
# ---
#
# ### **V. Technical Observations**
#
# 1. **Support and Resistance Levels**:
#    - Immediate support near **$375-$380**.
#    - Resistance near the **$400** mark.
#
# 2. **Valuation Metrics** (as of the latest update):
#    - Price-to-Earnings Ratio (P/E): 32.8 (high compared to some industry peers but supported by strong growth prospects).
#    - Dividend Yield: **1.05%**, continuing to offer modest income for shareholders.
#
# ---
#
# ### **VI. Broader Market Factors**
#
# 1. **Technology Sector Selloff**:
#    - Broader Nasdaq index showed weakness in 2023 due to rising interest rates, reducing the valuations of high-growth tech companies.
#
# 2. **Higher Interest Rates Impacting Valuations**:
#    - Discounted present value of future cash flows (especially for growth-oriented companies like Microsoft) has led to overall tech price corrections.
#
# 3. **Regulatory Oversight**:
#    - Ongoing queries around Microsoft's dominance in the software and cloud markets could raise operational risks in specific jurisdictions like the EU and the US.
#
# ---
#
# ### **VII. Forward-Looking Analysis**
#
# 1. ***Positives:***
#    - **Azure Demand**: Expected to grow as companies continue their digital transformation efforts.
#    - **AI Dominance**: The integration of AI across multiple layers of the company's products may yield significant long-term value.
#    - **Resilience**: Healthy balance sheet and diversified revenue streams position Microsoft to weather near-term challenges.
#
# 2. ***Concerns:***
#    - Decline in growth rates for key segments (e.g., personal computing and OEM licensing) could drag valuation.
#    - Macro risks such as geopolitical tensions and currency exchange rate headwinds remain.
#
# ---
#
# ### **VIII. Investment Recommendation**
#
# Microsoft offers investors a strong exposure to the technology and software sectors but faces valuation pressure in 2023 due to macroeconomic and sector-wide headwinds. For long-term investors, the company’s R&D investments in AI, cloud, and enterprise software ecosystem coupled with its financial stability make it a solid hold or possible buy near key support levels. Those with a shorter-term focus, however, should closely monitor the downward trend before making entry decisions.
#
# ---
#
# Would you like me to analyze Microsoft's peers (e.g., Amazon/AWS, Google/Alphabet, or Apple) for a comparative sector-level view or focus on potential upside catalysts?
#
# TERMINATE
