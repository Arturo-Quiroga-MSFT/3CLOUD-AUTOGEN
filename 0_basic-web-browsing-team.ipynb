# %%
# pip install -U autogen-agentchat autogen-ext[openai,web-surfer]
# playwright install

# %% [markdown]
# ## Example using the ROUND ROBING GROUPCHAT team with a USER PROXY AGENT and a MULTIMODAL WEBSURFER

# %%
import asyncio
from autogen_agentchat.agents import UserProxyAgent
from autogen_agentchat.conditions import TextMentionTermination
from autogen_agentchat.teams import RoundRobinGroupChat
from autogen_agentchat.ui import Console
from autogen_ext.models.openai import AzureOpenAIChatCompletionClient
from autogen_ext.agents.web_surfer import MultimodalWebSurfer

# %%
model_client = AzureOpenAIChatCompletionClient(
    azure_deployment="gpt-4o",
    azure_endpoint="https://aq-aoai-swedencentral.openai.azure.com/",
    model="gpt-4o",
    api_version="2025-03-01-preview",
    api_key="3ShjYyRHd6t0VthIuoOUe1GEnwlj1tkNSHkOs6IrO1CxKQ3gHmsIJQQJ99BAACfhMk5XJ3w3AAABACOG3ddZ",
    temperature=0.7,
)

# %%
async def main() -> None:
    # The web surfer will open a Chromium browser window to perform web browsing tasks.
    web_surfer = MultimodalWebSurfer("web_surfer", model_client, headless=False, animate_actions=True)
    # The user proxy agent is used to get user input after each step of the web surfer.
    # NOTE: you can skip input by pressing Enter.
    user_proxy = UserProxyAgent("user_proxy")
    # The termination condition is set to end the conversation when the user types 'exit'.
    termination = TextMentionTermination("exit", sources=["user_proxy"])
    # Web surfer and user proxy take turns in a round-robin fashion.
    team = RoundRobinGroupChat([web_surfer, user_proxy], termination_condition=termination)
    try:
        # Start the team and wait for it to terminate.
        await Console(team.run_stream(task="find information about the latest iPhone"))
    finally:
        await web_surfer.close()
        await model_client.close()

await main()
# Out:
# ---------- user ----------
# find information about the latest iPhone
# /Users/arturoquiroga/3CLOUD-AUTOGEN/.venv/lib/python3.13/site-packages/autogen_ext/agents/web_surfer/_multimodal_web_surfer.py:612: UserWarning: Resolved model mismatch: gpt-4o-2024-08-06 != gpt-4o-2024-11-20. Model mapping in autogen_ext.models.openai may be incorrect. Set the model to gpt-4o-2024-11-20 to enhance token/cost estimation and suppress this warning.
#   response = await self._model_client.create(
# ---------- web_surfer ----------
# I typed 'latest iPhone' into '0 characters out of 2000'.
#
# The web browser is open to the page [latest iPhone - Search](https://www.bing.com/search?q=latest+iPhone&form=QBLH&sp=-1&lq=0&pq=latest+iphon&sc=12-12&qs=n&sk=&cvid=B0B9CA1E640F47BF8CC9919AB1874DB1).
# The viewport shows 27% of the webpage, and is positioned at the top of the page
# The following text is visible in the viewport:
#
# Skip to content
# latest iPhoneFrançaisMobileScan the QR code to turn your words into art with the Bing app.
# Learn more
# Later
# All
# Search
# Shopping
# Images
# Videos
# Maps
# Copilot
# More
# Tools
# About 1,840,000 resultsSponsored
# See Latest iPhoneiPhone 16 Pro 128GB Black Titanium Unlocked- Apple$1,449.00Apple Store
# 7iPhone 16 Pro Max 256GB With 2-Yr Phone Plan On Bell Smartpay + Device Return Option$1,799.28 now$42/mo x 24
# Bell MobilityiPhone 16E 128GB With 2-Yr Phone Plan On Bell Smartpay + Device Return Option$924.48 now$26.02/mo x 24
# Bell MobilityiPhone 16 Pro 128GB With 2-Yr Phone Plan On Bell Smartpay + Device Return Option$1,490.40 now$37/mo x 24
# Bell MobilityiPhone 15 Pro Max 512GB With 2-Yr Phone Plan On Bell Smartpay + Device Return Option$1,953.72 now$37.47/mo x 24
# Bell MobilityiPhone 16 256GB With 2-Yr Phone Plan On Bell Smartpay + Device Return Option$1,315.44 now$39.81/mo x 24
# Bell MobilityApple iPhone 13 (256 GB) - Blue
# $689.00Amazon CA
# 1iPhone 16 Pro 256GB Desert Titanium Unlocked- Apple$1,599.00Apple StoreiPhone 16 Plus 256GB With 2-Yr Phone Plan On Bell Smartpay + Device Return Option$1,469.88 now$41.44/mo x 24
# Bell MobilityiPhone 14 128GB With 2-Yr Phone Plan On Bell Smartpay + Device Return Option$873.72 now$36.41/mo x 24
# Bell MobilityExplore
# Apple iPhone
# iPhone 13
# iPhone 14
# iPhone 16
# New iPhone
# iPhone 11
# iPhone 13 Pro Max
# iPhones for Sale
# iPhone 13 Pro
# iPhone Latest Model
# Apple
# https://www.apple.com › caiPhone | Apple Official Site | Explore the lineupSponsored
# Introducing iPhone 16e. Explore iPhone 16 and iPhone 16 Pro. Learn more. Designed to be loved. Take a closer look at our latest models.
# Compare all iPhone models
# Buy iPhone 16
# Shop iPhone
# Buy iPhone 16 Pro
# Apple Trade In
# Apple
# https://www.apple.com › ca › iphone
# iPhone - Apple (CA)
# Shop Latest iPhone
# bing.com/shop
#
# The following metadata was extracted from the webpage:
#
# {
#     "meta_tags": {
#         "referrer": "origin-when-cross-origin",
#         "SystemEntropyOriginTrialToken": "A5is4nwJJVnhaJpUr1URgj4vvAXSiHoK0VBbM9fawMskbDUj9WUREpa3JzGAo6xd1Cp2voQEG1h6NQ71AsMznU8AAABxeyJvcmlnaW4iOiJodHRwczovL3d3dy5iaW5nLmNvbTo0NDMiLCJmZWF0dXJlIjoiTXNVc2VyQWdlbnRMYXVuY2hOYXZUeXBlIiwiZXhwaXJ5IjoxNzUzNzQ3MjAwLCJpc1N1YmRvbWFpbiI6dHJ1ZX0=",
#         "ConfidenceOriginTrialToken": "Aqw360MHzRcmtEVv55zzdIWcTk2BBYHcdBAOysNJZP4qkN8M+5vUq36ITHFVst8LiX36KBZJXB8xvyBgdK2z5Q0AAAB6eyJvcmlnaW4iOiJodHRwczovL2JpbmcuY29tOjQ0MyIsImZlYXR1cmUiOiJQZXJmb3JtYW5jZU5hdmlnYXRpb25UaW1pbmdDb25maWRlbmNlIiwiZXhwaXJ5IjoxNzYwNDAwMDAwLCJpc1N1YmRvbWFpbiI6dHJ1ZX0=",
#         "og:description": "Intelligent search from Bing makes it easier to quickly find what you\u2019re looking for and rewards you.",
#         "og:site_name": "Bing",
#         "og:title": "latest iPhone - Bing",
#         "og:url": "https://www.bing.com/search?q=latest+iPhone&form=QBLH&sp=-1&lq=0&pq=latest+iphon&sc=12-12&qs=n&sk=&cvid=B0B9CA1E640F47BF8CC9919AB1874DB1",
#         "fb:app_id": "3732605936979161",
#         "og:image": "http://www.bing.com/sa/simg/facebook_sharing_5.png",
#         "og:type": "website",
#         "og:image:width": "600",
#         "og:image:height": "315"
#     }
# }
#
# Here is a screenshot of the page.
#
# ---------- user_proxy ----------
#
# ---------- web_surfer ----------
# The Bing search results for "latest iPhone" highlight the newest models, including the iPhone 16 and iPhone 16 Pro, featuring advanced cameras, Apple Intelligence, and 5G capability. These devices emphasize customization, environmental friendliness, and privacy protection. Pricing varies depending on models and retailers, with options for installment payments. The Apple website provides detailed information, comparisons between models, and purchasing options for the latest iPhone lineup.
# /Users/arturoquiroga/3CLOUD-AUTOGEN/.venv/lib/python3.13/site-packages/autogen_ext/agents/web_surfer/_multimodal_web_surfer.py:951: UserWarning: Resolved model mismatch: gpt-4o-2024-08-06 != gpt-4o-2024-11-20. Model mapping in autogen_ext.models.openai may be incorrect. Set the model to gpt-4o-2024-11-20 to enhance token/cost estimation and suppress this warning.
#   response = await self._model_client.create(messages, cancellation_token=cancellation_token)
# ---------- user_proxy ----------
# continue writing the report
# continue writing the report
# ---------- web_surfer ----------
# The latest iPhone models showcased include the iPhone 16 Pro, iPhone 16 Pro Max, iPhone 16E, and iPhone 16 Plus. These devices feature advanced specifications such as increased storage options, enhanced camera capabilities, and elegant designs including Titanium finishes. Prices vary depending on the model and retailer, with installment plans available for affordability. For example:
#
# - The iPhone 16 Pro (128GB Black Titanium) is priced at $1,449.00.
# - The iPhone 16 Pro Max (256GB) is available for $1,799.28 or $42/month for 24 months.
# - The iPhone 16E (128GB) is priced at $924.48 or $26.02/month for 24 months.
# - The iPhone 16 Plus (256GB) is priced at $1,469.88 or $41.44/month for 24 months.
#
# The official Apple website provides further details and comparisons between models, alongside options to purchase or trade in older devices. Additional features like Apple Trade-In and environmental considerations are emphasized.
#
# Retailers such as Bell Mobility and Amazon offer competitive pricing and payment plans for these models.
# ---------- user_proxy ----------
# get info about the latest macbook
# ---------- web_surfer ----------
# I typed 'latest MacBook' into the browser search bar.
#
# The web browser is open to the page [latest MacBook - Search](https://www.bing.com/search?q=latest+MacBook&FORM=QBLH).
# The viewport shows 29% of the webpage, and is positioned at the top of the page
# The following text is visible in the viewport:
#
# Skip to content
# latest MacBookFrançaisMobileAll
# Search
# Shopping
# Images
# Videos
# Maps
# Copilot
# More
# Tools
# About 2,630,000 resultsSponsored
# See Latest MacbookMacbook Pro M4 Pro 16-Inch (2024) - 24GB RAM, 512GB SSD - Space Black - Apple - Apple$3,299.00Apple Store14-day returns13-In. Macbook Air Laptop - M4 Chip, 256GB - Midnight - Apple - Apple$1,399.00Apple Store14-day returns15-In. Macbook Air Laptop - M4 Chip, 512GB - Sky Blue - Apple - Apple$2,299.00Apple Store13-In. Macbook Air Laptop - M4 Chip, 256GB - Silver - Apple - Apple$1,399.00Apple StoreFree shipping13-In. Macbook Air Laptop - M4 Chip, 256GB - Sky Blue - Apple - Apple$1,399.00Apple Store14-day returns13-In. Macbook Air Laptop - M4 Chip, 512GB - Starlight - Apple - Apple$1,699.00Apple Store14-day returnsApple 2024 Macbook Air 15-Inch Laptop With M3 Chip: Built For Apple Intelligence, 15.3-Inch Liquid Retina Display, 24GB Unified Memory, 512GB SSD$2,278.22Amazon CAApple 2024 Macbook Air 15-Inch Laptop With M3 Chip: Built For Apple Intelligence, 15.3-Inch Liquid Retina Display, 8GB Unified Memory, 512GB SSD$1,999.00Amazon CA
# 300Apple 2025 Macbook Air 13-Inch Laptop With M4 Chip: Built For Apple Intelligence, 16GB Unified Memory, 512GB SSD Storage, Touch ID Sky Blue -$1,699.00Amazon CAApple 15.4" Macbook Pro Laptop (Retina, Touch Bar, 2.2Ghz 6-Core Intel Core I7, 16GB RAM, 256GB SSD Storage) Space Gray (MR932LL/A) (2018 Model)$749.00Amazon CAExplore
# MacBook Pro
# MacBook Air
# Apple MacBook
# Apple MacBook Pro
# MacBook Air M1
# Apple MacBook Air
# MacBook Price
# MacBook Laptop
# MacBook Pro 16
# MacBook Pro M2
# Apple
# https://www.apple.com › ca › mac
# Mac - Apple (CA)The most powerful Mac laptops and desktops ever. Supercharged by Apple silicon. MacBook Air, MacBook Pro, iMac, Mac mini, Mac Studio and Mac Pro.
# Other content from apple.comMacBook Pro - Apple (CA)MacBook Pro - AppleMac - Apple
# MacBook ProLine of Mac laptop computersThe MacBook Pro is a line of Mac laptop computers developed and manufactured by Apple. Introduced in 2006, it is the high-end sibling of the MacBook family, sitting above the ultra-portable MacBook Ai…Wikipedia
# Developer
# AppleManufacturer
# Foxconn · PegatronProduct family
# MacBookType
# Laptop
#
# The following metadata was extracted from the webpage:
#
# {
#     "meta_tags": {
#         "referrer": "origin-when-cross-origin",
#         "SystemEntropyOriginTrialToken": "A5is4nwJJVnhaJpUr1URgj4vvAXSiHoK0VBbM9fawMskbDUj9WUREpa3JzGAo6xd1Cp2voQEG1h6NQ71AsMznU8AAABxeyJvcmlnaW4iOiJodHRwczovL3d3dy5iaW5nLmNvbTo0NDMiLCJmZWF0dXJlIjoiTXNVc2VyQWdlbnRMYXVuY2hOYXZUeXBlIiwiZXhwaXJ5IjoxNzUzNzQ3MjAwLCJpc1N1YmRvbWFpbiI6dHJ1ZX0=",
#         "ConfidenceOriginTrialToken": "Aqw360MHzRcmtEVv55zzdIWcTk2BBYHcdBAOysNJZP4qkN8M+5vUq36ITHFVst8LiX36KBZJXB8xvyBgdK2z5Q0AAAB6eyJvcmlnaW4iOiJodHRwczovL2JpbmcuY29tOjQ0MyIsImZlYXR1cmUiOiJQZXJmb3JtYW5jZU5hdmlnYXRpb25UaW1pbmdDb25maWRlbmNlIiwiZXhwaXJ5IjoxNzYwNDAwMDAwLCJpc1N1YmRvbWFpbiI6dHJ1ZX0=",
#         "og:description": "Intelligent search from Bing makes it easier to quickly find what you\u2019re looking for and rewards you.",
#         "og:site_name": "Bing",
#         "og:title": "latest MacBook - Bing",
#         "og:url": "https://www.bing.com/search?q=latest+MacBook&FORM=QBLH",
#         "fb:app_id": "3732605936979161",
#         "og:image": "http://www.bing.com/sa/simg/facebook_sharing_5.png",
#         "og:type": "website",
#         "og:image:width": "600",
#         "og:image:height": "315"
#     }
# }
#
# Here is a screenshot of the page.
#
# ---------- user_proxy ----------
# write me a report of the latest macbook and its potential use for agentic ai development
# ---------- web_surfer ----------
# The latest MacBook models include the MacBook Pro 16-inch (2024) and the MacBook Air 15-inch (2024), equipped with advanced Apple silicon chips like the M4 and M3 respectively. These devices are designed to deliver exceptional performance, making them ideal for demanding computational tasks.
#
# ### Specifications:
#
# 1. **MacBook Pro M4 Pro 16-inch (2024)**:
#    - **RAM**: 24GB
#    - **Storage**: 512GB SSD
#    - **Color**: Space Black
#    - **Price**: $3,299.00 (Apple Store)
#
# 2. **MacBook Air M3 15-inch (2024)**:
#    - **Display**: 15.3-inch Liquid Retina
#    - **Memory Options**: 8GB or 24GB Unified Memory
#    - **Storage**: 512GB SSD
#    - **Price**: $1,999.00 to $2,278.22 depending on configuration (Amazon CA)
#
# ### Potential Use for Agentic AI Development:
#
# Agentic AI systems require robust hardware capable of handling large-scale data processing, complex simulations, and machine learning tasks. The advanced computational power offered by these MacBooks makes them suitable for AI development in several ways:
#
# 1. **High-Performance Computing**:
#    - The M3 and M4 chips provide enhanced speed and efficiency, making them suitable for training deep learning models and running intensive simulations.
#
# 2. **Unified Memory Architecture**:
#    - With up to 24GB Unified Memory, developers can handle large datasets and execute complex algorithms without bottlenecks.
#
# 3. **Storage Capacity**:
#    - The 512GB SSD in both models allows for quick access and storage of AI models and data.
#
# 4. **Integration with Apple Ecosystem**:
#    - MacBooks are integrated with Apple’s software ecosystem, offering tools like Core ML and TensorFlow optimized for macOS.
#
# 5. **Portability**:
#    - The lightweight design of MacBooks ensures that developers can work on AI projects from anywhere, facilitating collaborative and remote development.
#
# ### Recommendations for AI Development:
# For agentic AI development, the MacBook Pro 16-inch is recommended due to its larger RAM and advanced processing capabilities, suitable for high-complexity tasks. The MacBook Air 15-inch is a cost-effective alternative for entry-level AI projects or developers focusing on lightweight applications.
#
# In summary, the latest MacBooks, powered by Apple silicon chips, provide the computational power and efficiency required for developing agentic AI systems. Their advanced features and portability make them valuable assets for AI researchers and developers.
# ---------- user_proxy ----------
# find iinformation about magentic one from microsoft and create a summary of its capabilities
# ---------- web_surfer ----------
# I typed 'Magentic One Microsoft' into the browser search bar.
#
# The web browser is open to the page [Magentic One Microsoft - Search](https://www.bing.com/search?q=Magentic+One+Microsoft&FORM=QBLH).
# The viewport shows 27% of the webpage, and is positioned at the top of the page
# The following text is visible in the viewport:
#
# Skip to content
# Magentic One MicrosoftFrançaisMobileAll
# Search
# Videos
# Images
# Maps
# News
# Copilot
# More
# Tools
# About 261,000 resultsMicrosoft
# https://www.microsoft.com › en-us › research › articles › magentic-one …
# Magentic-One: A Generalist Multi-Agent System for Solving …Nov 4, 2024 · We are introducing Magentic-One, our new generalist multi-agent system for solving open-ended web and file-based tasks across a variety of domains. Magentic-One represents a …
# microsoft.github.io
# https://microsoft.github.io › ... › agentchat-user-guide › m…
# Magentic-One — AutoGen - microsoft.github.ioMagentic-One is a generalist multi-agent system for solving open-ended web and file-based tasks across a variety of domains. It represents a significant step forward for multi-agent systems, achieving competitive performance on a …
# Videos of Magentic One Microsoft
# bing.com › videos8:05
# Microsoft’s New Magnetic-
# One AI System Is More Powerful Than Anything We’ve Seen!
# 60.6K views5 months agoYouTubeAI Revolution16:39
# Multi-Agent AI EXPLAINED: How
# Magentic-
# One Works
# 22.2K views5 months agoYouTubeSam WitteveenRelated searches for
# magnetic one microsoftmagnetic one
# downloadinstall magnetic one
# magentic one
# installmicrosoft
# magentic one
# tutorialmagnetic one
# autogenmagnetic one microsoft
# github
#
# The following metadata was extracted from the webpage:
#
# {
#     "meta_tags": {
#         "referrer": "origin-when-cross-origin",
#         "SystemEntropyOriginTrialToken": "A5is4nwJJVnhaJpUr1URgj4vvAXSiHoK0VBbM9fawMskbDUj9WUREpa3JzGAo6xd1Cp2voQEG1h6NQ71AsMznU8AAABxeyJvcmlnaW4iOiJodHRwczovL3d3dy5iaW5nLmNvbTo0NDMiLCJmZWF0dXJlIjoiTXNVc2VyQWdlbnRMYXVuY2hOYXZUeXBlIiwiZXhwaXJ5IjoxNzUzNzQ3MjAwLCJpc1N1YmRvbWFpbiI6dHJ1ZX0=",
#         "ConfidenceOriginTrialToken": "Aqw360MHzRcmtEVv55zzdIWcTk2BBYHcdBAOysNJZP4qkN8M+5vUq36ITHFVst8LiX36KBZJXB8xvyBgdK2z5Q0AAAB6eyJvcmlnaW4iOiJodHRwczovL2JpbmcuY29tOjQ0MyIsImZlYXR1cmUiOiJQZXJmb3JtYW5jZU5hdmlnYXRpb25UaW1pbmdDb25maWRlbmNlIiwiZXhwaXJ5IjoxNzYwNDAwMDAwLCJpc1N1YmRvbWFpbiI6dHJ1ZX0=",
#         "og:description": "Intelligent search from Bing makes it easier to quickly find what you\u2019re looking for and rewards you.",
#         "og:site_name": "Bing",
#         "og:title": "Magentic One Microsoft - Bing",
#         "og:url": "https://www.bing.com/search?q=Magentic+One+Microsoft&FORM=QBLH",
#         "fb:app_id": "3732605936979161",
#         "og:image": "http://www.bing.com/sa/simg/facebook_sharing_5.png",
#         "og:type": "website",
#         "og:image:width": "600",
#         "og:image:height": "315"
#     }
# }
#
# Here is a screenshot of the page.
#
# ---------- user_proxy ----------
# go to the second link on the page
# ---------- web_surfer ----------
# I clicked 'Magentic-One — AutoGen - microsoft.github.io'.
#
# The web browser is open to the page [Magentic-One — AutoGen](https://microsoft.github.io/autogen/dev/user-guide/agentchat-user-guide/magentic-one.html).
# The viewport shows 14% of the webpage, and is positioned at the top of the page
# The following text is visible in the viewport:
#
# This is documentation for
# an unstable development version.
# Switch to stable version
# dev (main)
#  AgentChat
#  Core
#  Extensions
#  Studio
#  API Reference
#  .NET
#  More
# Search
# ⌘
# +
# K
# GitHub
# Discord
# Twitter
# Installation
# Quickstart
# Migration Guide for v0.2 to v0.4
# TutorialIntroduction
# Models
# Messages
# Agents
# Teams
# Human-in-the-Loop
# Termination
# Managing State
# AdvancedCustom Agents
# Selector Group Chat
# Swarm
# Magentic-One
# Memory and RAG
# Logging
# Serializing Components
# Tracing and Observability
# MoreExamples
# Travel Planning
# Company Research
# Literature Review
#  API Reference
#  PyPi
#  Source
# AgentChat
# Magentic-One
# Magentic-One
# #Magentic-One is a generalist multi-agent system for solving open-ended web and file-based tasks across a variety of domains. It represents a significant step forward for multi-agent systems, achieving competitive performance on a number of agentic benchmarks (see the
# technical report for full details).
# When originally released in
# November 2024 Magentic-One was
# implemented directly on the autogen-core library. We have now ported Magentic-One to use
# autogen-agentchat, providing a more modular and easier to use interface.
# To this end, the Magentic-One orchestrator
# MagenticOneGroupChat is now simply an AgentChat team, supporting all standard AgentChat agents and features. Likewise, Magentic-One’s
# MultimodalWebSurfer,
# FileSurfer, and
# MagenticOneCoderAgent agents are now broadly available as AgentChat agents, to be used in any AgentChat workflows.
# Lastly, there is a helper class,
# MagenticOne, which bundles all of this together as it was in the paper with minimal configuration.
# Find additional information about Magentic-one in our
# blog post and
# technical report.
#  On this page
# Getting started
# Architecture
# Citation
#  Edit on GitHub  Show Source
#
# The following metadata was extracted from the webpage:
#
# {
#     "meta_tags": {
#         "viewport": "width=device-width, initial-scale=1",
#         "description": "User Guide for AgentChat, a high-level API for AutoGen ",
#         "docsearch:language": "en",
#         "docsearch:version": "0.4"
#     }
# }
#
# Here is a screenshot of the page.
#
# ---------- user_proxy ----------
# display the magentic one architecture here
# ---------- web_surfer ----------
# I clicked 'Architecture'.
#
# The web browser is open to the page [Magentic-One — AutoGen](https://microsoft.github.io/autogen/dev/user-guide/agentchat-user-guide/magentic-one.html#architecture).
# The viewport shows 14% of the webpage, and is positioned 61% down from the top of the page
# The following text is visible in the viewport:
#
# dev (main)
#  AgentChat
#  Core
#  Extensions
#  Studio
#  API Reference
#  .NET
#  More
# Search
# ⌘
# +
# K
# GitHub
# Discord
# Twitter
# Quickstart
# Migration Guide for v0.2 to v0.4
# TutorialIntroduction
# Models
# Messages
# Agents
# Teams
# Human-in-the-Loop
# Termination
# Managing State
# AdvancedCustom Agents
# Selector Group Chat
# Swarm
# Magentic-One
# Memory and RAG
# Logging
# Serializing Components
# Tracing and Observability
# MoreExamples
# Travel Planning
# Company Research
# Literature Review
#  API Reference
#  PyPi
#  Source
# if
# __name__
# ==
# "__main__":
# asyncio.run(example_usage())Architecture
# #Magentic-One work is based on a multi-agent architecture where a lead Orchestrator agent is responsible for high-level planning, directing other agents and tracking task progress. The Orchestrator begins by creating a plan to tackle the task, gathering needed facts and educated guesses in a Task Ledger that is maintained. At each step of its plan, the Orchestrator creates a Progress Ledger where it self-reflects on task progress and checks whether the task is completed. If the task is not yet completed, it assigns one of Magentic-One other agents a subtask to complete. After the assigned agent completes its subtask, the Orchestrator updates the Progress Ledger and continues in this way until the task is complete. If the Orchestrator finds that progress is not being made for enough steps, it can update the Task Ledger and create a new plan. This is illustrated in the figure above; the Orchestrator work is thus divided into an outer loop where it updates the Task Ledger and an inner loop to update the Progress Ledger.
#  On this page
# Getting started
# Architecture
# Citation
#  Edit on GitHub  Show Source
# Here is a screenshot of the page.
#
# ---------- user_proxy ----------
# got to 'examples" on the left and summarize the examples there
# ---------- web_surfer ----------
# I clicked 'More: Examples'.
#
# The web browser is open to the page [Examples — AutoGen](https://microsoft.github.io/autogen/dev/user-guide/agentchat-user-guide/examples/index.html).
# The viewport shows 87% of the webpage, and is positioned at the top of the page
# The following text is visible in the viewport:
#
# This is documentation for
# an unstable development version.
# Switch to stable version
# dev (main)
#  AgentChat
#  Core
#  Extensions
#  Studio
#  API Reference
#  .NET
#  More
# Search
# ⌘
# +
# K
# GitHub
# Discord
# Twitter
# Installation
# Quickstart
# Migration Guide for v0.2 to v0.4
# TutorialIntroduction
# Models
# Messages
# Agents
# Teams
# Human-in-the-Loop
# Termination
# Managing State
# AdvancedCustom Agents
# Selector Group Chat
# Swarm
# Magentic-One
# Memory and RAG
# Logging
# Serializing Components
# Tracing and Observability
# MoreExamples
# Travel Planning
# Company Research
# Literature Review
# AgentChat
# Examples
# Examples
# #A list of examples to help you get started with AgentChat.
#  Travel Planning
# Generating a travel plan using multiple agents.
#  Company Research
# Generating a company research report using multiple agents with tools.
#  Literature Review
# Generating a literature review using agents with tools.
# previous
# Tracing and Observability
# next
# Travel Planning
#  Edit on GitHub  Show Source
#
# The following metadata was extracted from the webpage:
#
# {
#     "meta_tags": {
#         "viewport": "width=device-width, initial-scale=1",
#         "description": "Examples built using AgentChat, a high-level api for AutoGen ",
#         "docsearch:language": "en",
#         "docsearch:version": "0.4"
#     }
# }
#
# Here is a screenshot of the page.
#
# ---------- user_proxy ----------
# now find me th most important news on cnn about president trump's new tariff on canada
# ---------- web_surfer ----------
# I typed 'President Trump new tariff on Canada site:cnn.com' into the browser search bar.
#
# The web browser is open to the page [President Trump new tariff on Canada site:cnn.com - Search](https://www.bing.com/search?q=President+Trump+new+tariff+on+Canada+site%3Acnn.com&FORM=QBLH).
# The viewport shows 37% of the webpage, and is positioned at the top of the page
# The following text is visible in the viewport:
#
# Skip to content
# President Trump new tariff on Canada site:cnn.comFrançaisMobileAll
# Search
# Videos
# Images
# Maps
# News
# Copilot
# More
# Tools
# About 1,440 resultsCNN
# https://www.cnn.com › business › tariffs-canada-trump
# Trump reverses new tariffs threat on Canada after Ontario …Mar 11, 2025 · President Donald Trump earlier on Tuesday threatened a 50% tariff on the country’s aluminum and steel, a sharp escalation in the budding trade war with Canada in retaliation for Ontario’s...
# CNN
# https://www.cnn.com › politics › trump-canada-dairy-tariffs-fact-check
# Fact check: What Trump doesn’t mention about Canada’s dairy …Mar 10, 2025 · President Donald Trump correctly noted Friday, as he has before, that Canada has tariffs above 200% on dairy products imported from the US. But Trump again failed to mention …
# CNN
# https://www.cnn.com › business › tariffs-trump-canada
# Trump threatens new tariffs on Canada, including 250% tax on …Mar 7, 2025 · A day after offering Canada a one-month reprieve on punishing nearly across-the-board 25% tariffs, President Donald Trump has threatened new tariffs as soon as Friday on …
# CNN
# https://edition.cnn.com › business › canada-tariffs-carney...
# Canada warns Trump on tariffs: Retaliation is coming April 2Mar 28, 2025 · Canadian Prime Minister Mark Carney told President Donald Trump Friday that his nation will retaliate against the United States with tariffs of its own if Trump presses forward …
# CNN
# https://www.cnn.com › business › canada-mexico-auto-tariffs-trump-dg
# Trump’s promised a slew of new tariffs. Here’s what he’s already …Apr 2, 2025 · President Donald Trump has promised to impose dollar-for-dollar reciprocal tariffs on countries he believes treat the United States unfairly in trade, whether through high tariffs or …
#
# The following metadata was extracted from the webpage:
#
# {
#     "meta_tags": {
#         "referrer": "origin-when-cross-origin",
#         "SystemEntropyOriginTrialToken": "A5is4nwJJVnhaJpUr1URgj4vvAXSiHoK0VBbM9fawMskbDUj9WUREpa3JzGAo6xd1Cp2voQEG1h6NQ71AsMznU8AAABxeyJvcmlnaW4iOiJodHRwczovL3d3dy5iaW5nLmNvbTo0NDMiLCJmZWF0dXJlIjoiTXNVc2VyQWdlbnRMYXVuY2hOYXZUeXBlIiwiZXhwaXJ5IjoxNzUzNzQ3MjAwLCJpc1N1YmRvbWFpbiI6dHJ1ZX0=",
#         "ConfidenceOriginTrialToken": "Aqw360MHzRcmtEVv55zzdIWcTk2BBYHcdBAOysNJZP4qkN8M+5vUq36ITHFVst8LiX36KBZJXB8xvyBgdK2z5Q0AAAB6eyJvcmlnaW4iOiJodHRwczovL2JpbmcuY29tOjQ0MyIsImZlYXR1cmUiOiJQZXJmb3JtYW5jZU5hdmlnYXRpb25UaW1pbmdDb25maWRlbmNlIiwiZXhwaXJ5IjoxNzYwNDAwMDAwLCJpc1N1YmRvbWFpbiI6dHJ1ZX0=",
#         "og:description": "Intelligent search from Bing makes it easier to quickly find what you\u2019re looking for and rewards you.",
#         "og:site_name": "Bing",
#         "og:title": "President Trump new tariff on Canada site:cnn.com - Bing",
#         "og:url": "https://www.bing.com/search?q=President+Trump+new+tariff+on+Canada+site%3Acnn.com&FORM=QBLH",
#         "fb:app_id": "3732605936979161",
#         "og:image": "http://www.bing.com/sa/simg/facebook_sharing_5.png",
#         "og:type": "website",
#         "og:image:width": "600",
#         "og:image:height": "315"
#     }
# }
#
# Here is a screenshot of the page.
#
# ---------- user_proxy ----------
# click on first link on the reversal of tariffs
# ---------- web_surfer ----------
# I clicked 'Trump reverses new tariffs threat on Canada after Ontario …'.
#
# The web browser is open to the page [Trump reverses new tariffs threat on Canada after Ontario rescinds electricity charges | CNN Business](https://www.cnn.com/2025/03/11/business/tariffs-canada-trump/index.html).
# The viewport shows 12% of the webpage, and is positioned at the top of the page
# The following text is visible in the viewport:
#
# Ad Feedback
# Business
#  Markets
#  Tech
#  Media
#  Calculators
#  Videos
#  Watch
#  Listen
#  Live TV
#  Sign in
# Markets
# DOW39,305.59
# 0.92%
# S&P 5005,306.03
# 0.57%
# NASDAQ16,330.47
# 0.14%
# Fear & Greed Index
# 21
# extreme fear is driving the US market
#  Latest Market News
# Google is an online advertising monopoly, judge rulesFord tells dealers prices could go up in June if Trump’s tariffs remainMortgage rates climb to highest level in two months as Trump’s tariffs continue to rock markets Trump reverses new tariffs threat on Canada after Ontario rescinds electricity charges
#  By
# David Goldman and
# Elisabeth Buchwald, CNN
#  6 minute read
#  Updated 5:37 PM EDT, Tue March 11, 2025
#  Link Copied!
# More from CNN
# Trump blasts Fed Chair Powell, saying his ‘termination cannot come fast ...At least 6 people injured in mass shooting at Florida State UniversityOur use of cookies and other technologies
# We and our
# Affiliates use third parties to access and store data on your device to analyze use, improve your experience and personalize, measure and deliver ads and content. For more information, visit our
# Privacy Policy.
#  You can
# Accept All Cookies, or go to
# Cookie Settings for more choices.
# Cookies Settings
# Accept All Cookies
#
# The following metadata was extracted from the webpage:
#
# {
#     "jsonld": [
#         {
#             "@type": "NewsArticle",
#             "@context": "https://schema.org",
#             "articleBody": "President Donald Trump backed down from an extraordinary trade war escalation Tuesday that had threatened a massive surge in tariffs on Canadian steel and aluminum and new tariffs on Canadian electricity. In turn, Ontario paused surcharges on electricity to US customers. After the back-and-forth tariff threats that sent markets sharply lower for a second day Tuesday, US Commerce Secretary Howard Lutnick, Canada\u2019s Minister of Finance Dominic LeBlanc and Ontario Premier Doug Ford said they would meet Thursday to renegotiate the free trade treaty known as the USMCA. Ontario agreed to suspend its 25% surcharge on electricity exports to Michigan, Minnesota and New York. President Donald Trump earlier on Tuesday threatened a 50% tariff on the country\u2019s aluminum and steel, a sharp escalation in the budding trade war with Canada in retaliation for Ontario\u2019s export surcharge. But Trump later signaled he would back down. When a reporter asked him at a White House event if that 50% tariff would still go into effect, Trump sidestepped: \u201cI\u2019ll let you know,\u201d he said. Shortly after those remarks, White House senior counselor for trade and manufacturing Peter Navarro confirmed in a CNBC interview that Trump\u2019s threat of higher tariffs won\u2019t be going into effect. Instead, 25% tariffs on all steel and aluminum the US imports, including from Canada, are set to take effect at midnight on Wednesday, White House spokesperson Kush Desai told CNN in an emailed statement. \u201cIt may go up higher,\u201d Trump said Tuesday at an event hosted by the Business Roundtable. \u201cThe higher it goes, the more likely it is they\u2019re going to build,\u201d he said, referring to more companies moving their production to the US. Markets initially fell sharply following Trump\u2019s Truth Social post announcing his 50% tariff threat on Canadian aluminum and steel but pared their losses after the joint Lutnick-Ford statement. The Dow pared its losses but still fell after Trump said in comments outside the White House Tuesday that he didn\u2019t care what happened to the stock market. The Dow closed the day down 478 points, or 1.1%. The broader S&P 500 fell 0.8% and approached correction territory, when a stock falls 10% from its high. The Nasdaq Composite, already in correction, fell another 0.2%. Tit for tat Earlier Tuesday morning, Trump said he would respond in kind to Ontario\u2019s 25% surcharge on electricity to New York, Minnesota and Michigan with a 25% tariff on Canadian electricity. The surcharge, announced Monday, could have increases utility bills by $100 a month, according to Ford. In addition, Trump said he would levy even larger tariffs on Canadian steel and aluminum than he had planned Wednesday. \u201cBased on Ontario, Canada, placing a 25% Tariff on \u2018Electricity\u2019 coming into the United States, I have instructed my Secretary of Commerce to ad an ADDITIONAL 25% Tariff, to 50%, on all STEEL and ALUMINUM COMING INTO THE UNITED STATES FROM CANADA, ONE OF THE HIGHEST TARIFFING NATIONS ANYWHERE IN THE WORLD,\u201d Trump said in a social media post Tuesday. Ford threatened to shut off electricity supply to the US entirely, and Mark Carney, Canada\u2019s next leader, said he would continue to keep the pressure on America in response to Trump\u2019s tariff actions. \u201cMy government will keep our tariffs on until the Americans show us respect and make credible, reliable commitments to free and fair trade,\u201d he said in a post on X on Tuesday before the announcement from Lutnick and Ford. White House Press Secretary Karoline Leavitt said on Tuesday that Trump has yet to speak with Carney but that \u201chis phone is always open to leaders who wish to speak with him.\u201d Trump had said he would declare a national electricity emergency in the states Ontario targeted. \u201cCan you imagine Canada stooping so low as to use ELECTRICITY, that so affects the life of innocent peop ...
#             "articleSection": [
#                 "business"
#             ],
#             "author": [
#                 {
#                     "@type": "Person",
#                     "name": "David Goldman",
#                     "url": "https://www.cnn.com/profiles/david-goldman"
#                 },
#                 {
#                     "@type": "Person",
#                     "name": "Elisabeth Buchwald",
#                     "url": "https://www.cnn.com/profiles/elisabeth-buchwald"
#                 }
#             ],
#             "dateModified": "2025-03-11T21:37:32.604Z",
#             "description": "President Donald Trump backed down from an extraordinary trade war escalation Tuesday that had threatened a massive surge in Canadian steel and aluminum tariffs and new tariffs on Canadian electricity. In turn, Ontario paused surcharges on electricity to US customers.",
#             "headline": "Trump reverses new tariffs threat on Canada after Ontario rescinds electricity charges",
#             "alternativeHeadline": "Trump reverses new tariffs threat on Canada after Ontario rescinds electricity charges",
#             "image": [
#                 {
#                     "@type": "ImageObject",
#                     "contentUrl": "https://media.cnn.com/api/v1/images/stellar/prod/ap25041803740466.jpg?c=original",
#                     "caption": "Steel coils at the ArcelorMittal Dofasco steel production facility in Hamilton, Ontario, Monday, Feb. 10, 2025.",
#                     "sourceOrganization": {
#                         "@type": "Organization",
#                         "name": "AP licensed"
#                     },
#                     "width": "2000",
#                     "height": "1333",
#                     "creditText": "Nick Iwanyshyn/The Canadian Press/AP",
#                     "dateCreated": "2025-02-10T05:00:00.000Z"
#                 },
#                 {
#                     "@type": "ImageObject",
#                     "contentUrl": "https://media.cnn.com/api/v1/images/stellar/prod/ap25041803740466.jpg?c=original",
#                     "caption": "Steel coils at the ArcelorMittal Dofasco steel production facility in Hamilton, Ontario, Monday, Feb. 10, 2025.",
#                     "sourceOrganization": {
#                         "@type": "Organization",
#                         "name": "AP licensed"
#                     },
#                     "width": "2000",
#                     "height": "1333",
#                     "creditText": "Nick Iwanyshyn/The Canadian Press/AP",
#                     "dateCreated": "2025-02-10T05:00:00.000Z"
#                 }
#             ],
#             "thumbnailUrl": "https://media.cnn.com/api/v1/images/stellar/prod/ap25041803740466.jpg?c=original",
#             "inLanguage": "en",
#             "mainEntityOfPage": {
#                 "@type": "WebPage",
#                 "@context": "https://schema.org",
#                 "url": "https://www.cnn.com/2025/03/11/business/tariffs-canada-trump/index.html",
#                 "dateModified": "2025-03-11T21:37:32.604Z",
#                 "inLanguage": "en",
#                 "additionalType": "article_leaf",
#                 "publisher": {
#                     "@type": "NewsMediaOrganization",
#                     "name": "CNN",
#                     "logo": "https://media.cnn.com/api/v1/images/stellar/prod/cnnlogo.png?q=w_60,h_61",
#                     "foundingDate": "1980-06-01",
#                     "url": "https://www.cnn.com",
#                     "sameAs": [
#                         "https://www.facebook.com/cnn/",
#                         "https://x.com/CNN",
#                         "https://www.tiktok.com/@cnn",
#                         "https://www.instagram.com/cnn/",
#                         "https://www.youtube.com/cnn"
#                     ]
#                 },
#                 "name": "Trump reverses new tariffs threat on Canada after Ontario rescinds electricity charges",
#                 "headline": "Trump reverses new tariffs threat on Canada after Ontario rescinds electricity charges",
#                 "description": "President Donald Trump backed down from an extraordinary trade war escalation Tuesday that had threatened a massive surge in Canadian steel and aluminum tariffs and new tariffs on Canadian electricity. In turn, Ontario paused surcharges on electricity to US customers.",
#                 "datePublished": "2025-03-11T14:18:43.762Z"
#             },
#             "publisher": {
#                 "@type": "NewsMediaOrganization",
#                 "name": "CNN",
#                 "logo": "https://media.cnn.com/api/v1/images/stellar/prod/cnnlogo.png?q=w_60,h_61",
#                 "foundingDate": "1980-06-01",
#                 "url": "https://www.cnn.com",
#                 "sameAs": [
#                     "https://www.facebook.com/cnn/",
#                     "https://x.com/CNN",
#                     "https://www.tiktok.com/@cnn",
#                     "https://www.instagram.com/cnn/",
#                     "https://www.youtube.com/cnn"
#                 ]
#             },
#             "timeRequired": "P0Y0M0DT0H5M25S",
#             "wordCount": 1222,
#             "datePublished": "2025-03-11T14:18:43.762Z",
#             "isAccessibleForFree": false,
#             "hasPart": {
#                 "@type": "WebPageElement",
#                 "isAccessibleForFree": false,
#                 "cssSelector": ".article__content"
#             }
#         }
#     ],
#     "meta_tags": {
#         "viewport": "width=device-width,initial-scale=1,shrink-to-fit=no",
#         "og:title": "Trump reverses new tariffs threat on Canada after Ontario rescinds electricity charges | CNN Business",
#         "twitter:title": "Trump reverses new tariffs threat on Canada after Ontario rescinds electricity charges | CNN Business",
#         "description": "President Donald Trump backed down from an extraordinary trade war escalation Tuesday that had threatened a massive surge in Canadian steel and aluminum tariffs and new tariffs on Canadian electricity. In turn, Ontario paused surcharges on electricity to US customers.",
#         "twitter:description": "President Donald Trump backed down from an extraordinary trade war escalation Tuesday that had threatened a massive surge in Canadian steel and aluminum tariffs and new tariffs on Canadian electricity. In turn, Ontario paused surcharges on electricity to US customers.",
#         "og:description": "President Donald Trump backed down from an extraordinary trade war escalation Tuesday that had threatened a massive surge in Canadian steel and aluminum tariffs and new tariffs on Canadian electricity. In turn, Ontario paused surcharges on electricity to US customers.",
#         "twitter:image": "https://media.cnn.com/api/v1/images/stellar/prod/ap25041803740466.jpg?c=16x9&q=w_800,c_fill",
#         "og:image": "https://media.cnn.com/api/v1/images/stellar/prod/ap25041803740466.jpg?c=16x9&q=w_800,c_fill",
#         "template_type": "article_leaf",
#         "og:type": "article",
#         "type": "article",
#         "meta-section": "business",
#         "meta-branding": "",
#         "theme": "business",
#         "twitter:card": "summary_large_image",
#         "og:url": "https://www.cnn.com/2025/03/11/business/tariffs-canada-trump/index.html",
#         "article:published_time": "2025-03-11T14:18:43.762Z",
#         "article:modified_time": "2025-03-11T21:37:32.604Z",
#         "keywords": "",
#         "article:tag": "",
#         "author": "David Goldman, Elisabeth Buchwald",
#         "robots": "max-image-preview:large",
#         "twitter:site": "@CNNbusiness",
#         "article:publisher": "https://www.facebook.com/CNN",
#         "fb:app_id": "80401312489",
#         "og:site_name": "CNN"
#     }
# }
#
# Here is a screenshot of the page.
#
# ---------- user_proxy ----------
# exit
