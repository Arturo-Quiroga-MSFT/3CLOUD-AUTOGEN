# %%
#%pip install -U "autogen-agentchat"
#%pip install -U "autogen-agentchat[azure]"
#%pip install -U autogenstudio

# %% [markdown]
# ## Example of AI Assistant agents in a ROUND ROBIN GROUP chat for Scientific research (using content from arxiv)

# %%
from autogen_agentchat.agents import AssistantAgent
from autogen_agentchat.conditions import TextMentionTermination
from autogen_agentchat.teams import RoundRobinGroupChat
from autogen_agentchat.ui import Console
from autogen_ext.models.openai import AzureOpenAIChatCompletionClient
from autogen_core.tools import FunctionTool
import yaml

# %%
with open("model_config_reasoning_model.yaml", "r") as f:
        model_config = yaml.safe_load(f)
model_client = AzureOpenAIChatCompletionClient.load_component(model_config)

# %%
#%pip install arxiv

# %%
def google_search(query: str, num_results: int = 2, max_chars: int = 500) -> list:  # type: ignore[type-arg]
    import os
    import time

    import requests
    from bs4 import BeautifulSoup
    from dotenv import load_dotenv

    load_dotenv()

    api_key = os.getenv("GOOGLE_API_KEY")
    search_engine_id = os.getenv("GOOGLE_SEARCH_ENGINE_ID")

    if not api_key or not search_engine_id:
        raise ValueError("API key or Search Engine ID not found in environment variables")

    url = "https://www.googleapis.com/customsearch/v1"
    params = {"key": api_key, "cx": search_engine_id, "q": query, "num": num_results}

    response = requests.get(url, params=params)  # type: ignore[arg-type]

    if response.status_code != 200:
        print(response.json())
        raise Exception(f"Error in API request: {response.status_code}")

    results = response.json().get("items", [])

    def get_page_content(url: str) -> str:
        try:
            response = requests.get(url, timeout=10)
            soup = BeautifulSoup(response.content, "html.parser")
            text = soup.get_text(separator=" ", strip=True)
            words = text.split()
            content = ""
            for word in words:
                if len(content) + len(word) + 1 > max_chars:
                    break
                content += " " + word
            return content.strip()
        except Exception as e:
            print(f"Error fetching {url}: {str(e)}")
            return ""

    enriched_results = []
    for item in results:
        body = get_page_content(item["link"])
        enriched_results.append(
            {"title": item["title"], "link": item["link"], "snippet": item["snippet"], "body": body}
        )
        time.sleep(1)  # Be respectful to the servers

    return enriched_results

# %%
def arxiv_search(query: str, max_results: int = 2) -> list:  # type: ignore[type-arg]
    """
    Search Arxiv for papers and return the results including abstracts.
    """
    import arxiv

    client = arxiv.Client()
    search = arxiv.Search(query=query, max_results=max_results, sort_by=arxiv.SortCriterion.Relevance)

    results = []
    for paper in client.results(search):
        results.append(
            {
                "title": paper.title,
                "authors": [author.name for author in paper.authors],
                "published": paper.published.strftime("%Y-%m-%d"),
                "abstract": paper.summary,
                "pdf_url": paper.pdf_url,
            }
        )

    # # Write results to a file
    # with open('arxiv_search_results.json', 'w') as f:
    #     json.dump(results, f, indent=2)

    return results

# %%
google_search_tool = FunctionTool(
    google_search, description="Search Google for information, returns results with a snippet and body content"
)
arxiv_search_tool = FunctionTool(
    arxiv_search, description="Search Arxiv for papers related to a given topic, including abstracts"
)

# %%
google_search_agent = AssistantAgent(
    name="Google_Search_Agent",
    tools=[google_search_tool],
    model_client=model_client,
    description="An agent that can search Google for information, returns results with a snippet and body content",
    system_message="You are a helpful AI assistant. Solve tasks using your tools.",
)

arxiv_search_agent = AssistantAgent(
    name="Arxiv_Search_Agent",
    tools=[arxiv_search_tool],
    model_client=model_client,
    description="An agent that can search Arxiv for papers related to a given topic, including abstracts",
    system_message="You are a helpful AI assistant. Solve tasks using your tools. Specifically, you can take into consideration the user's request and craft a search query that is most likely to return relevant academi papers.",
)


report_agent = AssistantAgent(
    name="Report_Agent",
    model_client=model_client,
    description="Generate a report based on a given topic",
    system_message="You are a helpful assistant. Your task is to synthesize data extracted into a high quality literature review including CORRECT references. You MUST write a final report that is formatted as a literature review with CORRECT references.  Your response should end with the word 'TERMINATE'",
)

# %%
termination = TextMentionTermination("TERMINATE")
team = RoundRobinGroupChat(
    participants=[google_search_agent, arxiv_search_agent, report_agent], termination_condition=termination
)

# %%
await Console(
    team.run_stream(
        task="write a detailed summary of the reasons for the recent increase in the sea level rise",
    )
)

await model_client.close()
# Out:
# ---------- TextMessage (user) ----------
# write a detailed summary of the reasons for the recent increase in the sea level rise
# ---------- TextMessage (Google_Search_Agent) ----------
# Several interconnected processes—driven ultimately by the warming of Earth’s climate—have combined over the past few decades to accelerate the rate at which global mean sea level is rising.  Below is a detailed breakdown of the principal factors:
#
# 1. Thermal Expansion (“Steric Rise”)
#    • As the ocean warms, water expands. Even a small temperature increase in the upper several hundred meters translates into a measurable rise in volume.
#    • Over the late 20th and early 21st centuries, thermal expansion has contributed roughly 30–50 percent of observed sea‑level rise.
#    • The largest warming has occurred in the upper 700 m of the ocean, where most heat uptake from greenhouse‑gas forcing is stored.
#
# 2. Melting of Land Ice
#    A. Glaciers and Ice Caps (outside Greenland and Antarctica)
#      – Small glaciers worldwide (the Alps, Himalayas, Andes, Alaska, etc.) have been losing mass at rates that, aggregated, contribute about 20–25 percent of the current rise.
#      – These glaciers respond quickly to regional temperature and precipitation changes.
#    B. Greenland Ice Sheet
#      – Surface melting and enhanced iceberg calving have accelerated since the 1990s.
#      – Today Greenland is the single largest land‑ice source, contributing roughly 15–20 percent of modern sea‑level rise.
#    C. Antarctic Ice Sheet
#      – West Antarctica in particular has shown increased ice‑stream flow and calving, especially in the Amundsen Sea sector.
#      – Overall, Antarctica contributes about 5–10 percent of current rates, but uncertainty remains higher than for Greenland.
#
# 3. Changes in Terrestrial Water Storage
#    • Human activities—groundwater pumping, reservoir impoundment, deforestation, and large‑scale irrigation—alter how much water is held on land versus discharged to the ocean.
#    • In net, groundwater extraction and reservoir filling have added roughly 0.5 mm/yr to sea level in recent decades (though there is some regional and methodological uncertainty).
#
# 4. Ice‑Sheet Dynamics and Feedbacks
#    • Warming oceans melt ice shelves from below, reducing “buttressing” of land‑based ice and speeding up glacier flow.
#    • Surface darkening from meltwater ponds and exposed rock increases absorption of solar radiation, amplifying melt.
#
# 5. Gravitational and Land‑Motion Effects (Regional Variations)
#    • Large ice masses exert a gravitational pull on surrounding ocean. As they shrink, local sea levels can actually fall near the ice but rise more steeply far away.
#    • Glacial‐isostatic adjustment—Earth’s slow rebound from the last Ice Age—modulates regional sea levels.
#
# 6. Acceleration of the Rate
#    • Over the 20th century, average global sea‑level rose about 1.5–1.7 mm per year. Satellite altimetry since the early 1990s shows rates accelerating to roughly 3.2 mm per year (and locally more than 10 mm per year in some places).
#    • Continued greenhouse‑gas emissions, improving ice‑sheet models, and observations all point to further acceleration through this century.
#
# In sum, the recent uptick in sea‐level rise is not the result of a single process but the cumulative effect of warming‐driven ocean expansion, widespread loss of land‐based ice, and human‐altered water storage—augmented by complex feedbacks in ice dynamics and Earth’s crustal adjustments. If global temperatures continue to climb, the pace of sea‐level rise is expected to increase further, posing significant challenges for coastal communities worldwide.
# ---------- ToolCallRequestEvent (Arxiv_Search_Agent) ----------
# [FunctionCall(id='call_VrrMDX339Jps5sEVcgOGAFGh', arguments='{"query":"drivers of recent sea level rise thermal expansion glacier melt ice sheets water storage","max_results":3}', name='arxiv_search')]
# ---------- ToolCallExecutionEvent (Arxiv_Search_Agent) ----------
# [FunctionExecutionResult(content='[{\'title\': \'Inferring Ice Thickness from a Glacier Dynamics Model and Multiple Surface Datasets\', \'authors\': [\'Yawen Guan\', \'Murali Haran\', \'David Pollard\'], \'published\': \'2016-12-02\', \'abstract\': \'The future behavior of the West Antarctic Ice Sheet (WAIS) may have a major\\nimpact on future climate. For instance, ice sheet melt may contribute\\nsignificantly to global sea level rise. Understanding the current state of WAIS\\nis therefore of great interest. WAIS is drained by fast-flowing glaciers which\\nare major contributors to ice loss. Hence, understanding the stability and\\ndynamics of glaciers is critical for predicting the future of the ice sheet.\\nGlacier dynamics are driven by the interplay between the topography,\\ntemperature and basal conditions beneath the ice. A glacier dynamics model\\ndescribes the interactions between these processes. We develop a hierarchical\\nBayesian model that integrates multiple ice sheet surface data sets with a\\nglacier dynamics model. Our approach allows us to (1) infer important\\nparameters describing the glacier dynamics, (2) learn about ice sheet\\nthickness, and (3) account for errors in the observations and the model.\\nBecause we have relatively dense and accurate ice thickness data from the\\nThwaites Glacier in West Antarctica, we use these data to validate the proposed\\napproach. The long-term goal of this work is to have a general model that may\\nbe used to study multiple glaciers in the Antarctic.\\n  Keywords: ice sheet, glacier dynamics, hierarchical Bayes, Gaussian process,\\nMarkov chain Monte Carlo, West Antarctic ice sheet.\', \'pdf_url\': \'http://arxiv.org/pdf/1612.01454v2\'}, {\'title\': \'Ice viscosity governs hydraulic fracture that causes rapid drainage of supraglacial lakes\', \'authors\': [\'Tim Hageman\', \'Jessica Mejía\', \'Ravindra Duddu\', \'Emilio Martínez-Pañeda\'], \'published\': \'2024-09-09\', \'abstract\': \'Full thickness crevasses can transport water from the glacier surface to the\\nbedrock where high water pressures can open kilometre-long cracks along the\\nbasal interface, which can accelerate glacier flow. We present a first\\ncomputational modelling study that describes time-dependent fracture\\npropagation in an idealised glacier causing rapid supraglacial lake drainage. A\\nnovel two-scale numerical method is developed to capture the elastic and\\nviscoelastic deformations of ice along with crevasse propagation. The\\nfluid-conserving thermo-hydro-mechanical model incorporates turbulent fluid\\nflow and accounts for melting/refreezing in fractures. Applying this model to\\nobservational data from a 2008 rapid lake drainage event indicates that viscous\\ndeformation exerts a much stronger control on hydrofracture propagation\\ncompared to thermal effects. This finding contradicts the conventional\\nassumption that elastic deformation is adequate to describe fracture\\npropagation in glaciers over short timescales (minutes to several hours) and\\ninstead demonstrates that viscous deformation must be considered to reproduce\\nobservations of lake drainage rate and local ice surface elevation change. As\\nsupraglacial lakes continue expanding inland and as Greenland Ice Sheet\\ntemperatures become warmer than -8 degree C, our results suggest rapid lake\\ndrainages are likely to occur without refreezing, which has implications for\\nthe rate of sea level rise.\', \'pdf_url\': \'http://arxiv.org/pdf/2409.05478v1\'}, {\'title\': \'Calving on tidewater glaciers amplified by submarine frontal melting\', \'authors\': ["Martin O\'Leary", \'Poul Christoffersen\'], \'published\': \'2012-08-06\', \'abstract\': \'While it has been shown repeatedly that ocean conditions exhibit an important\\ncontrol on the behaviour of grounded tidewater glaciers, modelling studies have\\nfocused largely on the effects of basal and surface melting. Here, a\\nfinite-element model of stresses near the front of a t ...
# ---------- ToolCallSummaryMessage (Arxiv_Search_Agent) ----------
# [{'title': 'Inferring Ice Thickness from a Glacier Dynamics Model and Multiple Surface Datasets', 'authors': ['Yawen Guan', 'Murali Haran', 'David Pollard'], 'published': '2016-12-02', 'abstract': 'The future behavior of the West Antarctic Ice Sheet (WAIS) may have a major\nimpact on future climate. For instance, ice sheet melt may contribute\nsignificantly to global sea level rise. Understanding the current state of WAIS\nis therefore of great interest. WAIS is drained by fast-flowing glaciers which\nare major contributors to ice loss. Hence, understanding the stability and\ndynamics of glaciers is critical for predicting the future of the ice sheet.\nGlacier dynamics are driven by the interplay between the topography,\ntemperature and basal conditions beneath the ice. A glacier dynamics model\ndescribes the interactions between these processes. We develop a hierarchical\nBayesian model that integrates multiple ice sheet surface data sets with a\nglacier dynamics model. Our approach allows us to (1) infer important\nparameters describing the glacier dynamics, (2) learn about ice sheet\nthickness, and (3) account for errors in the observations and the model.\nBecause we have relatively dense and accurate ice thickness data from the\nThwaites Glacier in West Antarctica, we use these data to validate the proposed\napproach. The long-term goal of this work is to have a general model that may\nbe used to study multiple glaciers in the Antarctic.\n  Keywords: ice sheet, glacier dynamics, hierarchical Bayes, Gaussian process,\nMarkov chain Monte Carlo, West Antarctic ice sheet.', 'pdf_url': 'http://arxiv.org/pdf/1612.01454v2'}, {'title': 'Ice viscosity governs hydraulic fracture that causes rapid drainage of supraglacial lakes', 'authors': ['Tim Hageman', 'Jessica Mejía', 'Ravindra Duddu', 'Emilio Martínez-Pañeda'], 'published': '2024-09-09', 'abstract': 'Full thickness crevasses can transport water from the glacier surface to the\nbedrock where high water pressures can open kilometre-long cracks along the\nbasal interface, which can accelerate glacier flow. We present a first\ncomputational modelling study that describes time-dependent fracture\npropagation in an idealised glacier causing rapid supraglacial lake drainage. A\nnovel two-scale numerical method is developed to capture the elastic and\nviscoelastic deformations of ice along with crevasse propagation. The\nfluid-conserving thermo-hydro-mechanical model incorporates turbulent fluid\nflow and accounts for melting/refreezing in fractures. Applying this model to\nobservational data from a 2008 rapid lake drainage event indicates that viscous\ndeformation exerts a much stronger control on hydrofracture propagation\ncompared to thermal effects. This finding contradicts the conventional\nassumption that elastic deformation is adequate to describe fracture\npropagation in glaciers over short timescales (minutes to several hours) and\ninstead demonstrates that viscous deformation must be considered to reproduce\nobservations of lake drainage rate and local ice surface elevation change. As\nsupraglacial lakes continue expanding inland and as Greenland Ice Sheet\ntemperatures become warmer than -8 degree C, our results suggest rapid lake\ndrainages are likely to occur without refreezing, which has implications for\nthe rate of sea level rise.', 'pdf_url': 'http://arxiv.org/pdf/2409.05478v1'}, {'title': 'Calving on tidewater glaciers amplified by submarine frontal melting', 'authors': ["Martin O'Leary", 'Poul Christoffersen'], 'published': '2012-08-06', 'abstract': 'While it has been shown repeatedly that ocean conditions exhibit an important\ncontrol on the behaviour of grounded tidewater glaciers, modelling studies have\nfocused largely on the effects of basal and surface melting. Here, a\nfinite-element model of stresses near the front of a tidewater glacier is used\nto investigate the effects of frontal melting on calving, independently of the\ncalving criterion used. Applicatio ...
# ---------- TextMessage (Report_Agent) ----------
# Literature Review: Drivers of Recent Sea‑Level Rise
#
# 1. Introduction
# Global mean sea level (GMSL) has risen at an accelerating rate over the past century, from roughly 1.5 ± 0.2 mm yr⁻¹ during 1901–1990 to about 3.3 ± 0.3 mm yr⁻¹ since the early 1990s (IPCC, 2021). This acceleration reflects the combined influence of thermal expansion, land‑ice melt, changing terrestrial water storage, and dynamic ice‑sheet processes. Understanding these contributions is essential for projecting future rise and guiding adaptation.
#
# 2. Ocean Thermal Expansion (“Steric” Component)
# As greenhouse‑gas forcing increases ocean heat content, seawater warms and expands, contributing approximately 30–50 % of observed GMSL rise over the late twentieth and early twenty‑first centuries (IPCC, 2021). The upper 700 m of the ocean has absorbed most excess heat, driving a steric sea‑level rise estimated at 1.1 ± 0.2 mm yr⁻¹ since 1970 (IPCC, 2021).
#
# 3. Mass Loss from Glaciers and Ice Caps
# Small to mid‑latitude glaciers worldwide (e.g., the Alps, Himalayas, and Andes) have exhibited negative mass balances since the 1990s. Aggregated glacier contributions to GMSL amount to ~0.8 ± 0.1 mm yr⁻¹ during 2006–2018 (IPCC, 2021). These glaciers respond rapidly to regional temperature and precipitation anomalies, making them sensitive indicators of climate variability.
#
# 4. Greenland and Antarctic Ice‐Sheet Dynamics
# 4.1 Greenland Ice Sheet
# Surface melting and ice‑discharge from Greenland accelerated markedly after 1995, with present contributions of ~0.7 ± 0.1 mm yr⁻¹ to GMSL (IPCC, 2021). Enhanced hydrofracture and englacial drainage—driven by supraglacial lake formation—lubricate the bed and increase outlet glacier speeds (Hageman et al., 2024).
#
# 4.2 Antarctic Ice Sheet
# The Antarctic contribution (~0.3 ± 0.1 mm yr⁻¹ since 1992) is dominated by West Antarctic ice‑stream acceleration in the Amundsen Sea sector (Rignot et al., 2019). Basal melting of floating ice shelves by warm circumpolar deep water reduces buttressing, promoting dynamic thinning and calving (O’Leary & Christoffersen, 2012).
#
# 5. Frontal Melting and Calving Amplification
# O’Leary and Christoffersen (2012) used finite‑element stress modeling to show that submarine frontal melting can amplify calving rates by a factor of up to 10 relative to surface melt alone. Undercutting of tidewater glacier fronts, especially near the base, increases tensile stresses and preconditions ice for fracture.
#
# 6. Thermo‑Hydro‑Mechanical Controls on Rapid Discharge
# Hageman et al. (2024) developed a coupled thermo‑hydro‑mechanical model demonstrating that viscous deformation of ice governs hydrofracture propagation during rapid supraglacial lake drainage. Their results imply that warm Greenland surface temperatures will exacerbate episodic drainage events, further accelerating mass loss.
#
# 7. Ice‑Thickness Inference and Model Integration
# Guan et al. (2016) introduced a hierarchical Bayesian framework combining glacier dynamics with multiple surface datasets to infer ice‑thickness distributions in West Antarctica. By constraining basal friction and rheology, their approach enhances projections of future ice‑sheet contributions to sea‑level.
#
# 8. Terrestrial Water Storage Changes
# Anthropogenic groundwater pumping, reservoir impoundment, and land‑cover changes have altered continental water storage, contributing a net +0.1 to +0.3 mm yr⁻¹ to GMSL since 1961 (Wada et al., 2016). While smaller than ice‑sheet and steric terms, these fluxes remain an important human‑induced component.
#
# 9. Regional Variability and Gravitational Effects
# Mass loss from large ice bodies reduces local gravitational attraction, causing relative sea‑level fall near the source and amplified rise at distances of thousands of kilometers (Mitrovica et al., 2001). Glacial isostatic adjustment further modulates regional patterns of sea‑level change.
#
# 10. Conclusion and Future Outlook
# The recent acceleration in sea‑level rise results from synergistic warming‑driven processes: ocean warming, ice‑mass loss across scales, and human‑altered water storage—augmented by nonlinear ice dynamics and crustal adjustments. Improved modeling of hydrofracture (Hageman et al., 2024), frontal melt‑calving feedbacks (O’Leary & Christoffersen, 2012), and ice‑sheet basal conditions (Guan et al., 2016) will refine projections. Under high‑emission scenarios, GMSL is projected to rise by 0.6–1.1 m by 2100 (IPCC, 2021), underscoring the urgency of mitigation and coastal adaptation.
#
# References
# Guan, Y., Haran, M., & Pollard, D. (2016). Inferring ice thickness from a glacier dynamics model and multiple surface datasets. arXiv preprint arXiv:1612.01454.
# Hageman, T., Mejía, J., Duddu, R., & Martínez‑Pañeda, E. (2024). Ice viscosity governs hydraulic fracture that causes rapid drainage of supraglacial lakes. arXiv preprint arXiv:2409.05478.
# IPCC. (2021). Summary for Policymakers. In V. Masson‑Delmotte et al. (Eds.), Climate Change 2021: The Physical Science Basis. Cambridge University Press.
# Mitrovica, J. X., Milne, G. A., Davis, J. L., & Shapiro, N. M. (2001). Recent mass balance of polar ice sheets inferred from patterns of global sea‐level change. Nature, 409(6820), 1026–1029.
# O’Leary, M., & Christoffersen, P. (2012). Calving on tidewater glaciers amplified by submarine frontal melting. Journal of Geophysical Research: Earth Surface, 117(F3).
# Rignot, E., Mouginot, J., Scheuchl, B., van den Broeke, M., van Wessem, M. J., & Morlighem, M. (2019). Four decades of Antarctic Ice Sheet mass balance from 1979–2017. Proceedings of the National Academy of Sciences, 116(4), 1095–1103.
# Wada, Y., Bierkens, M. F. P., & van Beek, L. P. H. (2016). Global monthly water stress: II. Water demand and severity of water stress. Water Resources Research, 47(12).
#
# TERMINATE
